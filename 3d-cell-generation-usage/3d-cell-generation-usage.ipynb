# %% [markdown]
# ## Demo of the 3D Cell Generation API

# %% [markdown]
# This notebook demonstrates how to get a cell type population for anatomical structures (ASpop) from HRApop, formulate a request for the 3D Cell Generation API, and display the result in 3D using the `node-dist-vis` HRA Jupyter Widgets.

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Install and import libraries

# %%
# %pip install requests pandas hra_jupyter_widgets ipywidgets

import requests
import json
from io import StringIO
import pandas as pd
from pprint import pprint
# Out:
# Requirement already satisfied: requests in /Users/abueckle/Documents/GitHub/hra-pop-notebooks/.venv/lib/python3.12/site-packages (2.32.3)
# Requirement already satisfied: pandas in /Users/abueckle/Documents/GitHub/hra-pop-notebooks/.venv/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: hra_jupyter_widgets in /Users/abueckle/Documents/GitHub/hra-pop-notebooks/.venv/lib/python3.12/site-packages (0.4.1)
# Requirement already satisfied: ipywidgets in /Users/abueckle/Documents/GitHub/hra-pop-notebooks/.venv/lib/python3.12/site-packages (8.1.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/abueckle/Documents/GitHub/hra-pop-notebooks/.venv/lib/python3.12/site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/abueckle/Documents/GitHub/hra-pop-notebooks/.venv/lib/python3.12/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/abueckle/Documents/GitHub/hra-pop-notebooks/.venv/lib/python3.12/site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/abueckle/Documents/GitHub/hra-pop-notebooks/.venv/lib/python3.12/site-packages (from requests) (2025.1.31)
# Requirement already satisfied: numpy>=1.26.0 in /Users/abueckle/Documents/GitHub/hra-pop-notebooks/.venv/lib/python3.12/site-packages (from pandas) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/abueckle/Documents/GitHub/hra-pop-notebooks/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/abueckle/Documents/GitHub/hra-pop-notebooks/.venv/lib/python3.12/site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/abueckle/Documents/GitHub/hra-pop-notebooks/.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: anywidget in /Users/abueckle/Documents/GitHub/hra-pop-notebooks/.venv/lib/python3.12/site-packages (from hra_jupyter_widgets) (0.9.18)
# Requirement already satisfied: traitlets>=5.10 in /Users/abueckle/Documents/GitHub/hra-pop-notebooks/.venv/lib/python3.12/site-packages (from hra_jupyter_widgets) (5.14.3)
# Requirement already satisfied: comm>=0.1.3 in /Users/abueckle/Documents/GitHub/hra-pop-notebooks/.venv/lib/python3.12/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /Users/abueckle/Documents/GitHub/hra-pop-notebooks/.venv/lib/python3.12/site-packages (from ipywidgets) (9.0.2)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Users/abueckle/Documents/GitHub/hra-pop-notebooks/.venv/lib/python3.12/site-packages (from ipywidgets) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Users/abueckle/Documents/GitHub/hra-pop-notebooks/.venv/lib/python3.12/site-packages (from ipywidgets) (3.0.15)
# Requirement already satisfied: decorator in /Users/abueckle/Documents/GitHub/hra-pop-notebooks/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /Users/abueckle/Documents/GitHub/hra-pop-notebooks/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/abueckle/Documents/GitHub/hra-pop-notebooks/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/abueckle/Documents/GitHub/hra-pop-notebooks/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /Users/abueckle/Documents/GitHub/hra-pop-notebooks/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/abueckle/Documents/GitHub/hra-pop-notebooks/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /Users/abueckle/Documents/GitHub/hra-pop-notebooks/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.1)
# Requirement already satisfied: stack_data in /Users/abueckle/Documents/GitHub/hra-pop-notebooks/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in /Users/abueckle/Documents/GitHub/hra-pop-notebooks/.venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/abueckle/Documents/GitHub/hra-pop-notebooks/.venv/lib/python3.12/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/abueckle/Documents/GitHub/hra-pop-notebooks/.venv/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Users/abueckle/Documents/GitHub/hra-pop-notebooks/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: psygnal>=0.8.1 in /Users/abueckle/Documents/GitHub/hra-pop-notebooks/.venv/lib/python3.12/site-packages (from anywidget->hra_jupyter_widgets) (0.14.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/abueckle/Documents/GitHub/hra-pop-notebooks/.venv/lib/python3.12/site-packages (from anywidget->hra_jupyter_widgets) (4.13.2)
# Requirement already satisfied: executing>=1.2.0 in /Users/abueckle/Documents/GitHub/hra-pop-notebooks/.venv/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/abueckle/Documents/GitHub/hra-pop-notebooks/.venv/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/abueckle/Documents/GitHub/hra-pop-notebooks/.venv/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Import widgets

# %%
import ipywidgets as widgets
from hra_jupyter_widgets import (
    NodeDistVis,          # VCCF 3D Node Distance Visualization
)

# %% [markdown]
# ## Exemplary call to visualize cell type population for the renal pyramid A in the male, left kidney

# %%
# get ASpop for the male, left kidney
response = requests.get('https://apps.humanatlas.io/api/grlc/hra-pop/cell_types_in_anatomical_structurescts_per_as.csv', headers = {'accept':'text/csv'})
df_as_pop = pd.read_csv(StringIO(response.text))
df_as_pop
# Out:
#                 organ                                             as  \
# 0     large intestine  http://purl.obolibrary.org/obo/UBERON_0001052
# 1     large intestine  http://purl.obolibrary.org/obo/UBERON_0001052
# 2     large intestine  http://purl.obolibrary.org/obo/UBERON_0001052
# 3     large intestine  http://purl.obolibrary.org/obo/UBERON_0001052
# 4     large intestine  http://purl.obolibrary.org/obo/UBERON_0001052
# ...               ...                                            ...
# 8891             lung            http://purl.org/sig/ont/fma/fma7508
# 8892             lung            http://purl.org/sig/ont/fma/fma7508
# 8893             lung            http://purl.org/sig/ont/fma/fma7508
# 8894             lung            http://purl.org/sig/ont/fma/fma7508
# 8895             lung            http://purl.org/sig/ont/fma/fma7508
#
#                                      as_label     sex           tool  \
# 0                                      rectum  Female     celltypist
# 1                                      rectum  Female     celltypist
# 2                                      rectum  Female     celltypist
# 3                                      rectum  Female     celltypist
# 4                                      rectum  Female     celltypist
# ...                                       ...     ...            ...
# 8891  Left posterior basal segmental bronchus    Male  sc_proteomics
# 8892  Left posterior basal segmental bronchus    Male  sc_proteomics
# 8893  Left posterior basal segmental bronchus    Male  sc_proteomics
# 8894  Left posterior basal segmental bronchus    Male  sc_proteomics
# 8895  Left posterior basal segmental bronchus    Male  sc_proteomics
#
#                 modality                                            cell_id  \
# 0     sc_transcriptomics         https://purl.org/ccf/ASCTB-TEMP_colonocyte
# 1     sc_transcriptomics    https://purl.org/ccf/ASCTB-TEMP_iga-plasma-cell
# 2     sc_transcriptomics   https://purl.org/ccf/ASCTB-TEMP_best4-epithelial
# 3     sc_transcriptomics    https://purl.org/ccf/ASCTB-TEMP_activated-cd4-t
# 4     sc_transcriptomics                 https://purl.org/ccf/ASCTB-TEMP_ta
# ...                  ...                                                ...
# 8891       sc_proteomics          http://purl.obolibrary.org/obo/CL_0000097
# 8892       sc_proteomics          http://purl.obolibrary.org/obo/CL_4033039
# 8893       sc_proteomics  https://purl.org/ccf/ASCTB-TEMP_lymphatic-endo...
# 8894       sc_proteomics  https://purl.org/ccf/ASCTB-TEMP_basal-epitheli...
# 8895       sc_proteomics          http://purl.obolibrary.org/obo/CL_0000236
#
#                                          cell_label  cell_count  \
# 0                                        Colonocyte       1.205
# 1                                   IgA plasma cell       1.182
# 2                                 BEST4+ epithelial       0.699
# 3                                   Activated CD4 T       0.690
# 4                                                TA       0.540
# ...                                             ...         ...
# 8891                                      Mast Cell   15322.464
# 8892                                    CD8+ T Cell    3691.176
# 8893  Lymphatic Endothelial (and some immune cells)    1753.956
# 8894                          Basal Epithelial Cell     970.104
# 8895                                         B Cell     462.144
#
#       cell_percentage  dataset_count
# 0            0.147653              3
# 1            0.144835              3
# 2            0.085651              3
# 3            0.084548              3
# 4            0.066168              3
# ...               ...            ...
# 8891         0.024702              1
# 8892         0.005951              1
# 8893         0.002828              1
# 8894         0.001564              1
# 8895         0.000745              1
#
# [8896 rows x 11 columns]

# %%
# subset to only keep male left kidney, renal pyramid, azimuth
df_renal_pyramid = df_as_pop[(df_as_pop['organ'] == 'Left kidney')& (df_as_pop['as_label'] == 'renal pyramid') & (df_as_pop['tool'] == 'azimuth') & (df_as_pop['sex']=='Male')]
df_renal_pyramid
# Out:
#             organ                                             as  \
# 6055  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6057  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6059  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6061  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6063  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6065  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6067  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6069  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6071  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6073  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6075  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6077  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6079  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6081  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6083  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6085  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6087  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6089  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6091  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6093  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6095  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6097  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6099  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6101  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6103  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6105  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6107  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6109  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6111  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6113  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6115  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6117  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6119  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6121  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6123  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6125  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6127  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6129  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6131  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6133  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6135  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6137  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6139  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6141  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6143  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6145  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6147  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
#
#            as_label   sex     tool            modality  \
# 6055  renal pyramid  Male  azimuth  sc_transcriptomics
# 6057  renal pyramid  Male  azimuth  sc_transcriptomics
# 6059  renal pyramid  Male  azimuth  sc_transcriptomics
# 6061  renal pyramid  Male  azimuth  sc_transcriptomics
# 6063  renal pyramid  Male  azimuth  sc_transcriptomics
# 6065  renal pyramid  Male  azimuth  sc_transcriptomics
# 6067  renal pyramid  Male  azimuth  sc_transcriptomics
# 6069  renal pyramid  Male  azimuth  sc_transcriptomics
# 6071  renal pyramid  Male  azimuth  sc_transcriptomics
# 6073  renal pyramid  Male  azimuth  sc_transcriptomics
# 6075  renal pyramid  Male  azimuth  sc_transcriptomics
# 6077  renal pyramid  Male  azimuth  sc_transcriptomics
# 6079  renal pyramid  Male  azimuth  sc_transcriptomics
# 6081  renal pyramid  Male  azimuth  sc_transcriptomics
# 6083  renal pyramid  Male  azimuth  sc_transcriptomics
# 6085  renal pyramid  Male  azimuth  sc_transcriptomics
# 6087  renal pyramid  Male  azimuth  sc_transcriptomics
# 6089  renal pyramid  Male  azimuth  sc_transcriptomics
# 6091  renal pyramid  Male  azimuth  sc_transcriptomics
# 6093  renal pyramid  Male  azimuth  sc_transcriptomics
# 6095  renal pyramid  Male  azimuth  sc_transcriptomics
# 6097  renal pyramid  Male  azimuth  sc_transcriptomics
# 6099  renal pyramid  Male  azimuth  sc_transcriptomics
# 6101  renal pyramid  Male  azimuth  sc_transcriptomics
# 6103  renal pyramid  Male  azimuth  sc_transcriptomics
# 6105  renal pyramid  Male  azimuth  sc_transcriptomics
# 6107  renal pyramid  Male  azimuth  sc_transcriptomics
# 6109  renal pyramid  Male  azimuth  sc_transcriptomics
# 6111  renal pyramid  Male  azimuth  sc_transcriptomics
# 6113  renal pyramid  Male  azimuth  sc_transcriptomics
# 6115  renal pyramid  Male  azimuth  sc_transcriptomics
# 6117  renal pyramid  Male  azimuth  sc_transcriptomics
# 6119  renal pyramid  Male  azimuth  sc_transcriptomics
# 6121  renal pyramid  Male  azimuth  sc_transcriptomics
# 6123  renal pyramid  Male  azimuth  sc_transcriptomics
# 6125  renal pyramid  Male  azimuth  sc_transcriptomics
# 6127  renal pyramid  Male  azimuth  sc_transcriptomics
# 6129  renal pyramid  Male  azimuth  sc_transcriptomics
# 6131  renal pyramid  Male  azimuth  sc_transcriptomics
# 6133  renal pyramid  Male  azimuth  sc_transcriptomics
# 6135  renal pyramid  Male  azimuth  sc_transcriptomics
# 6137  renal pyramid  Male  azimuth  sc_transcriptomics
# 6139  renal pyramid  Male  azimuth  sc_transcriptomics
# 6141  renal pyramid  Male  azimuth  sc_transcriptomics
# 6143  renal pyramid  Male  azimuth  sc_transcriptomics
# 6145  renal pyramid  Male  azimuth  sc_transcriptomics
# 6147  renal pyramid  Male  azimuth  sc_transcriptomics
#
#                                                 cell_id  \
# 6055          http://purl.obolibrary.org/obo/CL_1001109
# 6057          http://purl.obolibrary.org/obo/CL_4030012
# 6059          http://purl.obolibrary.org/obo/CL_1000714
# 6061          http://purl.obolibrary.org/obo/CL_1001108
# 6063          http://purl.obolibrary.org/obo/CL_1000768
# 6065          http://purl.obolibrary.org/obo/CL_1001107
# 6067          http://purl.obolibrary.org/obo/CL_4030022
# 6069          http://purl.obolibrary.org/obo/CL_4030016
# 6071  https://purl.org/ccf/ASCTB-TEMP_descending-vas...
# 6073          http://purl.obolibrary.org/obo/CL_1000718
# 6075          http://purl.obolibrary.org/obo/CL_4030014
# 6077          http://purl.obolibrary.org/obo/CL_1000692
# 6079          http://purl.obolibrary.org/obo/CL_0002201
# 6081          http://purl.obolibrary.org/obo/CL_1000850
# 6083          http://purl.obolibrary.org/obo/CL_1001131
# 6085          http://purl.obolibrary.org/obo/CL_4030013
# 6087          http://purl.obolibrary.org/obo/CL_1000716
# 6089          http://purl.obolibrary.org/obo/CL_1001318
# 6091          http://purl.obolibrary.org/obo/CL_1000717
# 6093          http://purl.obolibrary.org/obo/CL_0011031
# 6095  https://purl.org/ccf/ASCTB-TEMP_peritubular-ca...
# 6097          http://purl.obolibrary.org/obo/CL_0000084
# 6099          http://purl.obolibrary.org/obo/CL_4030009
# 6101          http://purl.obolibrary.org/obo/CL_1000452
# 6103          http://purl.obolibrary.org/obo/CL_4030018
# 6105          http://purl.obolibrary.org/obo/CL_0000890
# 6107          http://purl.obolibrary.org/obo/CL_1000715
# 6109          http://purl.obolibrary.org/obo/CL_1001005
# 6111          http://purl.obolibrary.org/obo/CL_1000597
# 6113          http://purl.obolibrary.org/obo/CL_0000653
# 6115          http://purl.obolibrary.org/obo/CL_4030011
# 6117          http://purl.obolibrary.org/obo/CL_1000412
# 6119          http://purl.obolibrary.org/obo/CL_0000650
# 6121          http://purl.obolibrary.org/obo/CL_0000990
# 6123          http://purl.obolibrary.org/obo/CL_0000236
# 6125          http://purl.obolibrary.org/obo/CL_4030010
# 6127          http://purl.obolibrary.org/obo/CL_4030017
# 6129          http://purl.obolibrary.org/obo/CL_0000648
# 6131          http://purl.obolibrary.org/obo/CL_0002138
# 6133          http://purl.obolibrary.org/obo/CL_0000097
# 6135          http://purl.obolibrary.org/obo/CL_0000814
# 6137          http://purl.obolibrary.org/obo/CL_0002573
# 6139          http://purl.obolibrary.org/obo/CL_0000786
# 6141          http://purl.obolibrary.org/obo/CL_0000775
# 6143          http://purl.obolibrary.org/obo/CL_4030020
# 6145          http://purl.obolibrary.org/obo/CL_0000875
# 6147          http://purl.obolibrary.org/obo/CL_4033078
#
#                                              cell_label  cell_count  \
# 6055                      Cortical Thick Ascending Limb  105493.791
# 6057                        Descending Thin Limb Type 1   48210.290
# 6059                 Cortical Collecting Duct Principal   47365.703
# 6061                     Medullary Thick Ascending Limb   37587.100
# 6063                                  Connecting Tubule   36564.115
# 6065                                Ascending Thin Limb   28549.937
# 6067                               Medullary Fibroblast   28149.594
# 6069                    Distal Convoluted Tubule Type 1   21950.691
# 6071                 Descending Vasa Recta Endothelial    19436.637
# 6073                    Inner Medullary Collecting Duct   13973.404
# 6075                        Descending Thin Limb Type 3    9374.074
# 6077                                         Fibroblast    7688.019
# 6079                                Intercalated Type B    6841.483
# 6081                                       Macula Densa    6573.065
# 6083                   Ascending Vasa Recta Endothelial    6114.286
# 6085                        Descending Thin Limb Type 2    6053.296
# 6087          Outer Medullary Collecting Duct Principal    3460.530
# 6089                  Vascular Smooth Muscle / Pericyte    3008.679
# 6091  Outer Medullary Collecting Duct Intercalated T...    2971.651
# 6093                                   Monocyte-derived    2951.421
# 6095                  Peritubular Capilary Endothelial     2368.401
# 6097                                                  T    2249.235
# 6099               Proximal Tubule Epithelial Segment 1    2203.518
# 6101                                Parietal Epithelial    2146.141
# 6103                        Connecting Tubule Principal    1745.379
# 6105                                      M2 Macrophage    1463.011
# 6107       Cortical Collecting Duct Intercalated Type A    1426.233
# 6109                   Glomerular Capillary Endothelial    1368.161
# 6111                           Papillary Tip Epithelial    1084.013
# 6113                                           Podocyte    1047.483
# 6115               Proximal Tubule Epithelial Segment 3     636.392
# 6117          Afferent / Efferent Arteriole Endothelial     468.172
# 6119                                          Mesangial     432.708
# 6121                                Classical Dendritic     358.000
# 6123                                                  B     152.012
# 6125               Proximal Tubule Epithelial Segment 2     114.691
# 6127                    Distal Convoluted Tubule Type 2      38.735
# 6129            Renin-positive Juxtaglomerular Granular      38.547
# 6131                              Lymphatic Endothelial      34.004
# 6133                                               Mast      34.000
# 6135                                   Natural Killer T      14.589
# 6137                                   Schwann / Neural      13.858
# 6139                                             Plasma       6.012
# 6141                                         Neutrophil       6.000
# 6143              Connecting Tubule Intercalated Type A       5.000
# 6145                             Non-classical monocyte       4.027
# 6147                      Cycling Mononuclear Phagocyte       4.000
#
#       cell_percentage  dataset_count
# 6055         0.228450             31
# 6057         0.104401             31
# 6059         0.102572             31
# 6061         0.081396             31
# 6063         0.079181             31
# 6065         0.061826             31
# 6067         0.060959             31
# 6069         0.047535             31
# 6071         0.042091             31
# 6073         0.030260             31
# 6075         0.020300             31
# 6077         0.016649             31
# 6079         0.014815             31
# 6081         0.014234             31
# 6083         0.013241             31
# 6085         0.013109             31
# 6087         0.007494             31
# 6089         0.006515             31
# 6091         0.006435             31
# 6093         0.006391             31
# 6095         0.005129             31
# 6097         0.004871             31
# 6099         0.004772             31
# 6101         0.004648             31
# 6103         0.003780             31
# 6105         0.003168             31
# 6107         0.003089             31
# 6109         0.002963             31
# 6111         0.002347             31
# 6113         0.002268             31
# 6115         0.001378             31
# 6117         0.001014             31
# 6119         0.000937             31
# 6121         0.000775             31
# 6123         0.000329             31
# 6125         0.000248             31
# 6127         0.000084             31
# 6129         0.000083             31
# 6131         0.000074             31
# 6133         0.000074             31
# 6135         0.000032             31
# 6137         0.000030             31
# 6139         0.000013             31
# 6141         0.000013             31
# 6143         0.000011             31
# 6145         0.000009             31
# 6147         0.000009             31

# %%
# filter out cells below threshold such that only n_max CTs remain
n_max = 10

top10 = df_renal_pyramid.nlargest(n_max, "cell_percentage")
top10
# Out:
#             organ                                             as  \
# 6055  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6057  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6059  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6061  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6063  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6065  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6067  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6069  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6071  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
# 6073  Left kidney  http://purl.obolibrary.org/obo/UBERON_0004200
#
#            as_label   sex     tool            modality  \
# 6055  renal pyramid  Male  azimuth  sc_transcriptomics
# 6057  renal pyramid  Male  azimuth  sc_transcriptomics
# 6059  renal pyramid  Male  azimuth  sc_transcriptomics
# 6061  renal pyramid  Male  azimuth  sc_transcriptomics
# 6063  renal pyramid  Male  azimuth  sc_transcriptomics
# 6065  renal pyramid  Male  azimuth  sc_transcriptomics
# 6067  renal pyramid  Male  azimuth  sc_transcriptomics
# 6069  renal pyramid  Male  azimuth  sc_transcriptomics
# 6071  renal pyramid  Male  azimuth  sc_transcriptomics
# 6073  renal pyramid  Male  azimuth  sc_transcriptomics
#
#                                                 cell_id  \
# 6055          http://purl.obolibrary.org/obo/CL_1001109
# 6057          http://purl.obolibrary.org/obo/CL_4030012
# 6059          http://purl.obolibrary.org/obo/CL_1000714
# 6061          http://purl.obolibrary.org/obo/CL_1001108
# 6063          http://purl.obolibrary.org/obo/CL_1000768
# 6065          http://purl.obolibrary.org/obo/CL_1001107
# 6067          http://purl.obolibrary.org/obo/CL_4030022
# 6069          http://purl.obolibrary.org/obo/CL_4030016
# 6071  https://purl.org/ccf/ASCTB-TEMP_descending-vas...
# 6073          http://purl.obolibrary.org/obo/CL_1000718
#
#                               cell_label  cell_count  cell_percentage  \
# 6055       Cortical Thick Ascending Limb  105493.791         0.228450
# 6057         Descending Thin Limb Type 1   48210.290         0.104401
# 6059  Cortical Collecting Duct Principal   47365.703         0.102572
# 6061      Medullary Thick Ascending Limb   37587.100         0.081396
# 6063                   Connecting Tubule   36564.115         0.079181
# 6065                 Ascending Thin Limb   28549.937         0.061826
# 6067                Medullary Fibroblast   28149.594         0.060959
# 6069     Distal Convoluted Tubule Type 1   21950.691         0.047535
# 6071  Descending Vasa Recta Endothelial    19436.637         0.042091
# 6073     Inner Medullary Collecting Duct   13973.404         0.030260
#
#       dataset_count
# 6055             31
# 6057             31
# 6059             31
# 6061             31
# 6063             31
# 6065             31
# 6067             31
# 6069             31
# 6071             31
# 6073             31

# %%
# transform into dict so it can be used in the payload for the API request

# %%
node_distribution = dict(zip(top10['cell_label'], top10['cell_percentage']))
pprint(node_distribution)
# Out:
# {'Ascending Thin Limb': 0.06182582952775565,
#  'Connecting Tubule': 0.07918079611955897,
#  'Cortical Collecting Duct Principal': 0.1025719909343514,
#  'Cortical Thick Ascending Limb': 0.2284502812949354,
#  'Descending Thin Limb Type 1': 0.1044009719189105,
#  'Descending Vasa Recta Endothelial ': 0.04209067801988033,
#  'Distal Convoluted Tubule Type 1': 0.04753494481555039,
#  'Inner Medullary Collecting Duct': 0.03025986690010765,
#  'Medullary Fibroblast': 0.06095887356667489,
#  'Medullary Thick Ascending Limb': 0.08139610385279325}

# %%
def call_3d_cell_api(file: str, scene_node: str, num_nodes: int, node_distribution: dict):
  """Wrapper function to make a call to the 3D Cell Generation API using a payload constructed with user-provided arguments

  Args:
      file (str): the link to the GLB file of the organ, see, e.g., https://apps.humanatlas.io/api#get-/v1/reference-organs
      scene_node (str): the scene node of the AS
      num_nodes (int): the max. total number of cells
      node_distribution (dict): a dict with key-value-pairs for cell label and percentages [0,1]
  """

  url = 'https://apps.humanatlas.io/api/v1/mesh-3d-cell-population'

  payload = {
      'file': file,
      'file_subpath': scene_node,
      'num_nodes': num_nodes,
      'node_distribution': node_distribution
  }

  headers = {
      'Content-Type': 'application/json'
  }

  try:
      response = requests.post(url, data=json.dumps(payload), headers=headers)
      response.raise_for_status()  # Raise an exception for HTTP errors (4xx or 5xx)
      return pd.read_csv(StringIO(response.text))
      print("Response Status Code:", response.status_code)
      print("Response JSON:", response.json())
  except requests.exceptions.RequestException as e:
      print(f"An error occurred: {e}")
      return None

# %%
# make request
result = call_3d_cell_api(
    file='https://cdn.humanatlas.io/digital-objects/ref-organ/kidney-male-left/v1.3/assets/3d-vh-m-kidney-l.glb',
    scene_node='VH_M_renal_pyramid_L_a',
    num_nodes=10000,
    node_distribution=node_distribution
)
result
# Out:
#              x         y         z                        Cell Type
# 0     0.058991  0.336645 -0.029124    Cortical Thick Ascending Limb
# 1     0.055172  0.333326 -0.027373    Cortical Thick Ascending Limb
# 2     0.055596  0.336089 -0.052402    Cortical Thick Ascending Limb
# 3     0.056092  0.325558 -0.047792    Cortical Thick Ascending Limb
# 4     0.054386  0.337223 -0.041805    Cortical Thick Ascending Limb
# ...        ...       ...       ...                              ...
# 8376  0.056225  0.331677 -0.041928  Inner Medullary Collecting Duct
# 8377  0.050889  0.343998 -0.043516  Inner Medullary Collecting Duct
# 8378  0.053685  0.337658 -0.039319  Inner Medullary Collecting Duct
# 8379  0.059127  0.335035 -0.047576  Inner Medullary Collecting Duct
# 8380  0.050304  0.338768 -0.031614  Inner Medullary Collecting Duct
#
# [8381 rows x 4 columns]

# %%
# Next, let's define a function that turns a DataFrame into a node list that can then be passed into the CdeVisualization or NodeDistVis widget
def make_node_list(df: pd.DataFrame, is_3d: bool = False):
  """Turn a DataFrame into a list of dicts for passing them into a HRA widget

  Args:
      df (pd.DataFrame): A DataFrame with cells
  """

  # If the df does not have a z-axis column, let's add one and set all cells to 0
  if not is_3d:
    df.loc[:, ('z')] = 0

  node_list = [{'x': row['x'], 'y': row['y'], 'z': row['z'], 'Cell Type': row['Cell Type']}
               for index, row in df.iterrows()]

  return node_list

# %%
node_list = make_node_list(result, True)
node_list
# Out:
# [{'x': 0.0589906,
#   'y': 0.336645,
#   'z': -0.0291241,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0551724,
#   'y': 0.333326,
#   'z': -0.0273735,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0555962,
#   'y': 0.336089,
#   'z': -0.0524018,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.056092,
#   'y': 0.325558,
#   'z': -0.0477916,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.054386,
#   'y': 0.337223,
#   'z': -0.0418046,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0589853,
#   'y': 0.335186,
#   'z': -0.0263734,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.047198,
#   'y': 0.328695,
#   'z': -0.0248323,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0580173,
#   'y': 0.331988,
#   'z': -0.0276687,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0504401,
#   'y': 0.342054,
#   'z': -0.0393548,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0558481,
#   'y': 0.337205,
#   'z': -0.0337074,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0563917,
#   'y': 0.340236,
#   'z': -0.0366124,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0568666,
#   'y': 0.331619,
#   'z': -0.0454603,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0520265,
#   'y': 0.319907,
#   'z': -0.0337371,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0560263,
#   'y': 0.337328,
#   'z': -0.0523881,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0589323,
#   'y': 0.328658,
#   'z': -0.0232276,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0540336,
#   'y': 0.330729,
#   'z': -0.0465281,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0577817,
#   'y': 0.331127,
#   'z': -0.0444665,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0573467,
#   'y': 0.328657,
#   'z': -0.0320319,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0574937,
#   'y': 0.335503,
#   'z': -0.0328217,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0562768,
#   'y': 0.334375,
#   'z': -0.0427628,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.056159,
#   'y': 0.341536,
#   'z': -0.0492674,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0587442,
#   'y': 0.32999,
#   'z': -0.0391772,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0608027,
#   'y': 0.330595,
#   'z': -0.0458967,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0538392,
#   'y': 0.332705,
#   'z': -0.0250145,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0519002,
#   'y': 0.332936,
#   'z': -0.0397678,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0501935,
#   'y': 0.327088,
#   'z': -0.0384645,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.05361,
#   'y': 0.33582,
#   'z': -0.0405684,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0497608,
#   'y': 0.325062,
#   'z': -0.0239765,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0507938,
#   'y': 0.332405,
#   'z': -0.0290945,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0566841,
#   'y': 0.335351,
#   'z': -0.0515817,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0438318,
#   'y': 0.32873,
#   'z': -0.0262759,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0533999,
#   'y': 0.329812,
#   'z': -0.0476335,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0552399,
#   'y': 0.335007,
#   'z': -0.0282865,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.056848,
#   'y': 0.328384,
#   'z': -0.0231594,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0563327,
#   'y': 0.342849,
#   'z': -0.0529546,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.05023,
#   'y': 0.318627,
#   'z': -0.0311115,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0500093,
#   'y': 0.331819,
#   'z': -0.0311509,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0620198,
#   'y': 0.335111,
#   'z': -0.0438748,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0563332,
#   'y': 0.334344,
#   'z': -0.0253151,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0617425,
#   'y': 0.344775,
#   'z': -0.0542897,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.054375,
#   'y': 0.337131,
#   'z': -0.0364221,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0516076,
#   'y': 0.335523,
#   'z': -0.0298256,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0544459,
#   'y': 0.33165,
#   'z': -0.0335846,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0568116,
#   'y': 0.326391,
#   'z': -0.0334408,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.058499,
#   'y': 0.327634,
#   'z': -0.0437834,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0573369,
#   'y': 0.337582,
#   'z': -0.0456589,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.056957,
#   'y': 0.324991,
#   'z': -0.0434083,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0489863,
#   'y': 0.33807,
#   'z': -0.0399519,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0565045,
#   'y': 0.332132,
#   'z': -0.0220023,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0584483,
#   'y': 0.330995,
#   'z': -0.0280875,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0493755,
#   'y': 0.325912,
#   'z': -0.0283054,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.061137,
#   'y': 0.334143,
#   'z': -0.0436655,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0554708,
#   'y': 0.331284,
#   'z': -0.028859,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0613521,
#   'y': 0.336944,
#   'z': -0.0393595,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0503723,
#   'y': 0.336991,
#   'z': -0.0380405,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0569182,
#   'y': 0.336231,
#   'z': -0.0363484,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0532151,
#   'y': 0.326936,
#   'z': -0.0373769,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0537525,
#   'y': 0.338027,
#   'z': -0.042631,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0607441,
#   'y': 0.344294,
#   'z': -0.0557172,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0545554,
#   'y': 0.339398,
#   'z': -0.0354762,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0453461,
#   'y': 0.332612,
#   'z': -0.0330476,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0569414,
#   'y': 0.328074,
#   'z': -0.0466097,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0591743,
#   'y': 0.328882,
#   'z': -0.021848,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.04692,
#   'y': 0.328551,
#   'z': -0.0286769,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0569485,
#   'y': 0.333711,
#   'z': -0.0464587,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0465593,
#   'y': 0.334234,
#   'z': -0.0325772,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0553264,
#   'y': 0.340417,
#   'z': -0.0355582,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0596312,
#   'y': 0.327696,
#   'z': -0.0345002,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0516598,
#   'y': 0.321659,
#   'z': -0.0324711,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0614667,
#   'y': 0.332576,
#   'z': -0.0292201,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0529775,
#   'y': 0.334504,
#   'z': -0.0312715,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0608738,
#   'y': 0.332729,
#   'z': -0.0360104,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0603639,
#   'y': 0.332472,
#   'z': -0.0304232,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0583843,
#   'y': 0.338241,
#   'z': -0.0468962,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.050378,
#   'y': 0.318069,
#   'z': -0.0321491,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0598809,
#   'y': 0.330184,
#   'z': -0.0269148,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0609138,
#   'y': 0.333974,
#   'z': -0.0361085,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0597141,
#   'y': 0.340818,
#   'z': -0.054087,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0552012,
#   'y': 0.332215,
#   'z': -0.0380163,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0505722,
#   'y': 0.338864,
#   'z': -0.0345096,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0472225,
#   'y': 0.329088,
#   'z': -0.0202434,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0599343,
#   'y': 0.342896,
#   'z': -0.0537884,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0606975,
#   'y': 0.334325,
#   'z': -0.0263194,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0608788,
#   'y': 0.33934,
#   'z': -0.0534486,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0536843,
#   'y': 0.329048,
#   'z': -0.0494939,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0561605,
#   'y': 0.330416,
#   'z': -0.0511908,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0602534,
#   'y': 0.338206,
#   'z': -0.0370024,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0555695,
#   'y': 0.334597,
#   'z': -0.0319619,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0565064,
#   'y': 0.340573,
#   'z': -0.0379942,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0581735,
#   'y': 0.330803,
#   'z': -0.0317252,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0499177,
#   'y': 0.319532,
#   'z': -0.0302231,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0452987,
#   'y': 0.336706,
#   'z': -0.0300654,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0577648,
#   'y': 0.344082,
#   'z': -0.0523583,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0536821,
#   'y': 0.335234,
#   'z': -0.0338936,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0511605,
#   'y': 0.323248,
#   'z': -0.0328568,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0508128,
#   'y': 0.330423,
#   'z': -0.0262262,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0561909,
#   'y': 0.334297,
#   'z': -0.0327209,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0576612,
#   'y': 0.339523,
#   'z': -0.052195,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0524098,
#   'y': 0.339437,
#   'z': -0.0372634,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0612309,
#   'y': 0.333154,
#   'z': -0.030247,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0544624,
#   'y': 0.333484,
#   'z': -0.0440513,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0600283,
#   'y': 0.328079,
#   'z': -0.0468012,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0470569,
#   'y': 0.324346,
#   'z': -0.0227293,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0458904,
#   'y': 0.336297,
#   'z': -0.0329252,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0536064,
#   'y': 0.346097,
#   'z': -0.0441734,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.058077,
#   'y': 0.329899,
#   'z': -0.031957,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0599464,
#   'y': 0.3276,
#   'z': -0.0252668,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0455467,
#   'y': 0.328654,
#   'z': -0.0270497,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0451302,
#   'y': 0.333715,
#   'z': -0.0326059,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0513589,
#   'y': 0.336049,
#   'z': -0.0311262,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0531265,
#   'y': 0.320212,
#   'z': -0.0312128,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0608848,
#   'y': 0.330931,
#   'z': -0.0386281,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0570495,
#   'y': 0.343351,
#   'z': -0.0514463,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0609918,
#   'y': 0.329221,
#   'z': -0.0259176,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0537811,
#   'y': 0.329636,
#   'z': -0.0297673,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0600082,
#   'y': 0.342509,
#   'z': -0.0504866,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0580226,
#   'y': 0.331917,
#   'z': -0.0240809,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0593013,
#   'y': 0.34548,
#   'z': -0.0460209,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0559652,
#   'y': 0.329756,
#   'z': -0.0479965,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0555428,
#   'y': 0.326909,
#   'z': -0.0352831,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0497427,
#   'y': 0.329948,
#   'z': -0.0228706,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0568061,
#   'y': 0.340773,
#   'z': -0.0383349,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0514443,
#   'y': 0.333733,
#   'z': -0.035768,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0558411,
#   'y': 0.334965,
#   'z': -0.0453118,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0468485,
#   'y': 0.331146,
#   'z': -0.0225302,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0541502,
#   'y': 0.332637,
#   'z': -0.036592,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.045123,
#   'y': 0.332012,
#   'z': -0.0237159,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.058232,
#   'y': 0.33853,
#   'z': -0.0388858,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0596672,
#   'y': 0.337901,
#   'z': -0.0369781,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0535629,
#   'y': 0.325244,
#   'z': -0.0322651,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.048122,
#   'y': 0.326,
#   'z': -0.0319014,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0536225,
#   'y': 0.328073,
#   'z': -0.0339198,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0494489,
#   'y': 0.324543,
#   'z': -0.0365539,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0489584,
#   'y': 0.33321,
#   'z': -0.0269104,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0497162,
#   'y': 0.333228,
#   'z': -0.0278598,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0619979,
#   'y': 0.345523,
#   'z': -0.0542959,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0602412,
#   'y': 0.342299,
#   'z': -0.0407609,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0455252,
#   'y': 0.32958,
#   'z': -0.026441,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0529727,
#   'y': 0.341452,
#   'z': -0.0432971,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0591207,
#   'y': 0.334784,
#   'z': -0.0491926,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0445108,
#   'y': 0.334393,
#   'z': -0.0351741,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0462142,
#   'y': 0.334545,
#   'z': -0.0332723,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0548992,
#   'y': 0.334247,
#   'z': -0.0478801,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0511516,
#   'y': 0.327049,
#   'z': -0.0352458,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0552423,
#   'y': 0.343122,
#   'z': -0.0504529,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0614469,
#   'y': 0.331147,
#   'z': -0.0406412,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0610679,
#   'y': 0.341801,
#   'z': -0.0533252,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0581287,
#   'y': 0.345008,
#   'z': -0.05182,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0504396,
#   'y': 0.33458,
#   'z': -0.0375017,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0549788,
#   'y': 0.323472,
#   'z': -0.03313,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0531157,
#   'y': 0.344423,
#   'z': -0.045469,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0553916,
#   'y': 0.335286,
#   'z': -0.0495642,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0550801,
#   'y': 0.333761,
#   'z': -0.0364329,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0540124,
#   'y': 0.338682,
#   'z': -0.0520135,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0541762,
#   'y': 0.332521,
#   'z': -0.0443284,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.056284,
#   'y': 0.32452,
#   'z': -0.0476204,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0537865,
#   'y': 0.327076,
#   'z': -0.0477625,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.047938,
#   'y': 0.334082,
#   'z': -0.040728,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0456905,
#   'y': 0.330754,
#   'z': -0.0328694,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0525719,
#   'y': 0.334999,
#   'z': -0.0341969,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0511922,
#   'y': 0.329505,
#   'z': -0.0249194,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0507503,
#   'y': 0.323016,
#   'z': -0.0325564,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0588849,
#   'y': 0.336089,
#   'z': -0.0319042,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0547222,
#   'y': 0.343824,
#   'z': -0.0415043,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0478971,
#   'y': 0.333522,
#   'z': -0.0278412,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0560262,
#   'y': 0.335845,
#   'z': -0.0360138,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0521451,
#   'y': 0.329942,
#   'z': -0.0346444,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0526455,
#   'y': 0.3378,
#   'z': -0.047092,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0590685,
#   'y': 0.336337,
#   'z': -0.0397259,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0433935,
#   'y': 0.33888,
#   'z': -0.0312229,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0602831,
#   'y': 0.332021,
#   'z': -0.0359414,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0460302,
#   'y': 0.331528,
#   'z': -0.0378063,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0480039,
#   'y': 0.330644,
#   'z': -0.0259677,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0493238,
#   'y': 0.323626,
#   'z': -0.0255518,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0451371,
#   'y': 0.334296,
#   'z': -0.0320755,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0531029,
#   'y': 0.330991,
#   'z': -0.0302375,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.057123,
#   'y': 0.330112,
#   'z': -0.0511144,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0534427,
#   'y': 0.335985,
#   'z': -0.0285464,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0499523,
#   'y': 0.338181,
#   'z': -0.0317727,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0587034,
#   'y': 0.332269,
#   'z': -0.0341547,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0528451,
#   'y': 0.326164,
#   'z': -0.0314076,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0538297,
#   'y': 0.333364,
#   'z': -0.0328393,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0462121,
#   'y': 0.332885,
#   'z': -0.0263226,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0454014,
#   'y': 0.331189,
#   'z': -0.0307565,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.058157,
#   'y': 0.337436,
#   'z': -0.0419954,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.046691,
#   'y': 0.334817,
#   'z': -0.0303895,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0610385,
#   'y': 0.343904,
#   'z': -0.0522636,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0501492,
#   'y': 0.328248,
#   'z': -0.0284026,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0588598,
#   'y': 0.344009,
#   'z': -0.0521747,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0546085,
#   'y': 0.334993,
#   'z': -0.0344987,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0551109,
#   'y': 0.335729,
#   'z': -0.051089,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0430847,
#   'y': 0.335964,
#   'z': -0.0304526,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0558548,
#   'y': 0.339947,
#   'z': -0.0490656,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0565676,
#   'y': 0.328408,
#   'z': -0.0491878,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0575889,
#   'y': 0.332449,
#   'z': -0.0337953,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0594655,
#   'y': 0.327273,
#   'z': -0.0390601,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0453454,
#   'y': 0.330599,
#   'z': -0.026795,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0478279,
#   'y': 0.330081,
#   'z': -0.0311715,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.053746,
#   'y': 0.338788,
#   'z': -0.0523311,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0462537,
#   'y': 0.331741,
#   'z': -0.0380121,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0579215,
#   'y': 0.328202,
#   'z': -0.0391008,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0608029,
#   'y': 0.330686,
#   'z': -0.0244144,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0605407,
#   'y': 0.333712,
#   'z': -0.0380328,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0595062,
#   'y': 0.327951,
#   'z': -0.04543,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0527122,
#   'y': 0.329935,
#   'z': -0.0272133,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0554779,
#   'y': 0.339558,
#   'z': -0.0482334,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0483651,
#   'y': 0.336687,
#   'z': -0.0419674,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0572735,
#   'y': 0.329098,
#   'z': -0.0331927,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0502229,
#   'y': 0.324737,
#   'z': -0.0343046,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.056796,
#   'y': 0.346259,
#   'z': -0.0444826,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0548139,
#   'y': 0.335318,
#   'z': -0.0289241,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0568543,
#   'y': 0.332396,
#   'z': -0.046802,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0527946,
#   'y': 0.339186,
#   'z': -0.042217,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0468135,
#   'y': 0.32939,
#   'z': -0.0253598,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0545916,
#   'y': 0.344314,
#   'z': -0.0516598,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0593682,
#   'y': 0.328121,
#   'z': -0.0378345,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0417487,
#   'y': 0.334308,
#   'z': -0.028799,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0559144,
#   'y': 0.333645,
#   'z': -0.0354654,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0618189,
#   'y': 0.329857,
#   'z': -0.0401333,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0508723,
#   'y': 0.321327,
#   'z': -0.032327,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0496622,
#   'y': 0.324281,
#   'z': -0.0355612,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0602728,
#   'y': 0.328649,
#   'z': -0.044386,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0451811,
#   'y': 0.328369,
#   'z': -0.0279397,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0561529,
#   'y': 0.335982,
#   'z': -0.0392996,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0588834,
#   'y': 0.336236,
#   'z': -0.0470639,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0606993,
#   'y': 0.330314,
#   'z': -0.0311291,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0483359,
#   'y': 0.324214,
#   'z': -0.0218047,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0529315,
#   'y': 0.32402,
#   'z': -0.0373501,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0571228,
#   'y': 0.338394,
#   'z': -0.0348755,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0500359,
#   'y': 0.344795,
#   'z': -0.0399761,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0536025,
#   'y': 0.32456,
#   'z': -0.0381052,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0506077,
#   'y': 0.315257,
#   'z': -0.0306799,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0524787,
#   'y': 0.332587,
#   'z': -0.0349472,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0510335,
#   'y': 0.334917,
#   'z': -0.0288388,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0527698,
#   'y': 0.330464,
#   'z': -0.032425,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0433508,
#   'y': 0.332422,
#   'z': -0.0252811,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0509343,
#   'y': 0.329477,
#   'z': -0.0270125,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0610835,
#   'y': 0.336513,
#   'z': -0.0507922,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0593569,
#   'y': 0.3316,
#   'z': -0.0237179,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0461705,
#   'y': 0.333656,
#   'z': -0.0378603,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0563622,
#   'y': 0.340136,
#   'z': -0.0536661,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0553953,
#   'y': 0.341717,
#   'z': -0.0530808,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0532021,
#   'y': 0.333959,
#   'z': -0.0313695,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0563061,
#   'y': 0.334285,
#   'z': -0.0443492,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0593021,
#   'y': 0.337139,
#   'z': -0.0402671,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0528482,
#   'y': 0.337554,
#   'z': -0.040022,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0537571,
#   'y': 0.340172,
#   'z': -0.0363743,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0598942,
#   'y': 0.340542,
#   'z': -0.0387721,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0496035,
#   'y': 0.336882,
#   'z': -0.0401473,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0510734,
#   'y': 0.343271,
#   'z': -0.0382249,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0529841,
#   'y': 0.345694,
#   'z': -0.0448481,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0510669,
#   'y': 0.329674,
#   'z': -0.0247758,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.057656,
#   'y': 0.344388,
#   'z': -0.0458489,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0537145,
#   'y': 0.335152,
#   'z': -0.0364643,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0537955,
#   'y': 0.332377,
#   'z': -0.0279033,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0560207,
#   'y': 0.339773,
#   'z': -0.0440578,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0510041,
#   'y': 0.327565,
#   'z': -0.0355372,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0487248,
#   'y': 0.334703,
#   'z': -0.0296618,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0523461,
#   'y': 0.324616,
#   'z': -0.0391751,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0525691,
#   'y': 0.339953,
#   'z': -0.0372478,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0554545,
#   'y': 0.338236,
#   'z': -0.0328327,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.057792,
#   'y': 0.334198,
#   'z': -0.0400836,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0591957,
#   'y': 0.328282,
#   'z': -0.0234044,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0579206,
#   'y': 0.333064,
#   'z': -0.0428894,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0540976,
#   'y': 0.344758,
#   'z': -0.0458445,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0548158,
#   'y': 0.341011,
#   'z': -0.0357223,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0524471,
#   'y': 0.3367,
#   'z': -0.0312371,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.056187,
#   'y': 0.331621,
#   'z': -0.0231403,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0472992,
#   'y': 0.325399,
#   'z': -0.027015,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0518652,
#   'y': 0.328807,
#   'z': -0.02591,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0525883,
#   'y': 0.324867,
#   'z': -0.0368353,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.052678,
#   'y': 0.325394,
#   'z': -0.0291896,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0534564,
#   'y': 0.335204,
#   'z': -0.0378398,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0475541,
#   'y': 0.330297,
#   'z': -0.0246706,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0428728,
#   'y': 0.334477,
#   'z': -0.0310391,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0471641,
#   'y': 0.334401,
#   'z': -0.0326709,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0595772,
#   'y': 0.343644,
#   'z': -0.0534364,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0512845,
#   'y': 0.337787,
#   'z': -0.0359898,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0472097,
#   'y': 0.336334,
#   'z': -0.0302375,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0627798,
#   'y': 0.329443,
#   'z': -0.0353251,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.058869,
#   'y': 0.329991,
#   'z': -0.0320953,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0498454,
#   'y': 0.335549,
#   'z': -0.03789,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0515107,
#   'y': 0.342783,
#   'z': -0.037449,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0511952,
#   'y': 0.32591,
#   'z': -0.0341534,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0617569,
#   'y': 0.334267,
#   'z': -0.0418373,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0489839,
#   'y': 0.331251,
#   'z': -0.0364226,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.048724,
#   'y': 0.32818,
#   'z': -0.0332667,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0506798,
#   'y': 0.342936,
#   'z': -0.0393654,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0422769,
#   'y': 0.331619,
#   'z': -0.0266328,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0550603,
#   'y': 0.339545,
#   'z': -0.0378695,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.053929,
#   'y': 0.343846,
#   'z': -0.0507147,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0588152,
#   'y': 0.335426,
#   'z': -0.04125,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.061686,
#   'y': 0.331143,
#   'z': -0.0288312,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0582835,
#   'y': 0.331273,
#   'z': -0.0219678,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.057436,
#   'y': 0.33704,
#   'z': -0.0340688,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0610841,
#   'y': 0.334995,
#   'z': -0.0383499,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0517554,
#   'y': 0.321192,
#   'z': -0.0318978,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.060578,
#   'y': 0.32659,
#   'z': -0.0371493,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0586347,
#   'y': 0.34201,
#   'z': -0.040911,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0433357,
#   'y': 0.336737,
#   'z': -0.0309346,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0581832,
#   'y': 0.328532,
#   'z': -0.0379406,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0531742,
#   'y': 0.337598,
#   'z': -0.0428533,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0591487,
#   'y': 0.335818,
#   'z': -0.0331343,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0581068,
#   'y': 0.338479,
#   'z': -0.0426027,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0577865,
#   'y': 0.330026,
#   'z': -0.0350722,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0530708,
#   'y': 0.337369,
#   'z': -0.0400831,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0608363,
#   'y': 0.331265,
#   'z': -0.0418954,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0614898,
#   'y': 0.333271,
#   'z': -0.0445786,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.053816,
#   'y': 0.330862,
#   'z': -0.0382599,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0546475,
#   'y': 0.334095,
#   'z': -0.0316368,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0502348,
#   'y': 0.325661,
#   'z': -0.0268411,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0525278,
#   'y': 0.341612,
#   'z': -0.0374997,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0586146,
#   'y': 0.335415,
#   'z': -0.0515353,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0512176,
#   'y': 0.323721,
#   'z': -0.0322145,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0525674,
#   'y': 0.341395,
#   'z': -0.0360813,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0595957,
#   'y': 0.334695,
#   'z': -0.0330493,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0433844,
#   'y': 0.331789,
#   'z': -0.0290187,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0504606,
#   'y': 0.316336,
#   'z': -0.0322143,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0564969,
#   'y': 0.339189,
#   'z': -0.0412541,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0534639,
#   'y': 0.329735,
#   'z': -0.0365632,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0477271,
#   'y': 0.334504,
#   'z': -0.0325906,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0491779,
#   'y': 0.333119,
#   'z': -0.0329972,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0510095,
#   'y': 0.330015,
#   'z': -0.0293739,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0515555,
#   'y': 0.333658,
#   'z': -0.0410262,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0524866,
#   'y': 0.329048,
#   'z': -0.0267432,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0563362,
#   'y': 0.33449,
#   'z': -0.052333,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.054729,
#   'y': 0.33496,
#   'z': -0.0443505,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0567549,
#   'y': 0.32733,
#   'z': -0.044668,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0596574,
#   'y': 0.340637,
#   'z': -0.0531918,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0528852,
#   'y': 0.326017,
#   'z': -0.0369625,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.05737,
#   'y': 0.332528,
#   'z': -0.0351141,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0541521,
#   'y': 0.325719,
#   'z': -0.0359889,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0503934,
#   'y': 0.336546,
#   'z': -0.0389362,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0557192,
#   'y': 0.337731,
#   'z': -0.0504733,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0557433,
#   'y': 0.329471,
#   'z': -0.0335518,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0525925,
#   'y': 0.335948,
#   'z': -0.0372518,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0439425,
#   'y': 0.3284,
#   'z': -0.0254886,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0607858,
#   'y': 0.329701,
#   'z': -0.0364099,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0497681,
#   'y': 0.342794,
#   'z': -0.0387433,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.059063,
#   'y': 0.333053,
#   'z': -0.036861,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.056144,
#   'y': 0.336506,
#   'z': -0.042748,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.056599,
#   'y': 0.326171,
#   'z': -0.0437229,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0463454,
#   'y': 0.331154,
#   'z': -0.0360802,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0518815,
#   'y': 0.317989,
#   'z': -0.031887,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.060389,
#   'y': 0.33891,
#   'z': -0.0522336,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0572281,
#   'y': 0.32818,
#   'z': -0.0347348,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0527867,
#   'y': 0.333134,
#   'z': -0.0286232,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0559033,
#   'y': 0.338696,
#   'z': -0.0342711,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0489372,
#   'y': 0.326273,
#   'z': -0.0252515,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0582386,
#   'y': 0.333721,
#   'z': -0.043299,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0538878,
#   'y': 0.325023,
#   'z': -0.0302803,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0528058,
#   'y': 0.332152,
#   'z': -0.0405006,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0462373,
#   'y': 0.332461,
#   'z': -0.0337093,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0578235,
#   'y': 0.333564,
#   'z': -0.032376,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0587546,
#   'y': 0.330606,
#   'z': -0.0449492,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0618459,
#   'y': 0.331107,
#   'z': -0.0264718,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0593694,
#   'y': 0.32792,
#   'z': -0.0479918,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0553143,
#   'y': 0.327015,
#   'z': -0.0463773,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0484645,
#   'y': 0.329096,
#   'z': -0.0308576,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0587367,
#   'y': 0.328497,
#   'z': -0.023604,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0561184,
#   'y': 0.336743,
#   'z': -0.0318369,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0546702,
#   'y': 0.333302,
#   'z': -0.03478,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0468337,
#   'y': 0.334864,
#   'z': -0.0278974,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0446063,
#   'y': 0.337885,
#   'z': -0.0299461,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0554646,
#   'y': 0.339268,
#   'z': -0.0366442,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0576342,
#   'y': 0.335006,
#   'z': -0.0261336,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0637397,
#   'y': 0.330346,
#   'z': -0.0378237,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0607465,
#   'y': 0.333653,
#   'z': -0.035946,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0614516,
#   'y': 0.332605,
#   'z': -0.0453713,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0453785,
#   'y': 0.331515,
#   'z': -0.0274424,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0503159,
#   'y': 0.331232,
#   'z': -0.0352888,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0463564,
#   'y': 0.333163,
#   'z': -0.0340424,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0503677,
#   'y': 0.324741,
#   'z': -0.0374519,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0461935,
#   'y': 0.328062,
#   'z': -0.0327084,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0586653,
#   'y': 0.334386,
#   'z': -0.0246849,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0507536,
#   'y': 0.343156,
#   'z': -0.0409194,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0508044,
#   'y': 0.321779,
#   'z': -0.0353759,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0587902,
#   'y': 0.327124,
#   'z': -0.0210639,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0564451,
#   'y': 0.327744,
#   'z': -0.033042,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0599225,
#   'y': 0.337581,
#   'z': -0.0468885,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0434472,
#   'y': 0.332644,
#   'z': -0.0299422,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0503334,
#   'y': 0.334883,
#   'z': -0.0328622,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0550838,
#   'y': 0.34275,
#   'z': -0.0495584,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.059738,
#   'y': 0.337334,
#   'z': -0.0352789,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0553384,
#   'y': 0.340359,
#   'z': -0.0521885,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0511475,
#   'y': 0.326946,
#   'z': -0.0252423,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0562929,
#   'y': 0.335708,
#   'z': -0.0484558,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0494772,
#   'y': 0.339051,
#   'z': -0.0376866,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0594807,
#   'y': 0.333588,
#   'z': -0.0499976,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.055115,
#   'y': 0.337358,
#   'z': -0.030098,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0603627,
#   'y': 0.331328,
#   'z': -0.027735,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0586771,
#   'y': 0.334967,
#   'z': -0.0345063,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0585768,
#   'y': 0.339715,
#   'z': -0.0502463,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0578384,
#   'y': 0.344774,
#   'z': -0.0529802,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0598717,
#   'y': 0.339684,
#   'z': -0.0486196,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0494134,
#   'y': 0.331771,
#   'z': -0.0372509,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0533816,
#   'y': 0.333759,
#   'z': -0.0250786,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0513529,
#   'y': 0.324444,
#   'z': -0.028838,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0545184,
#   'y': 0.32776,
#   'z': -0.0362504,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0585432,
#   'y': 0.333305,
#   'z': -0.0487552,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0528556,
#   'y': 0.319363,
#   'z': -0.0338649,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0521196,
#   'y': 0.325831,
#   'z': -0.035106,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0573677,
#   'y': 0.332917,
#   'z': -0.0385026,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0518226,
#   'y': 0.329815,
#   'z': -0.028656,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0535155,
#   'y': 0.34383,
#   'z': -0.0456059,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0546645,
#   'y': 0.326179,
#   'z': -0.0283272,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0546117,
#   'y': 0.341763,
#   'z': -0.0394223,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0599833,
#   'y': 0.334025,
#   'z': -0.0282802,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0481649,
#   'y': 0.334882,
#   'z': -0.0335997,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.045255,
#   'y': 0.331027,
#   'z': -0.0253822,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0571433,
#   'y': 0.338792,
#   'z': -0.0402945,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0517964,
#   'y': 0.335108,
#   'z': -0.0400584,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0522382,
#   'y': 0.342773,
#   'z': -0.0422239,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.046467,
#   'y': 0.331888,
#   'z': -0.0377116,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0520813,
#   'y': 0.334923,
#   'z': -0.0360317,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0546135,
#   'y': 0.334786,
#   'z': -0.0393875,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.05031,
#   'y': 0.322537,
#   'z': -0.032762,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0600452,
#   'y': 0.330163,
#   'z': -0.0319712,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0541385,
#   'y': 0.334658,
#   'z': -0.0491912,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0460543,
#   'y': 0.328419,
#   'z': -0.0314776,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0507577,
#   'y': 0.340833,
#   'z': -0.0420574,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0605719,
#   'y': 0.335556,
#   'z': -0.043225,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0590262,
#   'y': 0.336846,
#   'z': -0.0326756,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0534498,
#   'y': 0.342346,
#   'z': -0.0400093,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0431931,
#   'y': 0.334597,
#   'z': -0.0303002,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.060362,
#   'y': 0.329426,
#   'z': -0.0354689,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0512967,
#   'y': 0.33151,
#   'z': -0.0277854,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0503441,
#   'y': 0.338407,
#   'z': -0.0349383,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0474158,
#   'y': 0.330651,
#   'z': -0.0258255,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0434924,
#   'y': 0.327328,
#   'z': -0.0256374,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0601056,
#   'y': 0.329757,
#   'z': -0.0487864,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0430283,
#   'y': 0.333291,
#   'z': -0.0265748,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0549714,
#   'y': 0.34169,
#   'z': -0.051656,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0589819,
#   'y': 0.334718,
#   'z': -0.0243976,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0571834,
#   'y': 0.328922,
#   'z': -0.0393035,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0579543,
#   'y': 0.33689,
#   'z': -0.0536974,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0589813,
#   'y': 0.335169,
#   'z': -0.0366901,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0534019,
#   'y': 0.319128,
#   'z': -0.0334298,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0584956,
#   'y': 0.338146,
#   'z': -0.0414927,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0571923,
#   'y': 0.324441,
#   'z': -0.0424818,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0544971,
#   'y': 0.331173,
#   'z': -0.0402915,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0455186,
#   'y': 0.334949,
#   'z': -0.0317786,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.052034,
#   'y': 0.339646,
#   'z': -0.0329415,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0498036,
#   'y': 0.325754,
#   'z': -0.0289956,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0509905,
#   'y': 0.340577,
#   'z': -0.0411814,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0601357,
#   'y': 0.338431,
#   'z': -0.0409006,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.050717,
#   'y': 0.3312,
#   'z': -0.0352257,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0609949,
#   'y': 0.334668,
#   'z': -0.0345324,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0621362,
#   'y': 0.331598,
#   'z': -0.0399587,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0489773,
#   'y': 0.333491,
#   'z': -0.0424487,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0610439,
#   'y': 0.337025,
#   'z': -0.0378671,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0518783,
#   'y': 0.336389,
#   'z': -0.0271852,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0618057,
#   'y': 0.340338,
#   'z': -0.0518174,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0477487,
#   'y': 0.333329,
#   'z': -0.0403916,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.059943,
#   'y': 0.336357,
#   'z': -0.0337204,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0530984,
#   'y': 0.327599,
#   'z': -0.0288615,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0591614,
#   'y': 0.340097,
#   'z': -0.0521294,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0515725,
#   'y': 0.330328,
#   'z': -0.0353393,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0545525,
#   'y': 0.33346,
#   'z': -0.0275535,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0458828,
#   'y': 0.327231,
#   'z': -0.020319,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0549017,
#   'y': 0.330823,
#   'z': -0.0385343,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0498745,
#   'y': 0.328904,
#   'z': -0.0254112,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0532221,
#   'y': 0.334001,
#   'z': -0.0476658,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0571052,
#   'y': 0.338159,
#   'z': -0.0542974,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0624648,
#   'y': 0.332154,
#   'z': -0.0435232,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0553349,
#   'y': 0.329263,
#   'z': -0.0490224,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0499067,
#   'y': 0.34122,
#   'z': -0.0395417,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0577261,
#   'y': 0.333423,
#   'z': -0.0464238,
# ...
#   'z': -0.0329693,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0465434,
#   'y': 0.325379,
#   'z': -0.0213904,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0510852,
#   'y': 0.322828,
#   'z': -0.0308191,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0566438,
#   'y': 0.338108,
#   'z': -0.0402398,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.057133,
#   'y': 0.338863,
#   'z': -0.0512906,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0452628,
#   'y': 0.331602,
#   'z': -0.0311082,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.053698,
#   'y': 0.328982,
#   'z': -0.0495883,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0524037,
#   'y': 0.340587,
#   'z': -0.0409852,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0502458,
#   'y': 0.328883,
#   'z': -0.0252251,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0531016,
#   'y': 0.338554,
#   'z': -0.0415743,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0570796,
#   'y': 0.332979,
#   'z': -0.0475503,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0603198,
#   'y': 0.335154,
#   'z': -0.0422892,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0526973,
#   'y': 0.327393,
#   'z': -0.0270677,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0546337,
#   'y': 0.335918,
#   'z': -0.0517803,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0542099,
#   'y': 0.339811,
#   'z': -0.0482803,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0498364,
#   'y': 0.330251,
#   'z': -0.0278307,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0536603,
#   'y': 0.336328,
#   'z': -0.0447836,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0507404,
#   'y': 0.334359,
#   'z': -0.0348586,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0597517,
#   'y': 0.335254,
#   'z': -0.0492106,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0594039,
#   'y': 0.336248,
#   'z': -0.0491859,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0478673,
#   'y': 0.335043,
#   'z': -0.0418885,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.043336,
#   'y': 0.336948,
#   'z': -0.0289739,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0569473,
#   'y': 0.336202,
#   'z': -0.0421929,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0510818,
#   'y': 0.341157,
#   'z': -0.0372727,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0539985,
#   'y': 0.324577,
#   'z': -0.0385343,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0578943,
#   'y': 0.322276,
#   'z': -0.0430137,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0552004,
#   'y': 0.338279,
#   'z': -0.039459,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0465011,
#   'y': 0.330604,
#   'z': -0.0266482,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0595084,
#   'y': 0.328814,
#   'z': -0.0468393,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0466882,
#   'y': 0.328249,
#   'z': -0.030916,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0565209,
#   'y': 0.325522,
#   'z': -0.043476,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0525303,
#   'y': 0.326411,
#   'z': -0.0383627,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0534138,
#   'y': 0.343645,
#   'z': -0.0448226,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0497522,
#   'y': 0.337504,
#   'z': -0.0346739,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0528918,
#   'y': 0.333869,
#   'z': -0.0487424,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0529185,
#   'y': 0.328285,
#   'z': -0.0307068,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0543413,
#   'y': 0.335329,
#   'z': -0.0386775,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0593196,
#   'y': 0.340938,
#   'z': -0.0494508,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0589388,
#   'y': 0.331327,
#   'z': -0.0334689,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0489769,
#   'y': 0.33389,
#   'z': -0.0299023,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0507087,
#   'y': 0.326027,
#   'z': -0.0377864,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0562668,
#   'y': 0.330107,
#   'z': -0.0442239,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.049609,
#   'y': 0.336979,
#   'z': -0.038265,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0541391,
#   'y': 0.335292,
#   'z': -0.0411352,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0493116,
#   'y': 0.329915,
#   'z': -0.0293396,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0478855,
#   'y': 0.335952,
#   'z': -0.0396671,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0592556,
#   'y': 0.332306,
#   'z': -0.0349837,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0517483,
#   'y': 0.338816,
#   'z': -0.0316019,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0583621,
#   'y': 0.341527,
#   'z': -0.0415016,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0500629,
#   'y': 0.319746,
#   'z': -0.0308523,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.059321,
#   'y': 0.33675,
#   'z': -0.0292409,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.060422,
#   'y': 0.330318,
#   'z': -0.0358861,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0435075,
#   'y': 0.336705,
#   'z': -0.0292946,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0595652,
#   'y': 0.335338,
#   'z': -0.0358208,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0560297,
#   'y': 0.327919,
#   'z': -0.0331416,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0546671,
#   'y': 0.333929,
#   'z': -0.037849,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0449138,
#   'y': 0.334385,
#   'z': -0.0336631,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0552057,
#   'y': 0.325853,
#   'z': -0.0329808,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0548041,
#   'y': 0.338538,
#   'z': -0.0355324,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0533397,
#   'y': 0.323783,
#   'z': -0.0243455,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0507817,
#   'y': 0.334594,
#   'z': -0.0399484,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0504857,
#   'y': 0.324594,
#   'z': -0.0302497,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0549403,
#   'y': 0.326573,
#   'z': -0.0350477,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0529949,
#   'y': 0.318764,
#   'z': -0.0348362,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0583629,
#   'y': 0.32812,
#   'z': -0.0324634,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.05717,
#   'y': 0.33358,
#   'z': -0.0399578,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.056457,
#   'y': 0.334376,
#   'z': -0.0308778,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0540075,
#   'y': 0.338026,
#   'z': -0.0431068,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.047819,
#   'y': 0.329442,
#   'z': -0.0277927,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.053576,
#   'y': 0.330266,
#   'z': -0.0367615,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0482779,
#   'y': 0.33182,
#   'z': -0.0297493,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0626154,
#   'y': 0.33069,
#   'z': -0.042091,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0563259,
#   'y': 0.340507,
#   'z': -0.0479885,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0538624,
#   'y': 0.331,
#   'z': -0.0346245,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0549803,
#   'y': 0.334053,
#   'z': -0.0308792,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.05322,
#   'y': 0.319778,
#   'z': -0.0341048,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0473782,
#   'y': 0.332832,
#   'z': -0.0407816,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0441685,
#   'y': 0.331827,
#   'z': -0.0280568,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0503266,
#   'y': 0.335922,
#   'z': -0.0334106,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0589984,
#   'y': 0.338403,
#   'z': -0.0418007,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0587051,
#   'y': 0.333094,
#   'z': -0.0338839,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0561177,
#   'y': 0.330097,
#   'z': -0.0225595,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0606979,
#   'y': 0.344097,
#   'z': -0.0565244,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0598904,
#   'y': 0.334925,
#   'z': -0.0359633,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0546165,
#   'y': 0.344571,
#   'z': -0.0452469,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0527639,
#   'y': 0.339097,
#   'z': -0.0317492,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0558535,
#   'y': 0.337079,
#   'z': -0.0311417,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0466138,
#   'y': 0.334102,
#   'z': -0.0307276,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.056014,
#   'y': 0.342986,
#   'z': -0.0448622,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0568423,
#   'y': 0.329012,
#   'z': -0.0340784,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0599857,
#   'y': 0.328543,
#   'z': -0.0472767,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0524462,
#   'y': 0.332055,
#   'z': -0.0280074,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0483796,
#   'y': 0.33001,
#   'z': -0.0222747,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0606259,
#   'y': 0.341738,
#   'z': -0.0432185,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0477681,
#   'y': 0.335948,
#   'z': -0.0340785,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0489906,
#   'y': 0.333915,
#   'z': -0.0331959,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0612776,
#   'y': 0.338595,
#   'z': -0.0500603,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0545838,
#   'y': 0.338159,
#   'z': -0.0426873,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0585992,
#   'y': 0.335384,
#   'z': -0.0525787,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0559794,
#   'y': 0.335274,
#   'z': -0.0482665,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0474237,
#   'y': 0.342787,
#   'z': -0.0379757,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0433982,
#   'y': 0.328649,
#   'z': -0.0245225,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0557283,
#   'y': 0.341558,
#   'z': -0.0498471,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0569962,
#   'y': 0.33259,
#   'z': -0.0418464,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.046471,
#   'y': 0.334955,
#   'z': -0.0392199,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0552928,
#   'y': 0.347337,
#   'z': -0.0560184,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0566306,
#   'y': 0.327614,
#   'z': -0.0381672,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0509521,
#   'y': 0.335548,
#   'z': -0.038724,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0619345,
#   'y': 0.335575,
#   'z': -0.0483495,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0567794,
#   'y': 0.333607,
#   'z': -0.0268628,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0526976,
#   'y': 0.335183,
#   'z': -0.0470449,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0603891,
#   'y': 0.335904,
#   'z': -0.0285557,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0516988,
#   'y': 0.331955,
#   'z': -0.0304008,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0529484,
#   'y': 0.327705,
#   'z': -0.0313715,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0536733,
#   'y': 0.329507,
#   'z': -0.0336838,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.052075,
#   'y': 0.337048,
#   'z': -0.0488404,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0546027,
#   'y': 0.340238,
#   'z': -0.0361731,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0581002,
#   'y': 0.330612,
#   'z': -0.0320921,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0499086,
#   'y': 0.317034,
#   'z': -0.0309913,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0509734,
#   'y': 0.339157,
#   'z': -0.03489,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.056016,
#   'y': 0.33333,
#   'z': -0.043336,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.048715,
#   'y': 0.33655,
#   'z': -0.0413599,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0616878,
#   'y': 0.329092,
#   'z': -0.0383659,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0583694,
#   'y': 0.331145,
#   'z': -0.0466387,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0510976,
#   'y': 0.325287,
#   'z': -0.0312697,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0530515,
#   'y': 0.334558,
#   'z': -0.0399838,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0441413,
#   'y': 0.336711,
#   'z': -0.0289083,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0634604,
#   'y': 0.329051,
#   'z': -0.0410376,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0608006,
#   'y': 0.335318,
#   'z': -0.0363844,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0536278,
#   'y': 0.326651,
#   'z': -0.0319887,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0561028,
#   'y': 0.330227,
#   'z': -0.0225276,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0542515,
#   'y': 0.328793,
#   'z': -0.0381503,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0530004,
#   'y': 0.335065,
#   'z': -0.0279003,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0597857,
#   'y': 0.336151,
#   'z': -0.0458263,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0584898,
#   'y': 0.32925,
#   'z': -0.0436563,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0569047,
#   'y': 0.335829,
#   'z': -0.0432239,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0541251,
#   'y': 0.341802,
#   'z': -0.040878,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0508595,
#   'y': 0.333011,
#   'z': -0.0289225,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0563749,
#   'y': 0.332739,
#   'z': -0.0470646,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0478448,
#   'y': 0.326168,
#   'z': -0.0319262,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.055484,
#   'y': 0.330641,
#   'z': -0.0373207,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0552823,
#   'y': 0.336047,
#   'z': -0.0428996,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0511236,
#   'y': 0.333656,
#   'z': -0.0305536,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0512933,
#   'y': 0.324912,
#   'z': -0.0362801,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0520817,
#   'y': 0.336826,
#   'z': -0.0285805,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0508427,
#   'y': 0.330762,
#   'z': -0.0322612,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0506818,
#   'y': 0.328091,
#   'z': -0.0248968,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0469939,
#   'y': 0.33525,
#   'z': -0.0280246,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0569349,
#   'y': 0.336285,
#   'z': -0.0529191,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0506838,
#   'y': 0.342209,
#   'z': -0.0378729,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0569587,
#   'y': 0.332377,
#   'z': -0.0500143,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0485525,
#   'y': 0.332032,
#   'z': -0.0351364,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0560535,
#   'y': 0.342646,
#   'z': -0.0387788,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0503485,
#   'y': 0.334654,
#   'z': -0.028643,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.053614,
#   'y': 0.329709,
#   'z': -0.0342542,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  {'x': 0.0464732,
#   'y': 0.334907,
#   'z': -0.0362698,
#   'Cell Type': 'Cortical Thick Ascending Limb'},
#  ...]

# %% [markdown]
# ## Create and use `node-dist-vis` widget to display cells in 3D

# %%
node_dist_vis = NodeDistVis(
    nodes=node_list,
    node_target_key='Cell Type',
    node_target_value='',
    max_edge_distance=1000
)
display(node_dist_vis)
# Out:
# NodeDistVis(color_map=None, color_map_data=None, color_map_key=None, color_map_keys=None, edge_keys=None, edge…
