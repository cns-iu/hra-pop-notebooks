# %% [markdown]
# ## A comparison of genes between MOSDAP and HRApop/ASCT+B tables

# %% [markdown]
# Question: Can I presume, or can you tell me if there are any MOSDAP genes that only appear in one tissue in the other references or in no ASCT+B tables/references?

# %% [markdown]
# ## Install and import libraries

# %%
# %pip install requests pandas seaborn

import requests
import pandas as pd
import seaborn as sns
from io import StringIO
from pprint import pprint
# Out:
# Requirement already satisfied: requests in c:\users\abueckle\documents\github\hra-pop-notebooks\.venv\lib\site-packages (2.32.3)
# Requirement already satisfied: pandas in c:\users\abueckle\documents\github\hra-pop-notebooks\.venv\lib\site-packages (2.2.3)
# Requirement already satisfied: seaborn in c:\users\abueckle\documents\github\hra-pop-notebooks\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\abueckle\documents\github\hra-pop-notebooks\.venv\lib\site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abueckle\documents\github\hra-pop-notebooks\.venv\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\abueckle\documents\github\hra-pop-notebooks\.venv\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abueckle\documents\github\hra-pop-notebooks\.venv\lib\site-packages (from requests) (2025.1.31)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\abueckle\documents\github\hra-pop-notebooks\.venv\lib\site-packages (from pandas) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\abueckle\documents\github\hra-pop-notebooks\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\abueckle\documents\github\hra-pop-notebooks\.venv\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\abueckle\documents\github\hra-pop-notebooks\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\abueckle\documents\github\hra-pop-notebooks\.venv\lib\site-packages (from seaborn) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\abueckle\documents\github\hra-pop-notebooks\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\abueckle\documents\github\hra-pop-notebooks\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\abueckle\documents\github\hra-pop-notebooks\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\abueckle\documents\github\hra-pop-notebooks\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\abueckle\documents\github\hra-pop-notebooks\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\abueckle\documents\github\hra-pop-notebooks\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\abueckle\documents\github\hra-pop-notebooks\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.2)
# Requirement already satisfied: six>=1.5 in c:\users\abueckle\documents\github\hra-pop-notebooks\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Load data

# %%
asctb = pd.read_csv('data/MOSDAP HRA Gene Evidence - HRA ASCT+B.csv')
asctb['source'] = 'asctb'
asctb
# Out:
#      gene_label                                           ct_label  \
# 0         ABCC9                                           pericyte
# 1         ABCC9                                           pericyte
# 2         ABCC9                         capillary endothelial cell
# 3          ACAN                             Reparative Chondrocyte
# 4         ACKR1                      blood vessel endothelial cell
# ...         ...                                                ...
# 6629       XCL1                                 immature NK T cell
# 6630       XCL2                                natural killer cell
# 6631       XCL2  CD16-negative, CD56-bright natural killer cell...
# 6632     ZNF683             CD8-positive, alpha-beta memory T cell
# 6633     ZNF683                                CD8aa(II) thymocyte
#
#                              as_label  \
# 0                              venule
# 1                           capillary
# 2                           capillary
# 3        articular cartilage of joint
# 4                venule of lymph node
# ...                               ...
# 6629                medulla of thymus
# 6630                medulla of thymus
# 6631                    immune system
# 6632  Liver immune resident component
# 6633                medulla of thymus
#
#                                                      as  \
# 0         http://purl.obolibrary.org/obo/UBERON_0001979
# 1         http://purl.obolibrary.org/obo/UBERON_0001982
# 2         http://purl.obolibrary.org/obo/UBERON_0001982
# 3         http://purl.obolibrary.org/obo/UBERON_0010996
# 4         http://purl.obolibrary.org/obo/UBERON_8410041
# ...                                                 ...
# 6629      http://purl.obolibrary.org/obo/UBERON_0002124
# 6630      http://purl.obolibrary.org/obo/UBERON_0002124
# 6631      http://purl.obolibrary.org/obo/UBERON_0002405
# 6632  https://purl.org/ccf/ASCTB-TEMP_liver-immune-r...
# 6633      http://purl.obolibrary.org/obo/UBERON_0002124
#
#                                                      ct  \
# 0             http://purl.obolibrary.org/obo/CL_0000669
# 1             http://purl.obolibrary.org/obo/CL_0000669
# 2             http://purl.obolibrary.org/obo/CL_0002144
# 3     https://purl.org/ccf/ASCTB-TEMP_reparative-cho...
# 4             http://purl.obolibrary.org/obo/CL_0000071
# ...                                                 ...
# 6629          http://purl.obolibrary.org/obo/CL_0000914
# 6630          http://purl.obolibrary.org/obo/CL_0000623
# 6631          http://purl.obolibrary.org/obo/CL_0000938
# 6632          http://purl.obolibrary.org/obo/CL_0000909
# 6633          http://purl.obolibrary.org/obo/CL_0009069
#
#                                    gene source
# 0        http://identifiers.org/hgnc/60  asctb
# 1        http://identifiers.org/hgnc/60  asctb
# 2        http://identifiers.org/hgnc/60  asctb
# 3       http://identifiers.org/hgnc/319  asctb
# 4      http://identifiers.org/hgnc/4035  asctb
# ...                                 ...    ...
# 6629  http://identifiers.org/hgnc/10645  asctb
# 6630  http://identifiers.org/hgnc/10646  asctb
# 6631  http://identifiers.org/hgnc/10646  asctb
# 6632  http://identifiers.org/hgnc/28495  asctb
# 6633  http://identifiers.org/hgnc/28495  asctb
#
# [6634 rows x 7 columns]

# %%
hrapop = pd.read_csv('data/MOSDAP HRA Gene Evidence - HRApop Datasets.csv')
hrapop['source'] = 'hrapop'
hrapop
# Out:
#       gene_label                         ct_label  \
# 0          ABCA9                     stromal cell
# 1          ABCA9              neuroendocrine cell
# 2          ABCA9  CD8-positive, alpha-beta T cell
# 3          ABCA9                       keratocyte
# 4          ABCA9                       fibroblast
# ...          ...                              ...
# 19412     ZNF831  CD8-positive, alpha-beta T cell
# 19413     ZNF831       CD4-positive helper T cell
# 19414     ZNF831       CD4-positive helper T cell
# 19415     ZNF831  CD8-positive, alpha-beta T cell
# 19416     ZNF831  CD4-positive, alpha-beta T cell
#
#                                              as_label  avg_mean_gene_expr  \
# 0                               mesenteric lymph node            3.802716
# 1                                                lung            3.350485
# 2                                               heart            3.159235
# 3                                                 eye            2.957413
# 4                                                 eye            2.901781
# ...                                               ...                 ...
# 19412  Right posterior basal bronchopulmonary segment            0.311313
# 19413  Right posterior basal bronchopulmonary segment            0.257984
# 19414                                            lung            0.257984
# 19415                                            lung            0.249502
# 19416                 Medial bronchopulmonary segment            0.019102
#
#        cell_instance_count  dataset_count  \
# 0                       19              1
# 1                        2              1
# 2                        2              1
# 3                     2157              7
# 4                       55              4
# ...                    ...            ...
# 19412                 1397              2
# 19413                  406              1
# 19414                  406              1
# 19415                 5513              3
# 19416                12957              1
#
#                                                   as  \
# 0      http://purl.obolibrary.org/obo/UBERON_0002509
# 1      http://purl.obolibrary.org/obo/UBERON_0002048
# 2      http://purl.obolibrary.org/obo/UBERON_0000948
# 3      http://purl.obolibrary.org/obo/UBERON_0000970
# 4      http://purl.obolibrary.org/obo/UBERON_0000970
# ...                                              ...
# 19412            http://purl.org/sig/ont/fma/fma7362
# 19413            http://purl.org/sig/ont/fma/fma7362
# 19414  http://purl.obolibrary.org/obo/UBERON_0002048
# 19415  http://purl.obolibrary.org/obo/UBERON_0002048
# 19416            http://purl.org/sig/ont/fma/fma7360
#
#                                               ct  \
# 0      http://purl.obolibrary.org/obo/CL_0000499
# 1      http://purl.obolibrary.org/obo/CL_0000165
# 2      http://purl.obolibrary.org/obo/CL_0000625
# 3      http://purl.obolibrary.org/obo/CL_0002363
# 4      http://purl.obolibrary.org/obo/CL_0000057
# ...                                          ...
# 19412  http://purl.obolibrary.org/obo/CL_0000625
# 19413  http://purl.obolibrary.org/obo/CL_0000492
# 19414  http://purl.obolibrary.org/obo/CL_0000492
# 19415  http://purl.obolibrary.org/obo/CL_0000625
# 19416  http://purl.obolibrary.org/obo/CL_0000624
#
#                                         gene  source
# 0      https://purl.org/ccf/ASCTB-TEMP_abca9  hrapop
# 1             http://identifiers.org/hgnc/39  hrapop
# 2             http://identifiers.org/hgnc/39  hrapop
# 3      https://purl.org/ccf/ASCTB-TEMP_abca9  hrapop
# 4      https://purl.org/ccf/ASCTB-TEMP_abca9  hrapop
# ...                                      ...     ...
# 19412      http://identifiers.org/hgnc/16167  hrapop
# 19413      http://identifiers.org/hgnc/16167  hrapop
# 19414      http://identifiers.org/hgnc/16167  hrapop
# 19415      http://identifiers.org/hgnc/16167  hrapop
# 19416      http://identifiers.org/hgnc/16167  hrapop
#
# [19417 rows x 10 columns]

# %%
kpmp = pd.read_csv('data/MOSDAP HRA Gene Evidence - HRA KPMP-HuBMAP (Kidney Only).csv')
kpmp['source'] = 'kpmp'
kpmp
# Out:
#     gene_label                     ct_label                        as_label  \
# 0        ACTA2  renal interstitial pericyte                   renal papilla
# 1        ACTA2  renal interstitial pericyte                  kidney capsule
# 2        ACTA2  renal interstitial pericyte                          kidney
# 3        ACTA2  renal interstitial pericyte             kidney blood vessel
# 4        ACTA2  renal interstitial pericyte                  kidney pyramid
# ..         ...                          ...                             ...
# 220      VEGFA                     podocyte                          kidney
# 221      VEGFA                     podocyte                  kidney pyramid
# 222      VEGFA                     podocyte                    renal column
# 223      VEGFA                     podocyte          outer cortex of kidney
# 224      VEGFA                     podocyte  glomerular visceral epithelium
#
#      avg_mean_gene_expr                                             as  \
# 0              0.963027  http://purl.obolibrary.org/obo/UBERON_0001228
# 1              0.963027  http://purl.obolibrary.org/obo/UBERON_0002015
# 2              0.963027  http://purl.obolibrary.org/obo/UBERON_0002113
# 3              0.963027  http://purl.obolibrary.org/obo/UBERON_0003517
# 4              0.963027  http://purl.obolibrary.org/obo/UBERON_0004200
# ..                  ...                                            ...
# 220            2.070876  http://purl.obolibrary.org/obo/UBERON_0002113
# 221            2.070876  http://purl.obolibrary.org/obo/UBERON_0004200
# 222            2.070876  http://purl.obolibrary.org/obo/UBERON_0001284
# 223            2.070876  http://purl.obolibrary.org/obo/UBERON_0002189
# 224            2.070876  http://purl.obolibrary.org/obo/UBERON_0005751
#
#                                             ct  \
# 0    http://purl.obolibrary.org/obo/CL_1001318
# 1    http://purl.obolibrary.org/obo/CL_1001318
# 2    http://purl.obolibrary.org/obo/CL_1001318
# 3    http://purl.obolibrary.org/obo/CL_1001318
# 4    http://purl.obolibrary.org/obo/CL_1001318
# ..                                         ...
# 220  http://purl.obolibrary.org/obo/CL_0000653
# 221  http://purl.obolibrary.org/obo/CL_0000653
# 222  http://purl.obolibrary.org/obo/CL_0000653
# 223  http://purl.obolibrary.org/obo/CL_0000653
# 224  http://purl.obolibrary.org/obo/CL_0000653
#
#                                   gene source
# 0      http://identifiers.org/hgnc/130   kpmp
# 1      http://identifiers.org/hgnc/130   kpmp
# 2      http://identifiers.org/hgnc/130   kpmp
# 3      http://identifiers.org/hgnc/130   kpmp
# 4      http://identifiers.org/hgnc/130   kpmp
# ..                                 ...    ...
# 220  http://identifiers.org/hgnc/12680   kpmp
# 221  http://identifiers.org/hgnc/12680   kpmp
# 222  http://identifiers.org/hgnc/12680   kpmp
# 223  http://identifiers.org/hgnc/12680   kpmp
# 224  http://identifiers.org/hgnc/12680   kpmp
#
# [225 rows x 8 columns]

# %%
mosdap = pd.read_csv('data/MOSDAP ST Gene Lists.xlsx - MOSDAP_480_list.csv')
mosdap = mosdap.rename(
  columns={
    'Gene':'gene_name'
  }
)
mosdap
# Out:
#     gene_name       Ensembl ID             Lineage/ L1 or state  \
# 0         BAX  ENSG00000087088                        apoptosis
# 1         BID  ENSG00000015475                        apoptosis
# 2       CASP3  ENSG00000164305                        apoptosis
# 3       CASP8  ENSG00000064012                        apoptosis
# 4       CASP9  ENSG00000132906                        apoptosis
# ..        ...              ...                              ...
# 475       PLN  ENSG00000198523           stromal, smooth muscle
# 476    RBFOX3  ENSG00000167281           stromal, smooth muscle
# 477   SLC24A2  ENSG00000155886           stromal, smooth muscle
# 478     FOXC2  ENSG00000176692              stromal, transition
# 479     MYH10  ENSG00000133026  stromal, vascular smooth muscle
#
#                                           cell type(s)  \
# 0                                             multiple
# 1                                             multiple
# 2                                             multiple
# 3                                             multiple
# 4                                             multiple
# ..                                                 ...
# 475                                 smooth muscle cell
# 476                                      smooth muscle
# 477                                      smooth muscle
# 478  epithelial-mesenchymal transition, embryonic m...
# 479                             vascular smooth muscle
#
#                 Rationale/Source Specific Request by specificity flag  \
# 0           Tissue  expert added                 NaN              NaN
# 1           Tissue  expert added                 NaN              NaN
# 2           Tissue  expert added                 NaN              NaN
# 3           Tissue  expert added                 NaN              NaN
# 4           Tissue  expert added                 NaN              NaN
# ..                           ...                 ...              ...
# 475             TOP 5 (CZI) List                 NaN              NaN
# 476         Tissue  expert added              Uterus              NaN
# 477         Tissue  expert added      Fallopian Tube              NaN
# 478  State Rescue; MxIF Proteins                 NaN              NaN
# 479         Tissue  expert added                 HRT              NaN
#
#     Protein/Other name  is_in_10x_multi_panel 10x_multi_panel_celltype  \
# 0                  NaN                  False                      NaN
# 1                  NaN                  False                      NaN
# 2                  NaN                  False                      NaN
# 3                  NaN                  False                      NaN
# 4                  NaN                  False                      NaN
# ..                 ...                    ...                      ...
# 475                NaN                  False                      NaN
# 476                NaN                  False                      NaN
# 477                NaN                  False                      NaN
# 478                NaN                  False                      NaN
# 479                NaN                  False                      NaN
#
#      is_in_Xenium_KIL_panel 10x_panel_designer_comment
# 0                     False                        NaN
# 1                     False                        NaN
# 2                     False                        NaN
# 3                     False                        NaN
# 4                     False                        NaN
# ..                      ...                        ...
# 475                   False                        NaN
# 476                   False                        NaN
# 477                   False                        NaN
# 478                   False                        NaN
# 479                   False                        NaN
#
# [480 rows x 12 columns]

# %%
url = 'https://apps.humanatlas.io/api/grlc/hra/ensembl-lookup.csv'

# Get the response
response = requests.get(url)
response.raise_for_status()  # will raise an error if request fails

# Wrap response text in StringIO so pandas can read it like a file
json_data = StringIO(response.text)

# Load into DataFrame
look_up = pd.read_csv(json_data)
look_up
# Out:
#               ensemble  gene_name        hgnc
# 0      ENSG00000000003     TSPAN6  HGNC:11858
# 1      ENSG00000000005       TNMD  HGNC:17757
# 2      ENSG00000000419       DPM1   HGNC:3005
# 3      ENSG00000000457      SCYL3  HGNC:19285
# 4      ENSG00000000460      FIRRM  HGNC:25565
# ...                ...        ...         ...
# 41201  ENSG00000293312   HNRNPKP3  HGNC:42376
# 41202  ENSG00000293326  LINC00359  HGNC:42679
# 41203  ENSG00000293386    LRRC78P  HGNC:54091
# 41204  ENSG00000293543    DUSP13A  HGNC:56772
# 41205  ENSG00000293596    SCREEM1  HGNC:56860
#
# [41206 rows x 3 columns]

# %% [markdown]
# ## Preprocess

# %% [markdown]
# ### HRA (add organ IRIs)

# %%
df_combined = pd.concat([asctb, hrapop, kpmp])
df_combined
# Out:
#     gene_label                       ct_label                        as_label  \
# 0        ABCC9                       pericyte                          venule
# 1        ABCC9                       pericyte                       capillary
# 2        ABCC9     capillary endothelial cell                       capillary
# 3         ACAN         Reparative Chondrocyte    articular cartilage of joint
# 4        ACKR1  blood vessel endothelial cell            venule of lymph node
# ..         ...                            ...                             ...
# 220      VEGFA                       podocyte                          kidney
# 221      VEGFA                       podocyte                  kidney pyramid
# 222      VEGFA                       podocyte                    renal column
# 223      VEGFA                       podocyte          outer cortex of kidney
# 224      VEGFA                       podocyte  glomerular visceral epithelium
#
#                                                 as  \
# 0    http://purl.obolibrary.org/obo/UBERON_0001979
# 1    http://purl.obolibrary.org/obo/UBERON_0001982
# 2    http://purl.obolibrary.org/obo/UBERON_0001982
# 3    http://purl.obolibrary.org/obo/UBERON_0010996
# 4    http://purl.obolibrary.org/obo/UBERON_8410041
# ..                                             ...
# 220  http://purl.obolibrary.org/obo/UBERON_0002113
# 221  http://purl.obolibrary.org/obo/UBERON_0004200
# 222  http://purl.obolibrary.org/obo/UBERON_0001284
# 223  http://purl.obolibrary.org/obo/UBERON_0002189
# 224  http://purl.obolibrary.org/obo/UBERON_0005751
#
#                                                     ct  \
# 0            http://purl.obolibrary.org/obo/CL_0000669
# 1            http://purl.obolibrary.org/obo/CL_0000669
# 2            http://purl.obolibrary.org/obo/CL_0002144
# 3    https://purl.org/ccf/ASCTB-TEMP_reparative-cho...
# 4            http://purl.obolibrary.org/obo/CL_0000071
# ..                                                 ...
# 220          http://purl.obolibrary.org/obo/CL_0000653
# 221          http://purl.obolibrary.org/obo/CL_0000653
# 222          http://purl.obolibrary.org/obo/CL_0000653
# 223          http://purl.obolibrary.org/obo/CL_0000653
# 224          http://purl.obolibrary.org/obo/CL_0000653
#
#                                   gene source  avg_mean_gene_expr  \
# 0       http://identifiers.org/hgnc/60  asctb                 NaN
# 1       http://identifiers.org/hgnc/60  asctb                 NaN
# 2       http://identifiers.org/hgnc/60  asctb                 NaN
# 3      http://identifiers.org/hgnc/319  asctb                 NaN
# 4     http://identifiers.org/hgnc/4035  asctb                 NaN
# ..                                 ...    ...                 ...
# 220  http://identifiers.org/hgnc/12680   kpmp            2.070876
# 221  http://identifiers.org/hgnc/12680   kpmp            2.070876
# 222  http://identifiers.org/hgnc/12680   kpmp            2.070876
# 223  http://identifiers.org/hgnc/12680   kpmp            2.070876
# 224  http://identifiers.org/hgnc/12680   kpmp            2.070876
#
#      cell_instance_count  dataset_count
# 0                    NaN            NaN
# 1                    NaN            NaN
# 2                    NaN            NaN
# 3                    NaN            NaN
# 4                    NaN            NaN
# ..                   ...            ...
# 220                  NaN            NaN
# 221                  NaN            NaN
# 222                  NaN            NaN
# 223                  NaN            NaN
# 224                  NaN            NaN
#
# [26276 rows x 10 columns]

# %%
# add ref-organ
url = 'https://apps.humanatlas.io/api/v1/reference-organs'

# Get the response
response = requests.get(url)
response.raise_for_status()  # will raise an error if request fails

json_data = response.json()
ref_organs = json_data

uberon_ids = set([organ['representation_of']for organ in ref_organs])

# %%
# make look-up between as_id and ref_organ
def get_list_as(organ_id:str):
  """Gets a list of all AS in the provided organ

  Args:
      organ_id (str): Organ ID
  """
  url = f'https://apps.humanatlas.io/api/grlc/hra/as-parts?location='+organ_id
  
  headers = {
    'accept':'text/csv'
  }
  
    # Get the response
  response = requests.get(url, headers=headers)
  response.raise_for_status()  # will raise an error if request fails

  # Wrap response text in StringIO so pandas can read it like a file
  csv_data = StringIO(response.text)

  # Load into DataFrame
  df = pd.read_csv(csv_data)
  return df

# %%
df_organ_to_as = pd.DataFrame(columns=['organ_iri', 'part_iri', 'part_label'])

for organ_id in uberon_ids:
    as_list = get_list_as(organ_id)

    # add the organ_id as a new column so we can merge cleanly
    as_list = as_list.rename(
        columns={"as_id": "part_iri", "ref_organ": "part_label"})
    as_list["organ_iri"] = organ_id

    # append all rows at once
    df_organ_to_as = pd.concat([df_organ_to_as, as_list], ignore_index=True)
    
df_organ_to_as = df_organ_to_as.rename(columns={'part_iri': 'as'})
df_organ_to_as
# Out:
#                                           organ_iri  \
# 0     http://purl.obolibrary.org/obo/UBERON_0002509
# 1     http://purl.obolibrary.org/obo/UBERON_2001553
# 2              http://purl.org/sig/ont/fma/fma54974
# 3     http://purl.obolibrary.org/obo/UBERON_0002119
# 4     http://purl.obolibrary.org/obo/UBERON_0003126
# ...                                             ...
# 5456  http://purl.obolibrary.org/obo/UBERON_0000079
# 5457  http://purl.obolibrary.org/obo/UBERON_0000079
# 5458  http://purl.obolibrary.org/obo/UBERON_0000079
# 5459  http://purl.obolibrary.org/obo/UBERON_0001270
# 5460  http://purl.obolibrary.org/obo/UBERON_0001270
#
#                                                      as  \
# 0         http://purl.obolibrary.org/obo/UBERON_0002509
# 1         http://purl.obolibrary.org/obo/UBERON_2001553
# 2                  http://purl.org/sig/ont/fma/fma54974
# 3         http://purl.obolibrary.org/obo/UBERON_0002119
# 4         http://purl.obolibrary.org/obo/UBERON_0001901
# ...                                                 ...
# 5456  https://purl.org/ccf/ASCTB-TEMP_vena-recta-of-...
# 5457  https://purl.org/ccf/ASCTB-TEMP_zygomaticofaci...
# 5458  https://purl.org/ccf/ASCTB-TEMP_zygomaticotemp...
# 5459      http://purl.obolibrary.org/obo/UBERON_0000178
# 5460      http://purl.obolibrary.org/obo/UBERON_0001270
#
#                             part_label
# 0                mesenteric lymph node
# 1                            manubrium
# 2                 Left palatine tonsil
# 3                           left ovary
# 4                epithelium of trachea
# ...                                ...
# 5456  vena recta of large intestine #4
# 5457           zygomaticofacial artery
# 5458         zygomaticotemporal artery
# 5459                             blood
# 5460                       bony pelvis
#
# [5461 rows x 3 columns]

# %%
df_combined_with_organ = pd.merge(df_combined, df_organ_to_as, on='as', how='inner')
df_combined_with_organ
# Out:
#       gene_label                         ct_label     as_label  \
# 0          ABCC9                         pericyte       venule
# 1          ABCC9                         pericyte       venule
# 2          ABCC9                         pericyte       venule
# 3          ABCC9                         pericyte    capillary
# 4          ABCC9                         pericyte    capillary
# ...          ...                              ...          ...
# 29692     ZNF831       CD4-positive helper T cell         lung
# 29693     ZNF831  CD8-positive, alpha-beta T cell         lung
# 29694     PECAM1                 endothelial cell  endothelium
# 29695     PECAM1                 endothelial cell  endothelium
# 29696     PECAM1                 endothelial cell  endothelium
#
#                                                   as  \
# 0      http://purl.obolibrary.org/obo/UBERON_0001979
# 1      http://purl.obolibrary.org/obo/UBERON_0001979
# 2      http://purl.obolibrary.org/obo/UBERON_0001979
# 3      http://purl.obolibrary.org/obo/UBERON_0001982
# 4      http://purl.obolibrary.org/obo/UBERON_0001982
# ...                                              ...
# 29692  http://purl.obolibrary.org/obo/UBERON_0002048
# 29693  http://purl.obolibrary.org/obo/UBERON_0002048
# 29694  http://purl.obolibrary.org/obo/UBERON_0001986
# 29695  http://purl.obolibrary.org/obo/UBERON_0001986
# 29696  http://purl.obolibrary.org/obo/UBERON_0001986
#
#                                               ct  \
# 0      http://purl.obolibrary.org/obo/CL_0000669
# 1      http://purl.obolibrary.org/obo/CL_0000669
# 2      http://purl.obolibrary.org/obo/CL_0000669
# 3      http://purl.obolibrary.org/obo/CL_0000669
# 4      http://purl.obolibrary.org/obo/CL_0000669
# ...                                          ...
# 29692  http://purl.obolibrary.org/obo/CL_0000492
# 29693  http://purl.obolibrary.org/obo/CL_0000625
# 29694  http://purl.obolibrary.org/obo/CL_0000115
# 29695  http://purl.obolibrary.org/obo/CL_0000115
# 29696  http://purl.obolibrary.org/obo/CL_0000115
#
#                                     gene  source  avg_mean_gene_expr  \
# 0         http://identifiers.org/hgnc/60   asctb                 NaN
# 1         http://identifiers.org/hgnc/60   asctb                 NaN
# 2         http://identifiers.org/hgnc/60   asctb                 NaN
# 3         http://identifiers.org/hgnc/60   asctb                 NaN
# 4         http://identifiers.org/hgnc/60   asctb                 NaN
# ...                                  ...     ...                 ...
# 29692  http://identifiers.org/hgnc/16167  hrapop            0.257984
# 29693  http://identifiers.org/hgnc/16167  hrapop            0.249502
# 29694   http://identifiers.org/hgnc/8823    kpmp            1.741475
# 29695   http://identifiers.org/hgnc/8823    kpmp            1.741475
# 29696   http://identifiers.org/hgnc/8823    kpmp            1.741475
#
#        cell_instance_count  dataset_count  \
# 0                      NaN            NaN
# 1                      NaN            NaN
# 2                      NaN            NaN
# 3                      NaN            NaN
# 4                      NaN            NaN
# ...                    ...            ...
# 29692                406.0            1.0
# 29693               5513.0            3.0
# 29694                  NaN            NaN
# 29695                  NaN            NaN
# 29696                  NaN            NaN
#
#                                            organ_iri   part_label
# 0      http://purl.obolibrary.org/obo/UBERON_0000948       venule
# 1      http://purl.obolibrary.org/obo/UBERON_0004537       venule
# 2      http://purl.obolibrary.org/obo/UBERON_0000079       venule
# 3      http://purl.obolibrary.org/obo/UBERON_0000948    capillary
# 4      http://purl.obolibrary.org/obo/UBERON_0004537    capillary
# ...                                              ...          ...
# 29692  http://purl.obolibrary.org/obo/UBERON_0001004         lung
# 29693  http://purl.obolibrary.org/obo/UBERON_0001004         lung
# 29694  http://purl.obolibrary.org/obo/UBERON_0000948  endothelium
# 29695  http://purl.obolibrary.org/obo/UBERON_0004537  endothelium
# 29696  http://purl.obolibrary.org/obo/UBERON_0000079  endothelium
#
# [29697 rows x 12 columns]

# %% [markdown]
# ### MOSDAP (add HGNC IDs)

# %%
df_mosdap = pd.merge(mosdap, look_up, on='gene_name',
                     how='left').drop(columns=['ensemble'])
df_mosdap
# Out:
#     gene_name       Ensembl ID             Lineage/ L1 or state  \
# 0         BAX  ENSG00000087088                        apoptosis
# 1         BID  ENSG00000015475                        apoptosis
# 2       CASP3  ENSG00000164305                        apoptosis
# 3       CASP8  ENSG00000064012                        apoptosis
# 4       CASP9  ENSG00000132906                        apoptosis
# ..        ...              ...                              ...
# 475       PLN  ENSG00000198523           stromal, smooth muscle
# 476    RBFOX3  ENSG00000167281           stromal, smooth muscle
# 477   SLC24A2  ENSG00000155886           stromal, smooth muscle
# 478     FOXC2  ENSG00000176692              stromal, transition
# 479     MYH10  ENSG00000133026  stromal, vascular smooth muscle
#
#                                           cell type(s)  \
# 0                                             multiple
# 1                                             multiple
# 2                                             multiple
# 3                                             multiple
# 4                                             multiple
# ..                                                 ...
# 475                                 smooth muscle cell
# 476                                      smooth muscle
# 477                                      smooth muscle
# 478  epithelial-mesenchymal transition, embryonic m...
# 479                             vascular smooth muscle
#
#                 Rationale/Source Specific Request by specificity flag  \
# 0           Tissue  expert added                 NaN              NaN
# 1           Tissue  expert added                 NaN              NaN
# 2           Tissue  expert added                 NaN              NaN
# 3           Tissue  expert added                 NaN              NaN
# 4           Tissue  expert added                 NaN              NaN
# ..                           ...                 ...              ...
# 475             TOP 5 (CZI) List                 NaN              NaN
# 476         Tissue  expert added              Uterus              NaN
# 477         Tissue  expert added      Fallopian Tube              NaN
# 478  State Rescue; MxIF Proteins                 NaN              NaN
# 479         Tissue  expert added                 HRT              NaN
#
#     Protein/Other name  is_in_10x_multi_panel 10x_multi_panel_celltype  \
# 0                  NaN                  False                      NaN
# 1                  NaN                  False                      NaN
# 2                  NaN                  False                      NaN
# 3                  NaN                  False                      NaN
# 4                  NaN                  False                      NaN
# ..                 ...                    ...                      ...
# 475                NaN                  False                      NaN
# 476                NaN                  False                      NaN
# 477                NaN                  False                      NaN
# 478                NaN                  False                      NaN
# 479                NaN                  False                      NaN
#
#      is_in_Xenium_KIL_panel 10x_panel_designer_comment        hgnc
# 0                     False                        NaN    HGNC:959
# 1                     False                        NaN   HGNC:1050
# 2                     False                        NaN   HGNC:1504
# 3                     False                        NaN   HGNC:1509
# 4                     False                        NaN   HGNC:1511
# ..                      ...                        ...         ...
# 475                   False                        NaN   HGNC:9080
# 476                   False                        NaN  HGNC:27097
# 477                   False                        NaN  HGNC:10976
# 478                   False                        NaN   HGNC:3801
# 479                   False                        NaN   HGNC:7568
#
# [480 rows x 13 columns]

# %% [markdown]
# ## Analyze

# %%
# mosdap genes that appear in no ASCT+B tables
no_asctb = df_mosdap[~df_mosdap['gene_name'].isin(df_combined_with_organ.loc[df_combined_with_organ['source'] == 'asctb', 'gene_label'])]
no_asctb
# Out:
#     gene_name       Ensembl ID             Lineage/ L1 or state  \
# 0         BAX  ENSG00000087088                        apoptosis
# 2       CASP3  ENSG00000164305                        apoptosis
# 3       CASP8  ENSG00000064012                        apoptosis
# 4       CASP9  ENSG00000132906                        apoptosis
# 5       BIRC5  ENSG00000089685             apoptosis, inhibitor
# ..        ...              ...                              ...
# 474     PDE1C  ENSG00000154678           stromal, smooth muscle
# 476    RBFOX3  ENSG00000167281           stromal, smooth muscle
# 477   SLC24A2  ENSG00000155886           stromal, smooth muscle
# 478     FOXC2  ENSG00000176692              stromal, transition
# 479     MYH10  ENSG00000133026  stromal, vascular smooth muscle
#
#                                           cell type(s)  \
# 0                                             multiple
# 2                                             multiple
# 3                                             multiple
# 4                                             multiple
# 5    multiple, said to be generally low in adult ce...
# ..                                                 ...
# 474                                      smooth muscle
# 476                                      smooth muscle
# 477                                      smooth muscle
# 478  epithelial-mesenchymal transition, embryonic m...
# 479                             vascular smooth muscle
#
#                 Rationale/Source Specific Request by specificity flag  \
# 0           Tissue  expert added                 NaN              NaN
# 2           Tissue  expert added                 NaN              NaN
# 3           Tissue  expert added                 NaN              NaN
# 4           Tissue  expert added                 NaN              NaN
# 5           Tissue  expert added                 IVD              NaN
# ..                           ...                 ...              ...
# 474         Tissue  expert added      Fallopian Tube              NaN
# 476         Tissue  expert added              Uterus              NaN
# 477         Tissue  expert added      Fallopian Tube              NaN
# 478  State Rescue; MxIF Proteins                 NaN              NaN
# 479         Tissue  expert added                 HRT              NaN
#
#     Protein/Other name  is_in_10x_multi_panel 10x_multi_panel_celltype  \
# 0                  NaN                  False                      NaN
# 2                  NaN                  False                      NaN
# 3                  NaN                  False                      NaN
# 4                  NaN                  False                      NaN
# 5                  NaN                  False                      NaN
# ..                 ...                    ...                      ...
# 474                NaN                  False                      NaN
# 476                NaN                  False                      NaN
# 477                NaN                  False                      NaN
# 478                NaN                  False                      NaN
# 479                NaN                  False                      NaN
#
#      is_in_Xenium_KIL_panel 10x_panel_designer_comment        hgnc
# 0                     False                        NaN    HGNC:959
# 2                     False                        NaN   HGNC:1504
# 3                     False                        NaN   HGNC:1509
# 4                     False                        NaN   HGNC:1511
# 5                     False                        NaN    HGNC:593
# ..                      ...                        ...         ...
# 474                   False                        NaN   HGNC:8776
# 476                   False                        NaN  HGNC:27097
# 477                   False                        NaN  HGNC:10976
# 478                   False                        NaN   HGNC:3801
# 479                   False                        NaN   HGNC:7568
#
# [234 rows x 13 columns]

# %%
# not in hra-pop
not_in_hrapop = df_mosdap[~df_mosdap['gene_name'].isin(
    df_combined_with_organ.loc[df_combined_with_organ['source'] == 'hrapop', 'gene_label'])]
not_in_hrapop
# Out:
#      gene_name       Ensembl ID             Lineage/ L1 or state  \
# 45   LINC02360  ENSG00000248300            endothelial, vascular
# 79       KRT71  ENSG00000139648                       epithelial
# 82         LOR  ENSG00000203782                       epithelial
# 85        MMP3  ENSG00000149968                       epithelial
# 89        PAX1  ENSG00000125813                       epithelial
# 105     SLC5A8  ENSG00000256870                       epithelial
# 113     TRIM50  ENSG00000146755                       epithelial
# 125     ZNF750  ENSG00000141579                       epithelial
# 149     TRIM63  ENSG00000158022           epithelial, melanocyte
# 318    SLC6A12  ENSG00000111181                  immune, myeloid
# 320     SMIM25  ENSG00000224397                  immune, myeloid
# 330       NCR2  ENSG00000096264                       immune, NK
# 343      MMP13  ENSG00000137745                         multiple
# 350      HPGD   ENSG00000164120  multiple? capillary endothelial
# 355      NRSN1  ENSG00000152954                           neural
# 357     PHOX2A  ENSG00000165462                           neural
# 364      STMN4  ENSG00000015592                           neural
# 366       TLX2  ENSG00000115297                           neural
# 459      WSCD2  ENSG00000075035         stromal, skeletal muscle
#
#                                           cell type(s)      Rationale/Source  \
# 45                                vascular endothelium  Tissue  expert added
# 79                                   Inner root sheath  Tissue  expert added
# 82                                          epithelial  Tissue  expert added
# 85   epithelial, periosteum, osteocytes/blasts, lun...  Tissue  expert added
# 89        ventral vertebral column, few thymic stromal  Tissue  expert added
# 105                               glandular epithelium  Tissue  expert added
# 113                                        paneth cell      TOP 5 (CZI) List
# 125                                    absorptive cell      TOP 5 (CZI) List
# 149                                         melanocyte      TOP 5 (CZI) List
# 318                                    Langerhans cell      TOP 5 (CZI) List
# 320                             non classical monocyte  Tissue  expert added
# 330                                 activated NK cells         MxIF Proteins
# 343         chondrocytes, epithelial, neuronal, cancer  Tissue  expert added
# 350          Treg (esp in fat?), lung capillary, other         MxIF Proteins
# 355                         ganglion cell,motor neuron      TOP 5 (CZI) List
# 357          ganglion cell,motor neuron,sensory neuron      TOP 5 (CZI) List
# 364          ganglion cell,motor neuron,sensory neuron      TOP 5 (CZI) List
# 366                                     sensory neuron      TOP 5 (CZI) List
# 459                               skeletal muscle cell      TOP 5 (CZI) List
#
#     Specific Request by specificity flag Protein/Other name  \
# 45                Ovary              NaN                NaN
# 79                 Skin              NaN                NaN
# 82                 Skin              NaN                NaN
# 85                  IVD              NaN                NaN
# 89                  IVD              NaN                NaN
# 105              Uterus              NaN                NaN
# 113                 NaN              NaN                NaN
# 125                 NaN              NaN                NaN
# 149                 NaN              NaN                NaN
# 318                 NaN              NaN                NaN
# 320                 NaN          PELATON                NaN
# 330                 NaN              NaN                NaN
# 343                 IVD              NaN                NaN
# 350                 NaN              NaN            15-PGDH
# 355                 NaN              NaN                NaN
# 357                 NaN              NaN                NaN
# 364                 NaN              NaN                NaN
# 366                 NaN              NaN                NaN
# 459                 NaN              NaN                NaN
#
#      is_in_10x_multi_panel 10x_multi_panel_celltype  is_in_Xenium_KIL_panel  \
# 45                   False                      NaN                   False
# 79                   False                      NaN                   False
# 82                   False                      NaN                   False
# 85                   False                      NaN                   False
# 89                   False                      NaN                   False
# 105                  False                      NaN                   False
# 113                  False                      NaN                   False
# 125                  False                      NaN                   False
# 149                  False                      NaN                   False
# 318                  False                      NaN                   False
# 320                  False                      NaN                   False
# 330                  False                      NaN                   False
# 343                  False                      NaN                   False
# 350                  False                      NaN                   False
# 355                  False                      NaN                   False
# 357                  False                      NaN                   False
# 364                  False                      NaN                   False
# 366                  False                      NaN                   False
# 459                  False                      NaN                   False
#
#     10x_panel_designer_comment        hgnc
# 45                         NaN  HGNC:53282
# 79                         NaN  HGNC:28927
# 82                         NaN         NaN
# 85                         NaN   HGNC:7173
# 89                         NaN   HGNC:8615
# 105                        NaN  HGNC:19119
# 113                        NaN  HGNC:19017
# 125                        NaN  HGNC:25843
# 149                        NaN  HGNC:16007
# 318                        NaN  HGNC:11045
# 320                        NaN         NaN
# 330                        NaN   HGNC:6732
# 343                        NaN   HGNC:7159
# 350                        NaN         NaN
# 355                        NaN  HGNC:17881
# 357                        NaN    HGNC:691
# 364                        NaN  HGNC:16078
# 366                        NaN   HGNC:5057
# 459                        NaN  HGNC:29117

# %%
# not in kpmp
not_in_kpmp = df_mosdap[~df_mosdap['gene_name'].isin(
    df_combined_with_organ.loc[df_combined_with_organ['source'] == 'kpmp', 'gene_label'])]
not_in_kpmp
# Out:
#     gene_name       Ensembl ID             Lineage/ L1 or state  \
# 0         BAX  ENSG00000087088                        apoptosis
# 1         BID  ENSG00000015475                        apoptosis
# 2       CASP3  ENSG00000164305                        apoptosis
# 3       CASP8  ENSG00000064012                        apoptosis
# 4       CASP9  ENSG00000132906                        apoptosis
# ..        ...              ...                              ...
# 475       PLN  ENSG00000198523           stromal, smooth muscle
# 476    RBFOX3  ENSG00000167281           stromal, smooth muscle
# 477   SLC24A2  ENSG00000155886           stromal, smooth muscle
# 478     FOXC2  ENSG00000176692              stromal, transition
# 479     MYH10  ENSG00000133026  stromal, vascular smooth muscle
#
#                                           cell type(s)  \
# 0                                             multiple
# 1                                             multiple
# 2                                             multiple
# 3                                             multiple
# 4                                             multiple
# ..                                                 ...
# 475                                 smooth muscle cell
# 476                                      smooth muscle
# 477                                      smooth muscle
# 478  epithelial-mesenchymal transition, embryonic m...
# 479                             vascular smooth muscle
#
#                 Rationale/Source Specific Request by specificity flag  \
# 0           Tissue  expert added                 NaN              NaN
# 1           Tissue  expert added                 NaN              NaN
# 2           Tissue  expert added                 NaN              NaN
# 3           Tissue  expert added                 NaN              NaN
# 4           Tissue  expert added                 NaN              NaN
# ..                           ...                 ...              ...
# 475             TOP 5 (CZI) List                 NaN              NaN
# 476         Tissue  expert added              Uterus              NaN
# 477         Tissue  expert added      Fallopian Tube              NaN
# 478  State Rescue; MxIF Proteins                 NaN              NaN
# 479         Tissue  expert added                 HRT              NaN
#
#     Protein/Other name  is_in_10x_multi_panel 10x_multi_panel_celltype  \
# 0                  NaN                  False                      NaN
# 1                  NaN                  False                      NaN
# 2                  NaN                  False                      NaN
# 3                  NaN                  False                      NaN
# 4                  NaN                  False                      NaN
# ..                 ...                    ...                      ...
# 475                NaN                  False                      NaN
# 476                NaN                  False                      NaN
# 477                NaN                  False                      NaN
# 478                NaN                  False                      NaN
# 479                NaN                  False                      NaN
#
#      is_in_Xenium_KIL_panel 10x_panel_designer_comment        hgnc
# 0                     False                        NaN    HGNC:959
# 1                     False                        NaN   HGNC:1050
# 2                     False                        NaN   HGNC:1504
# 3                     False                        NaN   HGNC:1509
# 4                     False                        NaN   HGNC:1511
# ..                      ...                        ...         ...
# 475                   False                        NaN   HGNC:9080
# 476                   False                        NaN  HGNC:27097
# 477                   False                        NaN  HGNC:10976
# 478                   False                        NaN   HGNC:3801
# 479                   False                        NaN   HGNC:7568
#
# [479 rows x 13 columns]

# %%
# Count distinct as_label per gene_label in df_combined
counts = (
    df_combined_with_organ.groupby("gene_label")["organ_iri"]
    .nunique()                      # number of unique as_label per gene_label
    .reset_index(name="organ_count")
)

# Get the list of unique organs per gene_label
organ_lists = (
    df_combined_with_organ.groupby("gene_label")["organ_iri"]
    .unique()  # returns a numpy array of unique organ_iri per gene_label
    .reset_index(name="organ_list")
)

# Merge with your counts if needed
counts_with_list = counts.merge(organ_lists, on="gene_label", how="left")
counts_with_list
# Out:
#     gene_label  organ_count                                         organ_list
# 0        ABCA9            7  [http://purl.obolibrary.org/obo/UBERON_0002509...
# 1        ABCC9            6  [http://purl.obolibrary.org/obo/UBERON_0000948...
# 2         ACAN            1    [http://purl.obolibrary.org/obo/UBERON_0001004]
# 3        ACER1            1    [http://purl.obolibrary.org/obo/UBERON_0002097]
# 4        ACKR1           12  [http://purl.obolibrary.org/obo/UBERON_0000948...
# ..         ...          ...                                                ...
# 458    ZNF385B            3  [http://purl.obolibrary.org/obo/UBERON_0001004...
# 459    ZNF385C            2  [http://purl.obolibrary.org/obo/UBERON_0001270...
# 460     ZNF683            4  [http://purl.obolibrary.org/obo/UBERON_0002107...
# 461    ZNF804A            5  [http://purl.obolibrary.org/obo/UBERON_0000948...
# 462     ZNF831            8  [http://purl.obolibrary.org/obo/UBERON_0001270...
#
# [463 rows x 3 columns]

# %%
# Merge back onto df_mosdap by matching gene_name to gene_label
df_with_counts = df_mosdap.merge(
    counts_with_list, left_on="gene_name", right_on="gene_label", how="left")

# Fill NaN (if a gene_name never appears)
df_with_counts["organ_count"] = df_with_counts["organ_count"].fillna(0).astype(int)
df_with_counts
# Out:
#     gene_name       Ensembl ID             Lineage/ L1 or state  \
# 0         BAX  ENSG00000087088                        apoptosis
# 1         BID  ENSG00000015475                        apoptosis
# 2       CASP3  ENSG00000164305                        apoptosis
# 3       CASP8  ENSG00000064012                        apoptosis
# 4       CASP9  ENSG00000132906                        apoptosis
# ..        ...              ...                              ...
# 475       PLN  ENSG00000198523           stromal, smooth muscle
# 476    RBFOX3  ENSG00000167281           stromal, smooth muscle
# 477   SLC24A2  ENSG00000155886           stromal, smooth muscle
# 478     FOXC2  ENSG00000176692              stromal, transition
# 479     MYH10  ENSG00000133026  stromal, vascular smooth muscle
#
#                                           cell type(s)  \
# 0                                             multiple
# 1                                             multiple
# 2                                             multiple
# 3                                             multiple
# 4                                             multiple
# ..                                                 ...
# 475                                 smooth muscle cell
# 476                                      smooth muscle
# 477                                      smooth muscle
# 478  epithelial-mesenchymal transition, embryonic m...
# 479                             vascular smooth muscle
#
#                 Rationale/Source Specific Request by specificity flag  \
# 0           Tissue  expert added                 NaN              NaN
# 1           Tissue  expert added                 NaN              NaN
# 2           Tissue  expert added                 NaN              NaN
# 3           Tissue  expert added                 NaN              NaN
# 4           Tissue  expert added                 NaN              NaN
# ..                           ...                 ...              ...
# 475             TOP 5 (CZI) List                 NaN              NaN
# 476         Tissue  expert added              Uterus              NaN
# 477         Tissue  expert added      Fallopian Tube              NaN
# 478  State Rescue; MxIF Proteins                 NaN              NaN
# 479         Tissue  expert added                 HRT              NaN
#
#     Protein/Other name  is_in_10x_multi_panel 10x_multi_panel_celltype  \
# 0                  NaN                  False                      NaN
# 1                  NaN                  False                      NaN
# 2                  NaN                  False                      NaN
# 3                  NaN                  False                      NaN
# 4                  NaN                  False                      NaN
# ..                 ...                    ...                      ...
# 475                NaN                  False                      NaN
# 476                NaN                  False                      NaN
# 477                NaN                  False                      NaN
# 478                NaN                  False                      NaN
# 479                NaN                  False                      NaN
#
#      is_in_Xenium_KIL_panel 10x_panel_designer_comment        hgnc gene_label  \
# 0                     False                        NaN    HGNC:959        BAX
# 1                     False                        NaN   HGNC:1050        BID
# 2                     False                        NaN   HGNC:1504      CASP3
# 3                     False                        NaN   HGNC:1509      CASP8
# 4                     False                        NaN   HGNC:1511      CASP9
# ..                      ...                        ...         ...        ...
# 475                   False                        NaN   HGNC:9080        PLN
# 476                   False                        NaN  HGNC:27097     RBFOX3
# 477                   False                        NaN  HGNC:10976    SLC24A2
# 478                   False                        NaN   HGNC:3801      FOXC2
# 479                   False                        NaN   HGNC:7568      MYH10
#
#      organ_count                                         organ_list
# 0              3  [http://purl.obolibrary.org/obo/UBERON_0001004...
# 1              7  [http://purl.obolibrary.org/obo/UBERON_0000059...
# 2              4  [http://purl.obolibrary.org/obo/UBERON_0001004...
# 3              5  [http://purl.obolibrary.org/obo/UBERON_0000948...
# 4              2  [http://purl.obolibrary.org/obo/UBERON_0001270...
# ..           ...                                                ...
# 475           10  [http://purl.obolibrary.org/obo/UBERON_0001004...
# 476            2  [http://purl.obolibrary.org/obo/UBERON_0001255...
# 477            2  [http://purl.obolibrary.org/obo/UBERON_0000955...
# 478            4  [http://purl.obolibrary.org/obo/UBERON_0002370...
# 479            6  [http://purl.obolibrary.org/obo/UBERON_0004537...
#
# [480 rows x 16 columns]

# %%
only_one = df_with_counts[df_with_counts['organ_count'] == 1]
only_one
# Out:
#      gene_name       Ensembl ID        Lineage/ L1 or state  \
# 6          ARX  ENSG00000004848                   endocrine
# 8         IAPP  ENSG00000121351                   endocrine
# 28        ART4  ENSG00000111339      endothelial, lymphatic
# 39      TSPEAR  ENSG00000175894      endothelial, lymphatic
# 40   CADM3-AS1  ENSG00000225670       endothelial, vascular
# 51   ADCYAP1R1  ENSG00000078549                  epithelial
# 53       AMY2A  ENSG00000243480                  epithelial
# 55    ARHGAP40  ENSG00000124143                  epithelial
# 63       CXCL6  ENSG00000124875                  epithelial
# 73       HNF1B  ENSG00000275410                  epithelial
# 75       KCNC3  ENSG00000131398                  epithelial
# 95     SCGB3A2  ENSG00000164265                  epithelial
# 100    SLC15A1  ENSG00000088386                  epithelial
# 101     SLC1A1  ENSG00000106688                  epithelial
# 102   SLC22A31  ENSG00000259803                  epithelial
# 106    SLCO1A2  ENSG00000084453                  epithelial
# 111       TNS4  ENSG00000131746                  epithelial
# 128        DCD  ENSG00000161634   epithelial, eccrine cells
# 130       DSC1  ENSG00000134765   epithelial, keratinocytes
# 134       KRT2  ENSG00000172867   epithelial, keratinocytes
# 147       SIM2  ENSG00000159263      epithelial, melanocyte
# 153    CFAP157  ENSG00000160401   epithelial, multiciliated
# 170      DPPA4  ENSG00000121570     hematopoietic stem cell
# 175      ACER1  ENSG00000167769                Immune cells
# 184    CLEC17A  ENSG00000187912          immune lymphoid, B
# 257     UGT3A2  ENSG00000168671  immune lymphoid, thymoctye
# 296      KCND3  ENSG00000171385             immune, myeloid
# 318    SLC6A12  ENSG00000111181             immune, myeloid
# 354        INA  ENSG00000148798                      neural
# 360       PMP2  ENSG00000147588                      neural
# 368      TTC9B  ENSG00000174521                      neural
# 381      FOXO4  ENSG00000184481          senescence markers
# 418      TECRL  ENSG00000205678     stromal, cardiac muscle
# 424       ACAN  ENSG00000157766        stromal, chondrocyte
# 425    COL10A1  ENSG00000123500        stromal, chondrocyte
# 437     IGSF10  ENSG00000152580        stromal, fibroblasts
# 441     PWWP3B  ENSG00000157502        stromal, fibroblasts
# 443       SHC3  ENSG00000148082        stromal, fibroblasts
# 471       JPH2  ENSG00000149596      stromal, smooth muscle
#
#                                           cell type(s)  \
# 6                                           alpha cell
# 8                                            beta cell
# 28                               Lymphatic Endothelium
# 39                               Lymphatic Endothelium
# 40                                vascular endothelium
# 51                                glandular epithelium
# 53                                         acinar cell
# 55                                     absorptive cell
# 63                                           club cell
# 73                                glandular epithelium
# 75                                glandular epithelium
# 95   submocosal glands, bronchiolar epithelium, ? o...
# 100                                        paneth cell
# 101                                  type I pneumocyte
# 102                                 type II pneumocyte
# 106                                          tuft cell
# 111                                 myoepithelial cell
# 128                            Eccrine secretory cells
# 130                       Differentiated Keratinocytes
# 134                          Spinous to Granular Cells
# 147                                         melanocyte
# 153                                 multiciliated cell
# 170                            hematopoietic stem cell
# 175                                           CD4_RGCC
# 184                                    immature B cell
# 257                          double negative thymocyte
# 296                  conventional dendritic cell, cDC1
# 318                                    Langerhans cell
# 354                                      ganglion cell
# 360                                       schwann cell
# 368                       ganglion cell,sensory neuron
# 381                       with TP53 induces senescence
# 418  atrial cardiac myocyte,ventricular cardiac myo...
# 424                                  chondrocytes, CNS
# 425                          hypertrophic chondrocytes
# 437                                         fibroblast
# 441                                         fibroblast
# 443                                         fibroblast
# 471                                      smooth muscle
#
#                 Rationale/Source Specific Request by specificity flag  \
# 6           Tissue  expert added            pancreas              NaN
# 8           Tissue  expert added            pancreas              NaN
# 28          Tissue  expert added               Ovary              NaN
# 39          Tissue  expert added              Uterus              NaN
# 40          Tissue  expert added              Uterus              NaN
# 51          Tissue  expert added               Ovary              NaN
# 53          Tissue  expert added            pancreas              NaN
# 55              TOP 5 (CZI) List                 NaN              NaN
# 63              TOP 5 (CZI) List                 NaN              NaN
# 73          Tissue  expert added              Uterus              NaN
# 75          Tissue  expert added               Ovary              NaN
# 95                 MxIF Proteins                 NaN              NaN
# 100             TOP 5 (CZI) List                 NaN              NaN
# 101             TOP 5 (CZI) List                 NaN              NaN
# 102             TOP 5 (CZI) List                 NaN              NaN
# 106             TOP 5 (CZI) List                 NaN              NaN
# 111             TOP 5 (CZI) List                 NaN              NaN
# 128         Tissue  expert added                Skin              NaN
# 130         Tissue  expert added                Skin              NaN
# 134         Tissue  expert added                Skin              NaN
# 147             TOP 5 (CZI) List                 NaN              NaN
# 153             TOP 5 (CZI) List                 NaN              NaN
# 170             TOP 5 (CZI) List                 NaN              NaN
# 175         Tissue  expert added                Skin              NaN
# 184             TOP 5 (CZI) List                 NaN              NaN
# 257             TOP 5 (CZI) List                 NaN              NaN
# 296         Tissue  expert added                 NaN              NaN
# 318             TOP 5 (CZI) List                 NaN              NaN
# 354             TOP 5 (CZI) List                 NaN              NaN
# 360             TOP 5 (CZI) List                 NaN              NaN
# 368             TOP 5 (CZI) List                 NaN              NaN
# 381  State Rescue; MxIF Proteins                 NaN              NaN
# 418             TOP 5 (CZI) List                 NaN              NaN
# 424         Tissue  expert added                 IVD              NaN
# 425         Tissue  expert added                 IVD              NaN
# 437         Tissue  expert added               Ovary              NaN
# 441         Tissue  expert added               Ovary              NaN
# 443         Tissue  expert added              Uterus              NaN
# 471         Tissue  expert added      Fallopian Tube              NaN
#
#     Protein/Other name  is_in_10x_multi_panel  \
# 6                  NaN                  False
# 8                  NaN                  False
# 28                 NaN                  False
# 39                 NaN                  False
# 40                 NaN                  False
# 51                 NaN                  False
# 53                 NaN                   True
# 55                 NaN                  False
# 63               CXCL4                   True
# 73                 NaN                  False
# 75                 NaN                  False
# 95                 NaN                  False
# 100                NaN                  False
# 101                NaN                  False
# 102                NaN                  False
# 106                NaN                  False
# 111                NaN                  False
# 128                NaN                  False
# 130                NaN                  False
# 134                NaN                  False
# 147                NaN                  False
# 153                NaN                  False
# 170                NaN                  False
# 175                NaN                  False
# 184                NaN                  False
# 257                NaN                  False
# 296                NaN                  False
# 318                NaN                  False
# 354                NaN                  False
# 360                NaN                  False
# 368                NaN                  False
# 381                NaN                  False
# 418                NaN                  False
# 424                NaN                  False
# 425                NaN                  False
# 437                NaN                  False
# 441                NaN                  False
# 443                NaN                  False
# 471                NaN                  False
#
#                               10x_multi_panel_celltype  \
# 6                                                  NaN
# 8                                                  NaN
# 28                                                 NaN
# 39                                                 NaN
# 40                                                 NaN
# 51                                                 NaN
# 53                 Pancreas - Exocrine glandular cells
# 55                                                 NaN
# 63   General - Fibroblasts,Liver - Cholangiocytes,L...
# 73                                                 NaN
# 75                                                 NaN
# 95                                                 NaN
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
# 106                                                NaN
# 111                                                NaN
# 128                                                NaN
# 130                                                NaN
# 134                                                NaN
# 147                                                NaN
# 153                                                NaN
# 170                                                NaN
# 175                                                NaN
# 184                                                NaN
# 257                                                NaN
# 296                                                NaN
# 318                                                NaN
# 354                                                NaN
# 360                                                NaN
# 368                                                NaN
# 381                                                NaN
# 418                                                NaN
# 424                                                NaN
# 425                                                NaN
# 437                                                NaN
# 441                                                NaN
# 443                                                NaN
# 471                                                NaN
#
#      is_in_Xenium_KIL_panel 10x_panel_designer_comment        hgnc gene_label  \
# 6                     False                        NaN  HGNC:18060        ARX
# 8                     False                        NaN   HGNC:5329       IAPP
# 28                    False                        NaN    HGNC:726       ART4
# 39                    False                        NaN   HGNC:1268     TSPEAR
# 40                    False                        NaN  HGNC:40812  CADM3-AS1
# 51                    False                        NaN    HGNC:242  ADCYAP1R1
# 53                    False                        NaN    HGNC:477      AMY2A
# 55                    False                        NaN  HGNC:16226   ARHGAP40
# 63                    False                        NaN  HGNC:10643      CXCL6
# 73                    False                        NaN  HGNC:11630      HNF1B
# 75                    False                        NaN   HGNC:6235      KCNC3
# 95                     True                        NaN  HGNC:18391    SCGB3A2
# 100                   False                        NaN  HGNC:10920    SLC15A1
# 101                   False                        NaN  HGNC:10939     SLC1A1
# 102                   False                        NaN  HGNC:27091   SLC22A31
# 106                   False                        NaN  HGNC:10956    SLCO1A2
# 111                   False                        NaN  HGNC:24352       TNS4
# 128                   False                        NaN  HGNC:14669        DCD
# 130                   False                        NaN   HGNC:3035       DSC1
# 134                   False                        NaN   HGNC:6439       KRT2
# 147                   False                        NaN  HGNC:10883       SIM2
# 153                   False                        NaN  HGNC:27843    CFAP157
# 170                   False                        NaN  HGNC:19200      DPPA4
# 175                   False                        NaN  HGNC:18356      ACER1
# 184                   False                        NaN  HGNC:34520    CLEC17A
# 257                   False                        NaN  HGNC:27266     UGT3A2
# 296                   False                        NaN   HGNC:6239      KCND3
# 318                   False                        NaN  HGNC:11045    SLC6A12
# 354                   False                        NaN   HGNC:6057        INA
# 360                   False                        NaN   HGNC:9117       PMP2
# 368                   False                        NaN  HGNC:26395      TTC9B
# 381                   False                        NaN   HGNC:7139      FOXO4
# 418                   False                        NaN  HGNC:27365      TECRL
# 424                   False                        NaN    HGNC:319       ACAN
# 425                   False                        NaN   HGNC:2185    COL10A1
# 437                   False                        NaN  HGNC:26384     IGSF10
# 441                   False                        NaN  HGNC:26583     PWWP3B
# 443                   False                        NaN  HGNC:18181       SHC3
# 471                   False                        NaN  HGNC:14202       JPH2
#
#      organ_count                                       organ_list
# 6              1  [http://purl.obolibrary.org/obo/UBERON_0001264]
# 8              1  [http://purl.obolibrary.org/obo/UBERON_0001264]
# 28             1  [http://purl.obolibrary.org/obo/UBERON_0000948]
# 39             1  [http://purl.obolibrary.org/obo/UBERON_0000948]
# 40             1  [http://purl.obolibrary.org/obo/UBERON_0001004]
# 51             1  [http://purl.obolibrary.org/obo/UBERON_0000948]
# 53             1  [http://purl.obolibrary.org/obo/UBERON_0001264]
# 55             1  [http://purl.obolibrary.org/obo/UBERON_0001004]
# 63             1  [http://purl.obolibrary.org/obo/UBERON_0001004]
# 73             1  [http://purl.obolibrary.org/obo/UBERON_0001004]
# 75             1  [http://purl.obolibrary.org/obo/UBERON_0001270]
# 95             1  [http://purl.obolibrary.org/obo/UBERON_0001004]
# 100            1  [http://purl.obolibrary.org/obo/UBERON_0000059]
# 101            1  [http://purl.obolibrary.org/obo/UBERON_0001004]
# 102            1  [http://purl.obolibrary.org/obo/UBERON_0001004]
# 106            1  [http://purl.obolibrary.org/obo/UBERON_0001004]
# 111            1  [http://purl.obolibrary.org/obo/UBERON_0001004]
# 128            1  [http://purl.obolibrary.org/obo/UBERON_0002097]
# 130            1  [http://purl.obolibrary.org/obo/UBERON_0002097]
# 134            1  [http://purl.obolibrary.org/obo/UBERON_0002097]
# 147            1  [http://purl.obolibrary.org/obo/UBERON_0001004]
# 153            1  [http://purl.obolibrary.org/obo/UBERON_0001004]
# 170            1  [http://purl.obolibrary.org/obo/UBERON_0001270]
# 175            1  [http://purl.obolibrary.org/obo/UBERON_0002097]
# 184            1  [http://purl.obolibrary.org/obo/UBERON_0001270]
# 257            1  [http://purl.obolibrary.org/obo/UBERON_0002097]
# 296            1  [http://purl.obolibrary.org/obo/UBERON_0001004]
# 318            1  [http://purl.obolibrary.org/obo/UBERON_0000955]
# 354            1  [http://purl.obolibrary.org/obo/UBERON_0000955]
# 360            1  [http://purl.obolibrary.org/obo/UBERON_0000948]
# 368            1  [http://purl.obolibrary.org/obo/UBERON_0001004]
# 381            1  [http://purl.obolibrary.org/obo/UBERON_0000948]
# 418            1  [http://purl.obolibrary.org/obo/UBERON_0000948]
# 424            1  [http://purl.obolibrary.org/obo/UBERON_0001004]
# 425            1  [http://purl.obolibrary.org/obo/UBERON_0001004]
# 437            1  [http://purl.obolibrary.org/obo/UBERON_0001270]
# 441            1  [http://purl.obolibrary.org/obo/UBERON_0000948]
# 443            1  [http://purl.obolibrary.org/obo/UBERON_0000948]
# 471            1  [http://purl.obolibrary.org/obo/UBERON_0001004]

# %% [markdown]
# ## Not in MOSDAP

# %%
# load data
not_mosdap_hra_genes = pd.read_csv('data/NOT-mosdap-hra-genes.csv')
not_mosdap_hra_pop_genes = pd.read_csv('data/NOT-mosdap-hra-pop-genes.csv')
not_mosdap_kpmp_hubmap_genes = pd.read_csv('data/NOT-mosdap-kpmp-hubmap-genes.csv')

# %%
not_mosdap_hra_genes['source'] = 'hra'
not_mosdap_hra_pop_genes['source'] = 'hra-pop'
not_mosdap_kpmp_hubmap_genes['source'] = 'kpmp'

# %%
df_not_in_mosdap = pd.concat([not_mosdap_hra_genes, not_mosdap_hra_pop_genes, not_mosdap_kpmp_hubmap_genes])
df_not_in_mosdap
# Out:
#               gene_label                                               gene  \
# 0                    A2M                      http://identifiers.org/hgnc/7
# 1    ABC10-43608400O15.1  https://purl.org/ccf/ASCTB-TEMP_abc10-43608400...
# 2                  ABCA1                     http://identifiers.org/hgnc/29
# 3                 ABCA13                  http://identifiers.org/hgnc/14638
# 4                  ABCA3                     http://identifiers.org/hgnc/33
# ..                   ...                                                ...
# 281                 WSB1                  http://identifiers.org/hgnc/19221
# 282                 WWOX                  http://identifiers.org/hgnc/12799
# 283                 ZEB1                  http://identifiers.org/hgnc/11642
# 284                 ZEB2                  http://identifiers.org/hgnc/14881
# 285                ZFPM2                  http://identifiers.org/hgnc/16700
#
#     source
# 0      hra
# 1      hra
# 2      hra
# 3      hra
# 4      hra
# ..     ...
# 281   kpmp
# 282   kpmp
# 283   kpmp
# 284   kpmp
# 285   kpmp
#
# [31342 rows x 3 columns]

# %%
print(f'Unique genes NOT in MOSDAP: {df_not_in_mosdap['gene'].nunique()}')
# Out:
# Unique genes NOT in MOSDAP: 29754

# %% [markdown]
# ## Unique genes by source

# %%
# step 1: drop duplicates on (gene, source)
unique_pairs = df_combined[['gene_label', 'source']
                           ].drop_duplicates(subset=["gene_label", "source"])

# step 2: count per gene
result = (
    unique_pairs.groupby("gene_label")
    .size()
    .reset_index(name="unique_source_count")
)

above_two = result[result['unique_source_count'] > 1]
above_two
# Out:
#     gene_label  unique_source_count
# 1        ABCC9                    2
# 2         ACAN                    2
# 4        ACKR1                    2
# 5        ACTA2                    3
# 6        ACTG2                    2
# ..         ...                  ...
# 457       WIF1                    2
# 459        WT1                    2
# 461       XCL1                    2
# 462       XCL2                    2
# 466     ZNF683                    2
#
# [274 rows x 2 columns]

# %%
# step 1: drop duplicates on (gene, source)
unique_pairs = df_not_in_mosdap[['gene_label', 'source']
                           ].drop_duplicates(subset=["gene_label", "source"])

# step 2: count per gene
result = (
    unique_pairs.groupby("gene_label")
    .size()
    .reset_index(name="unique_source_count")
)

above_two = result[result['unique_source_count'] > 1]
above_two
# Out:
#       gene_label  unique_source_count
# 2            A2M                    2
# 27         ABCA1                    2
# 30        ABCA13                    2
# 32         ABCA3                    2
# 33         ABCA4                    2
# ...          ...                  ...
# 21105      ZFHX3                    2
# 21127      ZFPM2                    2
# 21128  ZFPM2-AS1                    2
# 21151       ZIC1                    2
# 21548  ZNF736P9Y                    2
#
# [1522 rows x 2 columns]

# %%
unique_pairs
# Out:
#     gene_label source
# 0        ABCC9  asctb
# 3         ACAN  asctb
# 4        ACKR1  asctb
# 17       ACTA2  asctb
# 793      ACTG2  asctb
# ..         ...    ...
# 197       SPP1   kpmp
# 198     THEMIS   kpmp
# 205     TPSAB1   kpmp
# 212      TPSB2   kpmp
# 219      VEGFA   kpmp
#
# [775 rows x 2 columns]

# %% [markdown]
# ## Gene by source

# %%
# create indicator table
df_summary = (
    df_all
    .assign(value=1)  # mark presence
    .pivot_table(
        index="gene",
        columns="source",
        values="value",
        aggfunc="max",   # in case duplicates
        fill_value=0
    )
    .reset_index()
)

# optional: rename gene column
df_summary = df_summary.rename(columns={"gene": "Gene_label"})

# %% [markdown]
# ## Export

# %%
no_asctb.to_csv('output/no-asctb.csv', index=False)
not_in_hrapop.to_csv('output/not-in-hra-pop.csv', index=False)
not_in_kpmp.to_csv('output/not-in-kpmp.csv', index=False)
only_one.to_csv('output/only-one-tissue-hra-pop.csv', index=False)
df_mosdap.to_csv('output/mosdap_gene_list_with_hgnc.csv', index=False)
df_not_in_mosdap.to_csv('output/not-in-mosdap.csv', index=False)
df_combined.to_csv('output/genes-hra-resources-combined.csv', index=False)
