# %% [markdown]
# # A notebook to to get true and predicted CTann and RUI for HRApop atlas datasets

# %% [markdown]
# ## Goal
#
# See [this GitHub issue](https://github.com/x-atlas-consortia/hra-pop/issues/100)

# %% [markdown]
# ## Import libraries

# %%
# %pip install requests pandas seaborn matplotlib scipy scikit-learn hra_api_client ipywidgets IPython

import time
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import json
from pprint import pprint
from scipy.spatial.distance import cosine
from sklearn.metrics.pairwise import cosine_similarity
from ipywidgets import IntProgress
from IPython.display import display
# Out:
# Requirement already satisfied: requests in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (2.32.3)
# Requirement already satisfied: pandas in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (2.2.2)
# Requirement already satisfied: seaborn in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: matplotlib in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (3.9.1)
# Requirement already satisfied: scipy in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (1.14.0)
# Requirement already satisfied: scikit-learn in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (1.5.1)
# Requirement already satisfied: hra_api_client in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (0.10.0)
# Requirement already satisfied: ipywidgets in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (8.1.5)
# Requirement already satisfied: IPython in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (8.26.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (from requests) (2024.7.4)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: pydantic>=2 in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (from hra_api_client) (2.8.2)
# Requirement already satisfied: typing-extensions>=4.7.1 in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (from hra_api_client) (4.12.2)
# Requirement already satisfied: comm>=0.1.3 in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: decorator in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (from IPython) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (from IPython) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (from IPython) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (from IPython) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (from IPython) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (from IPython) (0.6.3)
# Requirement already satisfied: colorama in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (from IPython) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (from jedi>=0.16->IPython) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->IPython) (0.2.13)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (from pydantic>=2->hra_api_client) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (from pydantic>=2->hra_api_client) (2.20.1)
# Requirement already satisfied: six>=1.5 in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (from stack-data->IPython) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (from stack-data->IPython) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\abueckle\documents\github\hra-cell-type-populations-supporting-information\.venv\lib\site-packages (from stack-data->IPython) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import hra_api_client

from hra_api_client.api import v1_api as default_api
from hra_api_client.models.sparql_query_request import SparqlQueryRequest

# %% [markdown]
# Configure HRA API client and create API instance

# %%
# may need to remove `v1`
configuration = hra_api_client.Configuration(
    host="https://apps.humanatlas.io/api"
)

api_client = hra_api_client.ApiClient(configuration)
api_instance = default_api.V1Api(api_client)

# %% [markdown]
# ## Set global variables

# %%
hra_pop_version = "v0.10.3"

# %% [markdown]
# ## Load data

# %%
# df_x = pd.read_csv("data/validation-v7-ctann-rui.csv")
df_x = pd.read_csv(
  f"../../../hra-pop/output-data/{hra_pop_version}/reports/atlas/validation-v7-x-axis.csv")
df_y = pd.read_csv(
  f"../../../hra-pop/output-data/{hra_pop_version}/reports/atlas/validation-v7-y-axis.csv")

# %% [markdown]
# ## Prepare data for visualization and visualize

# %%
df_x
# Out:
#         sex                                             sample  \
# 0    Female  https://doi.org/10.1126/science.abl4290#GTEX-1...
# 1    Female  https://doi.org/10.1126/science.abl4290#GTEX-1...
# 2    Female  https://doi.org/10.1126/science.abl4290#GTEX-1...
# 3    Female  https://api.cellxgene.cziscience.com/dp/v1/col...
# 4    Female  https://api.cellxgene.cziscience.com/dp/v1/col...
# ..      ...                                                ...
# 902    Male  https://entity.api.hubmapconsortium.org/entiti...
# 903    Male  https://entity.api.hubmapconsortium.org/entiti...
# 904    Male  https://entity.api.hubmapconsortium.org/entiti...
# 905    Male  https://entity.api.hubmapconsortium.org/entiti...
# 906    Male  https://entity.api.hubmapconsortium.org/entiti...
#
#                                           rui_location  \
# 0    http://purl.org/ccf/1.5/3b5d2036-3c56-4cf8-808...
# 1    http://purl.org/ccf/1.5/3b5d2036-3c56-4cf8-808...
# 2    http://purl.org/ccf/1.5/3b5d2036-3c56-4cf8-808...
# 3    http://purl.org/ccf/1.5/9abfed4e-2fde-4d80-a8a...
# 4    http://purl.org/ccf/1.5/9abfed4e-2fde-4d80-a8a...
# ..                                                 ...
# 902  http://purl.org/ccf/1.5/e21afc3c-3a7c-4717-90d...
# 903  http://purl.org/ccf/1.5/b2aca02c-9559-4869-b55...
# 904  http://purl.org/ccf/1.5/e43280c9-840b-481f-a8a...
# 905  http://purl.org/ccf/1.5/fb6bb0ea-5ba7-44e2-90a...
# 906  http://purl.org/ccf/1.5/cc08d64c-5d75-4995-b3b...
#
#                                                dataset        tool  \
# 0    https://doi.org/10.1126/science.abl4290#GTEX-1...        popv
# 1    https://doi.org/10.1126/science.abl4290#GTEX-1...        popv
# 2    https://doi.org/10.1126/science.abl4290#GTEX-1...        popv
# 3    https://api.cellxgene.cziscience.com/dp/v1/col...     azimuth
# 4    https://api.cellxgene.cziscience.com/dp/v1/col...  celltypist
# ..                                                 ...         ...
# 902  https://entity.api.hubmapconsortium.org/entiti...        popv
# 903  https://entity.api.hubmapconsortium.org/entiti...        popv
# 904  https://entity.api.hubmapconsortium.org/entiti...        popv
# 905  https://entity.api.hubmapconsortium.org/entiti...        popv
# 906  https://entity.api.hubmapconsortium.org/entiti...        popv
#
#                modality                                      organ  \
# 0    sc_transcriptomics  Set of lactiferous glands in right breast
# 1    sc_transcriptomics  Set of lactiferous glands in right breast
# 2    sc_transcriptomics  Set of lactiferous glands in right breast
# 3    sc_transcriptomics                                      heart
# 4    sc_transcriptomics                                      heart
# ..                  ...                                        ...
# 902  sc_transcriptomics                                     spleen
# 903  sc_transcriptomics                            urinary bladder
# 904  sc_transcriptomics                            urinary bladder
# 905  sc_transcriptomics                            urinary bladder
# 906  sc_transcriptomics                            urinary bladder
#
#             organId  datasetVsRuiSim
# 0         FMA:57987         0.950079
# 1         FMA:57987         0.944614
# 2         FMA:57987         0.934930
# 3    UBERON:0000948         0.911356
# 4    UBERON:0000948         0.701952
# ..              ...              ...
# 902  UBERON:0002106         0.744703
# 903  UBERON:0001255         1.000000
# 904  UBERON:0001255         0.998475
# 905  UBERON:0001255         0.913469
# 906  UBERON:0001255         0.966213
#
# [907 rows x 9 columns]

# %%
df_y
# Out:
#         sex                                       rui_location  \
# 0    Female  http://purl.org/ccf/1.5/2156f837-2ab2-4305-8e7...
# 1    Female  http://purl.org/ccf/1.5/8f99a469-7d51-46dc-919...
# 2    Female  http://purl.org/ccf/1.5/f6512db4-2809-4ffe-864...
# 3      Male  http://purl.org/ccf/1.5/886e391d-0151-46d3-8a5...
# 4      Male  http://purl.org/ccf/1.5/da28394d-789a-4fba-842...
# ..      ...                                                ...
# 927    Male  http://purl.org/ccf/1.5/aba1ebe3-af18-40cc-b53...
# 928    Male  http://purl.org/ccf/1.5/ca23f77c-a3cd-453f-bbe...
# 929    Male  http://purl.org/ccf/1.5/d662fd53-e925-4921-8d8...
# 930    Male  http://purl.org/ccf/1.5/df0b33f7-371a-47a4-a63...
# 931    Male  http://purl.org/ccf/1.5/fd76b9bb-85b0-4dd0-8e6...
#
#                                                dataset        tool  \
# 0    https://api.cellxgene.cziscience.com/dp/v1/col...  celltypist
# 1    https://entity.api.hubmapconsortium.org/entiti...     azimuth
# 2    https://doi.org/10.1126/science.abl4290#GTEX-1...        popv
# 3    https://entity.api.hubmapconsortium.org/entiti...        popv
# 4    https://entity.api.hubmapconsortium.org/entiti...        popv
# ..                                                 ...         ...
# 927  https://entity.api.hubmapconsortium.org/entiti...        popv
# 928  https://entity.api.hubmapconsortium.org/entiti...     azimuth
# 929  https://entity.api.hubmapconsortium.org/entiti...        popv
# 930  https://entity.api.hubmapconsortium.org/entiti...     azimuth
# 931  https://entity.api.hubmapconsortium.org/entiti...  celltypist
#
#                                          predicted_rui  similarity
# 0    http://purl.org/ccf/1.5/05c11830-1526-4472-bd1...    0.441815
# 1    http://purl.org/ccf/1.5/731ade72-cdb7-4262-8be...    0.792217
# 2    http://purl.org/ccf/1.5/ca476545-5b98-476c-b2f...    0.951883
# 3    http://purl.org/ccf/1.5/f6512db4-2809-4ffe-864...    0.957861
# 4    http://purl.org/ccf/1.5/f6512db4-2809-4ffe-864...    0.945847
# ..                                                 ...         ...
# 927  http://purl.org/ccf/1.5/fd4fcec2-93c3-428f-ad3...    0.925139
# 928  http://purl.org/ccf/1.5/1f414fc5-cb93-45b7-a1b...    0.855982
# 929  http://purl.org/ccf/1.5/aba1ebe3-af18-40cc-b53...    0.991318
# 930  http://purl.org/ccf/1.5/db35f27d-313f-4dd6-819...    0.911654
# 931  http://purl.org/ccf/1.5/502f175c-9d55-4341-b6f...    0.755117
#
# [932 rows x 6 columns]

# %% [markdown]
# ## Compute similarity scores for %AS

# %% [markdown]
# ### Define functions

# %%
def dict_to_vec(dict1: dict, dict2: dict):
  """Takes two dictionaries and returns a tuple of nornalized lists with values (0 if key not present)
  Args:
    dict1 (dict): dictionary 1
    dict2 (dict): dictionary 2

  Returns:
    result (tuple): a tuple with normalized lists
  """

  # initialize result
  dict1_list = []
  dict2_list = []

  # handle shared keys
  shared_keys = set(dict1['collisions'].keys()).intersection(
    dict2['collisions'].keys())

  for key in shared_keys:
    dict1_list.append(dict1['collisions'][key])
    dict2_list.append(dict2['collisions'][key])

  # handle not shared keys
  keys_in_dict1_not_in_dict2 = dict1.keys() - dict2.keys()
  for key in keys_in_dict1_not_in_dict2:
    dict1[key] = 0
  keys_in_dict2_not_in_dict1 = dict2.keys() - dict1.keys()
  for key in keys_in_dict2_not_in_dict1:
    dict1[key] = 0
  return (dict1_list, dict2_list)


def get_as_collision_items(iri: str, get_organ = False):
  """A function to get AS collision items for an IRI (extraction site) and return a dictionary with AS UBERON ID and intersection percentage of the extraction site. 
  This uses https://apps.humanatlas.io/api/#get-/v1/extraction-site to get the rui_location data given the IRI and https://apps.humanatlas.io/api/#post-/v1/collisions to get the collisions

  Args:
    iri (str): an IRI for an extraction site

  Returns:
    a dictionary with the IRI and a nested dictionary with collisions (ID and percentage) 
  """
  result = {
  }

  # get extraction site
  # base_url_extraction_site = "https://apps.humanatlas.io/api/v1/extraction-site?iri="
  # extraction_site = ""
  # response = requests.get(base_url_extraction_site+iri)
  # extraction_site = api_instance.extraction_site(iri)

  try:
    # extraction_site = json.loads(response)
    extraction_site = api_instance.extraction_site(iri)
  except Exception as e:
    print(f"Non-success status code given {iri}: {e}")
    return result  # Or use an empty dictionary, or any other placeholder
  
  try:
    # send extraction site to /collisions endpoints
    collisions = api_instance.collisions(extraction_site)
    for item in collisions:
      result[item['representation_of']] = item['percentage_of_tissue_block']

    if get_organ:
        result['organ'] = extraction_site['placement']['target']
  except Exception as e:
    print(f"Collision error with IRI {iri}: {e}")
    return result  # Or use an empty dictionary, or any other placeholder

  return result


def compute_cosine_similarity_by_as_percentage(iri_1: str, iri_2: str):
  """Takes two IRIs of extraction sites and returns the cosine similarity of their AS percentages

  Args:
          iri_1 (str): An IRI for an extraction site
          iri_2 (str): An IRI for an extraction site

Returns: 
          similarity (float): A cosine similarity
  """

  # Get AS collision items as dict
  dict1 = get_as_collision_items(iri_1)
  dict2 = get_as_collision_items(iri_2)

  # Get a combined set of all keys from both dictionaries
  all_keys = set(dict1.keys()).union(dict2.keys())

  # Create the two lists of values
  values1 = [dict1.get(key, 0) for key in all_keys]
  values2 = [dict2.get(key, 0) for key in all_keys]

  # Compute cosine similarity
  cosine_similarity_value = cosine_similarity([values1], [values2])
  # print(f"Got new sim: {cosine_similarity_value}")
  return float(cosine_similarity_value[0][0])

# %% [markdown]
# ### Loop through pairs of extraction sites (true and predicted) in validation and compute AS% similarity score

# %%
# handle exception for extraction site endpoint
# set up session. Can add HuBMAP token after ?token= to get private data
session_configuration = {"dataSources": [
    "https://apps.humanatlas.io/api/ds-graph/hubmap",
    "https://apps.humanatlas.io/api/ds-graph/sennet",
    "https://apps.humanatlas.io/api/ds-graph/gtex",
    "https://hubmapconsortium.github.io/hra-registrations/federated/rui_locations.jsonld",
    "https://hubmapconsortium.github.io/hra-registrations/staging/vccf-federated/rui_locations.jsonld",
    "https://hubmapconsortium.github.io/hra-registrations/staging/kpmp-kidney-jain-2023/rui_locations.jsonld"
]}

# Get a session token for this configuration
api_response = api_instance.session_token(session_configuration)
token = api_response.token
print(token)
# Out:
# c5b2cb62e42c399c281ae1cf421479cd

# %%
db_ready = False
while not db_ready:
    api_response = api_instance.db_status(token)
    print(api_response)
    if api_response.status == 'Ready':
        db_ready = True
    else:
        print('Database not ready yet! Retrying...')
        time.sleep(2)
# Out:
# status='Ready' checkback=3600000 load_time=346 message='Dataset ready'

# %%
# global counter
counter = 0

# instantiate progress bar
f = IntProgress(min=0, max=len(df_y.index))

# %%
# Define a helper function with try-except logic
def safe_cosine_similarity(rui_location, predicted_rui):
  """A function to wrap compute_cosine_similarity_by_as_percentage with a try-except block

  Args:
      rui_location (_type_): _description_
      predicted_rui (_type_): _description_

  Returns:
      _type_: _description_
  """
  
  global counter 
  global f
  counter += 1
  f.value += 1 # signal to increment the progress bar
  
  print(f"Now at row {counter}")
  try:
      return compute_cosine_similarity_by_as_percentage(rui_location, predicted_rui)
  except Exception as e:
      print(f"Error computing similarity: {e} caused by {rui_location} and {predicted_rui}")
      return f"There was an exception." 


display(f)  # display the bar

# add new column with cosine similarity between true and predicted rui
df_y['as_percentage_cosine_sim'] = df_y.apply(
    lambda row: safe_cosine_similarity(
        row['rui_location'], row['predicted_rui']),
    axis=1
)

# print for review inline
df_y
# Out:
# IntProgress(value=0, max=932)
# Now at row 1
# Now at row 2
# Now at row 3
# Now at row 4
# Now at row 5
# Now at row 6
# Now at row 7
# Now at row 8
# Now at row 9
# Now at row 10
# Now at row 11
# Now at row 12
# Now at row 13
# Now at row 14
# Now at row 15
# Now at row 16
# Now at row 17
# Now at row 18
# Now at row 19
# Now at row 20
# Now at row 21
# Now at row 22
# Now at row 23
# Now at row 24
# Now at row 25
# Now at row 26
# Now at row 27
# Now at row 28
# Now at row 29
# Now at row 30
# Now at row 31
# Now at row 32
# Now at row 33
# Now at row 34
# Now at row 35
# Now at row 36
# Now at row 37
# Now at row 38
# Now at row 39
# Now at row 40
# Now at row 41
# Now at row 42
# Now at row 43
# Now at row 44
# Now at row 45
# Now at row 46
# Now at row 47
# Now at row 48
# Now at row 49
# Now at row 50
# Now at row 51
# Now at row 52
# Now at row 53
# Now at row 54
# Now at row 55
# Now at row 56
# Now at row 57
# Now at row 58
# Now at row 59
# Now at row 60
# Now at row 61
# Now at row 62
# Now at row 63
# Now at row 64
# Now at row 65
# Now at row 66
# Now at row 67
# Now at row 68
# Now at row 69
# Now at row 70
# Now at row 71
# Now at row 72
# Now at row 73
# Now at row 74
# Now at row 75
# Now at row 76
# Now at row 77
# Now at row 78
# Now at row 79
# Now at row 80
# Now at row 81
# Now at row 82
# Now at row 83
# Now at row 84
# Now at row 85
# Now at row 86
# Now at row 87
# Now at row 88
# Now at row 89
# Now at row 90
# Now at row 91
# Now at row 92
# Now at row 93
# Now at row 94
# Now at row 95
# Now at row 96
# Now at row 97
# Now at row 98
# Now at row 99
# Now at row 100
# Now at row 101
# Now at row 102
# Now at row 103
# Now at row 104
# Now at row 105
# Now at row 106
# Now at row 107
# Now at row 108
# Now at row 109
# Now at row 110
# Now at row 111
# Now at row 112
# Now at row 113
# Now at row 114
# Now at row 115
# Now at row 116
# Now at row 117
# Now at row 118
# Now at row 119
# Now at row 120
# Now at row 121
# Now at row 122
# Now at row 123
# Now at row 124
# Now at row 125
# Now at row 126
# Now at row 127
# Now at row 128
# Now at row 129
# Now at row 130
# Now at row 131
# Now at row 132
# Now at row 133
# Now at row 134
# Now at row 135
# Now at row 136
# Now at row 137
# Now at row 138
# Now at row 139
# Now at row 140
# Now at row 141
# Now at row 142
# Now at row 143
# Now at row 144
# Now at row 145
# Now at row 146
# Now at row 147
# Now at row 148
# Now at row 149
# Now at row 150
# Now at row 151
# Now at row 152
# Now at row 153
# Now at row 154
# Now at row 155
# Now at row 156
# Now at row 157
# Now at row 158
# Now at row 159
# Now at row 160
# Now at row 161
# Now at row 162
# Now at row 163
# Now at row 164
# Now at row 165
# Now at row 166
# Now at row 167
# Now at row 168
# Now at row 169
# Now at row 170
# Now at row 171
# Now at row 172
# Now at row 173
# Now at row 174
# Now at row 175
# Now at row 176
# Now at row 177
# Now at row 178
# Now at row 179
# Now at row 180
# Now at row 181
# Now at row 182
# Now at row 183
# Now at row 184
# Non-success status code given http://purl.org/ccf/1.5/84d568f4-d72d-47c9-b556-afbf447533ad: (404)
# Reason: Not Found
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '25', 'Connection': 'keep-alive', 'Cache-Control': 'public, max-age=86400, stale-while-revalidate=600, stale-if-error=600', 'content-security-policy': "base-uri 'self' cdn.humanatlas.io cdn.jsdelivr.net;script-src 'self' 'unsafe-inline' 'unsafe-eval' cdn.humanatlas.io cdn.jsdelivr.net unpkg.com www.googletagmanager.com;img-src 'self' 'unsafe-eval' cdn.humanatlas.io cdn.jsdelivr.net unpkg.com www.googletagmanager.com;connect-src *;default-src 'self';font-src 'self' https: data:;form-action 'self';frame-ancestors 'self';object-src 'none';script-src-attr 'none';style-src 'self' https: 'unsafe-inline';upgrade-insecure-requests", 'cross-origin-opener-policy': 'same-origin', 'cross-origin-resource-policy': 'same-origin', 'Date': 'Wed, 20 Nov 2024 16:54:02 GMT', 'ETag': 'W/"19-6bBBrG5xJiEq6z4HdnaRbu7qYcg"', 'origin-agent-cluster': '?1', 'referrer-policy': 'no-referrer', 'strict-transport-security': 'max-age=15552000; includeSubDomains', 'x-content-type-options': 'nosniff', 'x-dns-prefetch-control': 'off', 'x-download-options': 'noopen', 'x-frame-options': 'SAMEORIGIN', 'x-permitted-cross-domain-policies': 'none', 'x-xss-protection': '0', 'x-envoy-upstream-service-time': '55', 'Server': 'envoy', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 51a9fe879233bcdaa87b146359af2e0c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'ORD51-C4', 'Alt-Svc': 'h3=":443"; ma=86400', 'X-Amz-Cf-Id': 'D_okm6HIp1tkS0MDiUdyd4mLe0VJVhFE2Eg4c-zyMEpQtnkdqcxlrw==', 'Age': '563', 'Vary': 'Origin'})
# HTTP response body: Extraction site not found
#
# Now at row 185
# Now at row 186
# Now at row 187
# Now at row 188
# Now at row 189
# Now at row 190
# Now at row 191
# Now at row 192
# Now at row 193
# Now at row 194
# Now at row 195
# Now at row 196
# Now at row 197
# Now at row 198
# Now at row 199
# Now at row 200
# Now at row 201
# Now at row 202
# Now at row 203
# Now at row 204
# Now at row 205
# Now at row 206
# Now at row 207
# Now at row 208
# Now at row 209
# Now at row 210
# Now at row 211
# Now at row 212
# Now at row 213
# Now at row 214
# Now at row 215
# Now at row 216
# Now at row 217
# Now at row 218
# Now at row 219
# Now at row 220
# Now at row 221
# Now at row 222
# Now at row 223
# Now at row 224
# Now at row 225
# Now at row 226
# Now at row 227
# Now at row 228
# Now at row 229
# Now at row 230
# Now at row 231
# Now at row 232
# Now at row 233
# Now at row 234
# Now at row 235
# Now at row 236
# Now at row 237
# Now at row 238
# Now at row 239
# Now at row 240
# Now at row 241
# Now at row 242
# Now at row 243
# Now at row 244
# Now at row 245
# Now at row 246
# Now at row 247
# Now at row 248
# Now at row 249
# Now at row 250
# Now at row 251
# Now at row 252
# Now at row 253
# Now at row 254
# Now at row 255
# Now at row 256
# Now at row 257
# Now at row 258
# Now at row 259
# Now at row 260
# Now at row 261
# Now at row 262
# Now at row 263
# Now at row 264
# Now at row 265
# Now at row 266
# Now at row 267
# Now at row 268
# Now at row 269
# Now at row 270
# Now at row 271
# Now at row 272
# Now at row 273
# Now at row 274
# Now at row 275
# Now at row 276
# Now at row 277
# Now at row 278
# Now at row 279
# Now at row 280
# Now at row 281
# Now at row 282
# Now at row 283
# Now at row 284
# Now at row 285
# Now at row 286
# Now at row 287
# Now at row 288
# Now at row 289
# Now at row 290
# Now at row 291
# Now at row 292
# Now at row 293
# Now at row 294
# Now at row 295
# Now at row 296
# Now at row 297
# Now at row 298
# Now at row 299
# Now at row 300
# Now at row 301
# Now at row 302
# Now at row 303
# Now at row 304
# Now at row 305
# Now at row 306
# Now at row 307
# Now at row 308
# Now at row 309
# Now at row 310
# Now at row 311
# Now at row 312
# Now at row 313
# Now at row 314
# Now at row 315
# Now at row 316
# Now at row 317
# Now at row 318
# Now at row 319
# Now at row 320
# Now at row 321
# Now at row 322
# Now at row 323
# Now at row 324
# Now at row 325
# Now at row 326
# Now at row 327
# Non-success status code given http://purl.org/ccf/1.5/112ef351-579d-40a1-a939-9a80dc94b909: (404)
# Reason: Not Found
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '25', 'Connection': 'keep-alive', 'Cache-Control': 'public, max-age=86400, stale-while-revalidate=600, stale-if-error=600', 'content-security-policy': "base-uri 'self' cdn.humanatlas.io cdn.jsdelivr.net;script-src 'self' 'unsafe-inline' 'unsafe-eval' cdn.humanatlas.io cdn.jsdelivr.net unpkg.com www.googletagmanager.com;img-src 'self' 'unsafe-eval' cdn.humanatlas.io cdn.jsdelivr.net unpkg.com www.googletagmanager.com;connect-src *;default-src 'self';font-src 'self' https: data:;form-action 'self';frame-ancestors 'self';object-src 'none';script-src-attr 'none';style-src 'self' https: 'unsafe-inline';upgrade-insecure-requests", 'cross-origin-opener-policy': 'same-origin', 'cross-origin-resource-policy': 'same-origin', 'Date': 'Wed, 20 Nov 2024 16:54:26 GMT', 'ETag': 'W/"19-6bBBrG5xJiEq6z4HdnaRbu7qYcg"', 'origin-agent-cluster': '?1', 'referrer-policy': 'no-referrer', 'strict-transport-security': 'max-age=15552000; includeSubDomains', 'x-content-type-options': 'nosniff', 'x-dns-prefetch-control': 'off', 'x-download-options': 'noopen', 'x-frame-options': 'SAMEORIGIN', 'x-permitted-cross-domain-policies': 'none', 'x-xss-protection': '0', 'x-envoy-upstream-service-time': '41', 'Server': 'envoy', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 51a9fe879233bcdaa87b146359af2e0c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'ORD51-C4', 'Alt-Svc': 'h3=":443"; ma=86400', 'X-Amz-Cf-Id': 'QMJ9QVvHcg5N6zzvfS2rkoxKLeW2EoA9qoekpKLTUelXvvU0KZCj0w==', 'Age': '552', 'Vary': 'Origin'})
# HTTP response body: Extraction site not found
#
# Now at row 328
# Now at row 329
# Now at row 330
# Now at row 331
# Now at row 332
# Now at row 333
# Now at row 334
# Now at row 335
# Now at row 336
# Now at row 337
# Now at row 338
# Now at row 339
# Now at row 340
# Now at row 341
# Now at row 342
# Non-success status code given http://purl.org/ccf/1.5/112ef351-579d-40a1-a939-9a80dc94b909: (404)
# Reason: Not Found
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '25', 'Connection': 'keep-alive', 'Cache-Control': 'public, max-age=86400, stale-while-revalidate=600, stale-if-error=600', 'content-security-policy': "base-uri 'self' cdn.humanatlas.io cdn.jsdelivr.net;script-src 'self' 'unsafe-inline' 'unsafe-eval' cdn.humanatlas.io cdn.jsdelivr.net unpkg.com www.googletagmanager.com;img-src 'self' 'unsafe-eval' cdn.humanatlas.io cdn.jsdelivr.net unpkg.com www.googletagmanager.com;connect-src *;default-src 'self';font-src 'self' https: data:;form-action 'self';frame-ancestors 'self';object-src 'none';script-src-attr 'none';style-src 'self' https: 'unsafe-inline';upgrade-insecure-requests", 'cross-origin-opener-policy': 'same-origin', 'cross-origin-resource-policy': 'same-origin', 'Date': 'Wed, 20 Nov 2024 16:54:26 GMT', 'ETag': 'W/"19-6bBBrG5xJiEq6z4HdnaRbu7qYcg"', 'origin-agent-cluster': '?1', 'referrer-policy': 'no-referrer', 'strict-transport-security': 'max-age=15552000; includeSubDomains', 'x-content-type-options': 'nosniff', 'x-dns-prefetch-control': 'off', 'x-download-options': 'noopen', 'x-frame-options': 'SAMEORIGIN', 'x-permitted-cross-domain-policies': 'none', 'x-xss-protection': '0', 'x-envoy-upstream-service-time': '41', 'Server': 'envoy', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 51a9fe879233bcdaa87b146359af2e0c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'ORD51-C4', 'Alt-Svc': 'h3=":443"; ma=86400', 'X-Amz-Cf-Id': '3iuTMC7t-hYEQ1y34nat7f9je2T6Uu2NjDR1AjiYl8D1FCiml_pBYw==', 'Age': '554', 'Vary': 'Origin'})
# HTTP response body: Extraction site not found
#
# Now at row 343
# Now at row 344
# Now at row 345
# Now at row 346
# Now at row 347
# Now at row 348
# Now at row 349
# Now at row 350
# Now at row 351
# Now at row 352
# Now at row 353
# Now at row 354
# Now at row 355
# Now at row 356
# Now at row 357
# Now at row 358
# Now at row 359
# Now at row 360
# Now at row 361
# Now at row 362
# Now at row 363
# Now at row 364
# Now at row 365
# Now at row 366
# Now at row 367
# Now at row 368
# Now at row 369
# Now at row 370
# Now at row 371
# Now at row 372
# Now at row 373
# Now at row 374
# Now at row 375
# Now at row 376
# Now at row 377
# Now at row 378
# Now at row 379
# Now at row 380
# Now at row 381
# Now at row 382
# Now at row 383
# Now at row 384
# Now at row 385
# Now at row 386
# Now at row 387
# Now at row 388
# Now at row 389
# Now at row 390
# Now at row 391
# Now at row 392
# Now at row 393
# Now at row 394
# Now at row 395
# Now at row 396
# Now at row 397
# Now at row 398
# Now at row 399
# Now at row 400
# Now at row 401
# Now at row 402
# Now at row 403
# Now at row 404
# Now at row 405
# Now at row 406
# Now at row 407
# Now at row 408
# Now at row 409
# Now at row 410
# Now at row 411
# Now at row 412
# Now at row 413
# Now at row 414
# Now at row 415
# Now at row 416
# Now at row 417
# Now at row 418
# Now at row 419
# Now at row 420
# Now at row 421
# Now at row 422
# Now at row 423
# Now at row 424
# Now at row 425
# Now at row 426
# Now at row 427
# Now at row 428
# Now at row 429
# Now at row 430
# Now at row 431
# Now at row 432
# Now at row 433
# Now at row 434
# Now at row 435
# Now at row 436
# Now at row 437
# Now at row 438
# Now at row 439
# Now at row 440
# Now at row 441
# Now at row 442
# Now at row 443
# Now at row 444
# Now at row 445
# Now at row 446
# Now at row 447
# Now at row 448
# Now at row 449
# Now at row 450
# Now at row 451
# Now at row 452
# Now at row 453
# Now at row 454
# Now at row 455
# Now at row 456
# Now at row 457
# Now at row 458
# Now at row 459
# Now at row 460
# Now at row 461
# Now at row 462
# Now at row 463
# Now at row 464
# Now at row 465
# Now at row 466
# Now at row 467
# Now at row 468
# Now at row 469
# Now at row 470
# Now at row 471
# Now at row 472
# Now at row 473
# Now at row 474
# Now at row 475
# Now at row 476
# Now at row 477
# Now at row 478
# Now at row 479
# Now at row 480
# Now at row 481
# Now at row 482
# Now at row 483
# Now at row 484
# Now at row 485
# Now at row 486
# Now at row 487
# Now at row 488
# Now at row 489
# Now at row 490
# Now at row 491
# Now at row 492
# Now at row 493
# Now at row 494
# Now at row 495
# Now at row 496
# Now at row 497
# Now at row 498
# Now at row 499
# Now at row 500
# Now at row 501
# Now at row 502
# Now at row 503
# Now at row 504
# Now at row 505
# Now at row 506
# Now at row 507
# Now at row 508
# Now at row 509
# Now at row 510
# Now at row 511
# Now at row 512
# Now at row 513
# Now at row 514
# Now at row 515
# Now at row 516
# Now at row 517
# Now at row 518
# Now at row 519
# Now at row 520
# Now at row 521
# Now at row 522
# Now at row 523
# Now at row 524
# Now at row 525
# Now at row 526
# Now at row 527
# Now at row 528
# Now at row 529
# Now at row 530
# Now at row 531
# Now at row 532
# Now at row 533
# Now at row 534
# Now at row 535
# Now at row 536
# Now at row 537
# Now at row 538
# Now at row 539
# Now at row 540
# Now at row 541
# Now at row 542
# Now at row 543
# Now at row 544
# Now at row 545
# Now at row 546
# Now at row 547
# Now at row 548
# Now at row 549
# Now at row 550
# Now at row 551
# Now at row 552
# Now at row 553
# Now at row 554
# Now at row 555
# Now at row 556
# Now at row 557
# Now at row 558
# Now at row 559
# Now at row 560
# Now at row 561
# Now at row 562
# Now at row 563
# Now at row 564
# Now at row 565
# Now at row 566
# Now at row 567
# Now at row 568
# Now at row 569
# Now at row 570
# Now at row 571
# Now at row 572
# Now at row 573
# Now at row 574
# Now at row 575
# Now at row 576
# Now at row 577
# Now at row 578
# Now at row 579
# Now at row 580
# Now at row 581
# Now at row 582
# Now at row 583
# Now at row 584
# Now at row 585
# Now at row 586
# Now at row 587
# Now at row 588
# Now at row 589
# Now at row 590
# Now at row 591
# Now at row 592
# Now at row 593
# Now at row 594
# Now at row 595
# Now at row 596
# Now at row 597
# Now at row 598
# Now at row 599
# Now at row 600
# Now at row 601
# Now at row 602
# Now at row 603
# Now at row 604
# Now at row 605
# Now at row 606
# Now at row 607
# Now at row 608
# Now at row 609
# Now at row 610
# Now at row 611
# Now at row 612
# Now at row 613
# Now at row 614
# Now at row 615
# Now at row 616
# Now at row 617
# Now at row 618
# Now at row 619
# Now at row 620
# Now at row 621
# Now at row 622
# Now at row 623
# Now at row 624
# Now at row 625
# Now at row 626
# Now at row 627
# Now at row 628
# Now at row 629
# Now at row 630
# Now at row 631
# Now at row 632
# Now at row 633
# Now at row 634
# Now at row 635
# Now at row 636
# Now at row 637
# Now at row 638
# Now at row 639
# Now at row 640
# Now at row 641
# Now at row 642
# Now at row 643
# Now at row 644
# Now at row 645
# Now at row 646
# Now at row 647
# Now at row 648
# Now at row 649
# Now at row 650
# Now at row 651
# Now at row 652
# Now at row 653
# Now at row 654
# Now at row 655
# Now at row 656
# Now at row 657
# Now at row 658
# Now at row 659
# Now at row 660
# Now at row 661
# Now at row 662
# Now at row 663
# Now at row 664
# Now at row 665
# Now at row 666
# Now at row 667
# Now at row 668
# Now at row 669
# Now at row 670
# Now at row 671
# Now at row 672
# Now at row 673
# Now at row 674
# Now at row 675
# Now at row 676
# Now at row 677
# Now at row 678
# Now at row 679
# Now at row 680
# Now at row 681
# Now at row 682
# Now at row 683
# Now at row 684
# Now at row 685
# Now at row 686
# Now at row 687
# Now at row 688
# Now at row 689
# Now at row 690
# Now at row 691
# Now at row 692
# Now at row 693
# Now at row 694
# Now at row 695
# Now at row 696
# Now at row 697
# Now at row 698
# Now at row 699
# Now at row 700
# Now at row 701
# Now at row 702
# Now at row 703
# Now at row 704
# Now at row 705
# Now at row 706
# Now at row 707
# Now at row 708
# Now at row 709
# Now at row 710
# Now at row 711
# Now at row 712
# Now at row 713
# Now at row 714
# Now at row 715
# Now at row 716
# Now at row 717
# Now at row 718
# Now at row 719
# Now at row 720
# Now at row 721
# Now at row 722
# Now at row 723
# Now at row 724
# Now at row 725
# Now at row 726
# Now at row 727
# Now at row 728
# Now at row 729
# Now at row 730
# Now at row 731
# Now at row 732
# Now at row 733
# Now at row 734
# Now at row 735
# Now at row 736
# Now at row 737
# Now at row 738
# Now at row 739
# Now at row 740
# Now at row 741
# Now at row 742
# Now at row 743
# Now at row 744
# Now at row 745
# Now at row 746
# Now at row 747
# Now at row 748
# Now at row 749
# Now at row 750
# Now at row 751
# Now at row 752
# Now at row 753
# Now at row 754
# Now at row 755
# Now at row 756
# Now at row 757
# Now at row 758
# Now at row 759
# Now at row 760
# Now at row 761
# Now at row 762
# Now at row 763
# Now at row 764
# Now at row 765
# Now at row 766
# Now at row 767
# Now at row 768
# Now at row 769
# Now at row 770
# Now at row 771
# Now at row 772
# Now at row 773
# Now at row 774
# Non-success status code given http://purl.org/ccf/1.5/ae8a12a2-e52e-4a41-a376-b9a74e22f64c: (404)
# Reason: Not Found
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '25', 'Connection': 'keep-alive', 'Cache-Control': 'public, max-age=86400, stale-while-revalidate=600, stale-if-error=600', 'content-security-policy': "base-uri 'self' cdn.humanatlas.io cdn.jsdelivr.net;script-src 'self' 'unsafe-inline' 'unsafe-eval' cdn.humanatlas.io cdn.jsdelivr.net unpkg.com www.googletagmanager.com;img-src 'self' 'unsafe-eval' cdn.humanatlas.io cdn.jsdelivr.net unpkg.com www.googletagmanager.com;connect-src *;default-src 'self';font-src 'self' https: data:;form-action 'self';frame-ancestors 'self';object-src 'none';script-src-attr 'none';style-src 'self' https: 'unsafe-inline';upgrade-insecure-requests", 'cross-origin-opener-policy': 'same-origin', 'cross-origin-resource-policy': 'same-origin', 'Date': 'Wed, 20 Nov 2024 16:55:57 GMT', 'ETag': 'W/"19-6bBBrG5xJiEq6z4HdnaRbu7qYcg"', 'origin-agent-cluster': '?1', 'referrer-policy': 'no-referrer', 'strict-transport-security': 'max-age=15552000; includeSubDomains', 'x-content-type-options': 'nosniff', 'x-dns-prefetch-control': 'off', 'x-download-options': 'noopen', 'x-frame-options': 'SAMEORIGIN', 'x-permitted-cross-domain-policies': 'none', 'x-xss-protection': '0', 'x-envoy-upstream-service-time': '39', 'Server': 'envoy', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 51a9fe879233bcdaa87b146359af2e0c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'ORD51-C4', 'Alt-Svc': 'h3=":443"; ma=86400', 'X-Amz-Cf-Id': 'SGR7inTV4MgyXzrRuUdnlPsXB-b8SoB2zCeP8bFv9_JtubNb2BDHZg==', 'Age': '505', 'Vary': 'Origin'})
# HTTP response body: Extraction site not found
#
# Now at row 775
# Now at row 776
# Now at row 777
# Now at row 778
# Now at row 779
# Now at row 780
# Now at row 781
# Now at row 782
# Now at row 783
# Now at row 784
# Now at row 785
# Now at row 786
# Now at row 787
# Now at row 788
# Now at row 789
# Now at row 790
# Now at row 791
# Now at row 792
# Now at row 793
# Now at row 794
# Now at row 795
# Now at row 796
# Now at row 797
# Now at row 798
# Now at row 799
# Now at row 800
# Now at row 801
# Now at row 802
# Now at row 803
# Now at row 804
# Now at row 805
# Now at row 806
# Now at row 807
# Now at row 808
# Now at row 809
# Now at row 810
# Now at row 811
# Now at row 812
# Now at row 813
# Now at row 814
# Now at row 815
# Now at row 816
# Now at row 817
# Now at row 818
# Now at row 819
# Now at row 820
# Now at row 821
# Now at row 822
# Now at row 823
# Now at row 824
# Now at row 825
# Now at row 826
# Now at row 827
# Now at row 828
# Now at row 829
# Now at row 830
# Now at row 831
# Now at row 832
# Now at row 833
# Now at row 834
# Now at row 835
# Now at row 836
# Now at row 837
# Now at row 838
# Now at row 839
# Now at row 840
# Now at row 841
# Now at row 842
# Now at row 843
# Now at row 844
# Now at row 845
# Now at row 846
# Now at row 847
# Now at row 848
# Now at row 849
# Now at row 850
# Now at row 851
# Now at row 852
# Now at row 853
# Now at row 854
# Now at row 855
# Now at row 856
# Now at row 857
# Now at row 858
# Now at row 859
# Now at row 860
# Now at row 861
# Now at row 862
# Now at row 863
# Now at row 864
# Now at row 865
# Now at row 866
# Now at row 867
# Now at row 868
# Now at row 869
# Now at row 870
# Now at row 871
# Now at row 872
# Now at row 873
# Now at row 874
# Now at row 875
# Now at row 876
# Now at row 877
# Now at row 878
# Now at row 879
# Now at row 880
# Now at row 881
# Now at row 882
# Now at row 883
# Now at row 884
# Now at row 885
# Now at row 886
# Now at row 887
# Now at row 888
# Now at row 889
# Now at row 890
# Now at row 891
# Now at row 892
# Now at row 893
# Now at row 894
# Now at row 895
# Now at row 896
# Now at row 897
# Now at row 898
# Now at row 899
# Now at row 900
# Now at row 901
# Now at row 902
# Now at row 903
# Now at row 904
# Now at row 905
# Now at row 906
# Now at row 907
# Now at row 908
# Now at row 909
# Now at row 910
# Now at row 911
# Now at row 912
# Now at row 913
# Now at row 914
# Now at row 915
# Now at row 916
# Now at row 917
# Now at row 918
# Now at row 919
# Now at row 920
# Now at row 921
# Now at row 922
# Now at row 923
# Now at row 924
# Now at row 925
# Now at row 926
# Now at row 927
# Now at row 928
# Now at row 929
# Now at row 930
# Now at row 931
# Now at row 932
#         sex                                       rui_location  \
# 0    Female  http://purl.org/ccf/1.5/2156f837-2ab2-4305-8e7...
# 1    Female  http://purl.org/ccf/1.5/8f99a469-7d51-46dc-919...
# 2    Female  http://purl.org/ccf/1.5/f6512db4-2809-4ffe-864...
# 3      Male  http://purl.org/ccf/1.5/886e391d-0151-46d3-8a5...
# 4      Male  http://purl.org/ccf/1.5/da28394d-789a-4fba-842...
# ..      ...                                                ...
# 927    Male  http://purl.org/ccf/1.5/aba1ebe3-af18-40cc-b53...
# 928    Male  http://purl.org/ccf/1.5/ca23f77c-a3cd-453f-bbe...
# 929    Male  http://purl.org/ccf/1.5/d662fd53-e925-4921-8d8...
# 930    Male  http://purl.org/ccf/1.5/df0b33f7-371a-47a4-a63...
# 931    Male  http://purl.org/ccf/1.5/fd76b9bb-85b0-4dd0-8e6...
#
#                                                dataset        tool  \
# 0    https://api.cellxgene.cziscience.com/dp/v1/col...  celltypist
# 1    https://entity.api.hubmapconsortium.org/entiti...     azimuth
# 2    https://doi.org/10.1126/science.abl4290#GTEX-1...        popv
# 3    https://entity.api.hubmapconsortium.org/entiti...        popv
# 4    https://entity.api.hubmapconsortium.org/entiti...        popv
# ..                                                 ...         ...
# 927  https://entity.api.hubmapconsortium.org/entiti...        popv
# 928  https://entity.api.hubmapconsortium.org/entiti...     azimuth
# 929  https://entity.api.hubmapconsortium.org/entiti...        popv
# 930  https://entity.api.hubmapconsortium.org/entiti...     azimuth
# 931  https://entity.api.hubmapconsortium.org/entiti...  celltypist
#
#                                          predicted_rui  similarity  \
# 0    http://purl.org/ccf/1.5/05c11830-1526-4472-bd1...    0.441815
# 1    http://purl.org/ccf/1.5/731ade72-cdb7-4262-8be...    0.792217
# 2    http://purl.org/ccf/1.5/ca476545-5b98-476c-b2f...    0.951883
# 3    http://purl.org/ccf/1.5/f6512db4-2809-4ffe-864...    0.957861
# 4    http://purl.org/ccf/1.5/f6512db4-2809-4ffe-864...    0.945847
# ..                                                 ...         ...
# 927  http://purl.org/ccf/1.5/fd4fcec2-93c3-428f-ad3...    0.925139
# 928  http://purl.org/ccf/1.5/1f414fc5-cb93-45b7-a1b...    0.855982
# 929  http://purl.org/ccf/1.5/aba1ebe3-af18-40cc-b53...    0.991318
# 930  http://purl.org/ccf/1.5/db35f27d-313f-4dd6-819...    0.911654
# 931  http://purl.org/ccf/1.5/502f175c-9d55-4341-b6f...    0.755117
#
#      as_percentage_cosine_sim
# 0                    0.532793
# 1                    1.000000
# 2                    1.000000
# 3                    0.000000
# 4                    0.000000
# ..                        ...
# 927                  1.000000
# 928                  0.000000
# 929                  0.000000
# 930                  1.000000
# 931                  1.000000
#
# [932 rows x 7 columns]

# %%
# filter out rows with a string instead of float for sim
df_y_filtered_as_needed = df_y[~df_y['as_percentage_cosine_sim'].apply(lambda val: isinstance(val, str))]

df_y_filtered_as_needed
# Out:
#         sex                                       rui_location  \
# 0    Female  http://purl.org/ccf/1.5/2156f837-2ab2-4305-8e7...
# 1    Female  http://purl.org/ccf/1.5/8f99a469-7d51-46dc-919...
# 2    Female  http://purl.org/ccf/1.5/f6512db4-2809-4ffe-864...
# 3      Male  http://purl.org/ccf/1.5/886e391d-0151-46d3-8a5...
# 4      Male  http://purl.org/ccf/1.5/da28394d-789a-4fba-842...
# ..      ...                                                ...
# 927    Male  http://purl.org/ccf/1.5/aba1ebe3-af18-40cc-b53...
# 928    Male  http://purl.org/ccf/1.5/ca23f77c-a3cd-453f-bbe...
# 929    Male  http://purl.org/ccf/1.5/d662fd53-e925-4921-8d8...
# 930    Male  http://purl.org/ccf/1.5/df0b33f7-371a-47a4-a63...
# 931    Male  http://purl.org/ccf/1.5/fd76b9bb-85b0-4dd0-8e6...
#
#                                                dataset        tool  \
# 0    https://api.cellxgene.cziscience.com/dp/v1/col...  celltypist
# 1    https://entity.api.hubmapconsortium.org/entiti...     azimuth
# 2    https://doi.org/10.1126/science.abl4290#GTEX-1...        popv
# 3    https://entity.api.hubmapconsortium.org/entiti...        popv
# 4    https://entity.api.hubmapconsortium.org/entiti...        popv
# ..                                                 ...         ...
# 927  https://entity.api.hubmapconsortium.org/entiti...        popv
# 928  https://entity.api.hubmapconsortium.org/entiti...     azimuth
# 929  https://entity.api.hubmapconsortium.org/entiti...        popv
# 930  https://entity.api.hubmapconsortium.org/entiti...     azimuth
# 931  https://entity.api.hubmapconsortium.org/entiti...  celltypist
#
#                                          predicted_rui  similarity  \
# 0    http://purl.org/ccf/1.5/05c11830-1526-4472-bd1...    0.441815
# 1    http://purl.org/ccf/1.5/731ade72-cdb7-4262-8be...    0.792217
# 2    http://purl.org/ccf/1.5/ca476545-5b98-476c-b2f...    0.951883
# 3    http://purl.org/ccf/1.5/f6512db4-2809-4ffe-864...    0.957861
# 4    http://purl.org/ccf/1.5/f6512db4-2809-4ffe-864...    0.945847
# ..                                                 ...         ...
# 927  http://purl.org/ccf/1.5/fd4fcec2-93c3-428f-ad3...    0.925139
# 928  http://purl.org/ccf/1.5/1f414fc5-cb93-45b7-a1b...    0.855982
# 929  http://purl.org/ccf/1.5/aba1ebe3-af18-40cc-b53...    0.991318
# 930  http://purl.org/ccf/1.5/db35f27d-313f-4dd6-819...    0.911654
# 931  http://purl.org/ccf/1.5/502f175c-9d55-4341-b6f...    0.755117
#
#      as_percentage_cosine_sim
# 0                    0.532793
# 1                    1.000000
# 2                    1.000000
# 3                    0.000000
# 4                    0.000000
# ..                        ...
# 927                  1.000000
# 928                  0.000000
# 929                  0.000000
# 930                  1.000000
# 931                  1.000000
#
# [932 rows x 7 columns]

# %% [markdown]
# ## Visualize

# %% [markdown]
# ### Create combined DataFrame

# %%
# Merging on columns
df_merged = pd.merge(
  df_x, df_y_filtered_as_needed, on=['dataset', 'tool', 'rui_location', 'sex'], how='inner')

# rename similarity columns for plotting
df_merged = df_merged.rename(columns={
  "datasetVsRuiSim": "ctann_sim",
  # RUI (y axis) cosine sim between dataset cell summary vs PREDICTED (most similar) rui location cell summary (*except* its TRUE rui location)
  "similarity": "rui_sim_by_cell_summary",
  "as_percentage_cosine_sim": "rui_sim_as_percentage"
})

df_merged
# Out:
#         sex                                             sample  \
# 0    Female  https://api.cellxgene.cziscience.com/dp/v1/col...
# 1    Female  https://api.cellxgene.cziscience.com/dp/v1/col...
# 2    Female  https://api.cellxgene.cziscience.com/dp/v1/col...
# 3    Female  https://api.cellxgene.cziscience.com/dp/v1/col...
# 4    Female  https://api.cellxgene.cziscience.com/dp/v1/col...
# ..      ...                                                ...
# 893    Male  https://entity.api.hubmapconsortium.org/entiti...
# 894    Male  https://entity.api.hubmapconsortium.org/entiti...
# 895    Male  https://entity.api.hubmapconsortium.org/entiti...
# 896    Male  https://entity.api.hubmapconsortium.org/entiti...
# 897    Male  https://entity.api.hubmapconsortium.org/entiti...
#
#                                           rui_location  \
# 0    http://purl.org/ccf/1.5/9abfed4e-2fde-4d80-a8a...
# 1    http://purl.org/ccf/1.5/9abfed4e-2fde-4d80-a8a...
# 2    http://purl.org/ccf/1.5/9abfed4e-2fde-4d80-a8a...
# 3    http://purl.org/ccf/1.5/2156f837-2ab2-4305-8e7...
# 4    http://purl.org/ccf/1.5/2156f837-2ab2-4305-8e7...
# ..                                                 ...
# 893  http://purl.org/ccf/1.5/e21afc3c-3a7c-4717-90d...
# 894  http://purl.org/ccf/1.5/b2aca02c-9559-4869-b55...
# 895  http://purl.org/ccf/1.5/e43280c9-840b-481f-a8a...
# 896  http://purl.org/ccf/1.5/fb6bb0ea-5ba7-44e2-90a...
# 897  http://purl.org/ccf/1.5/cc08d64c-5d75-4995-b3b...
#
#                                                dataset        tool  \
# 0    https://api.cellxgene.cziscience.com/dp/v1/col...     azimuth
# 1    https://api.cellxgene.cziscience.com/dp/v1/col...  celltypist
# 2    https://api.cellxgene.cziscience.com/dp/v1/col...        popv
# 3    https://api.cellxgene.cziscience.com/dp/v1/col...     azimuth
# 4    https://api.cellxgene.cziscience.com/dp/v1/col...  celltypist
# ..                                                 ...         ...
# 893  https://entity.api.hubmapconsortium.org/entiti...        popv
# 894  https://entity.api.hubmapconsortium.org/entiti...        popv
# 895  https://entity.api.hubmapconsortium.org/entiti...        popv
# 896  https://entity.api.hubmapconsortium.org/entiti...        popv
# 897  https://entity.api.hubmapconsortium.org/entiti...        popv
#
#                modality            organ         organId  ctann_sim  \
# 0    sc_transcriptomics            heart  UBERON:0000948   0.911356
# 1    sc_transcriptomics            heart  UBERON:0000948   0.701952
# 2    sc_transcriptomics            heart  UBERON:0000948   0.941554
# 3    sc_transcriptomics            heart  UBERON:0000948   0.933921
# 4    sc_transcriptomics            heart  UBERON:0000948   0.474365
# ..                  ...              ...             ...        ...
# 893  sc_transcriptomics           spleen  UBERON:0002106   0.744703
# 894  sc_transcriptomics  urinary bladder  UBERON:0001255   1.000000
# 895  sc_transcriptomics  urinary bladder  UBERON:0001255   0.998475
# 896  sc_transcriptomics  urinary bladder  UBERON:0001255   0.913469
# 897  sc_transcriptomics  urinary bladder  UBERON:0001255   0.966213
#
#                                          predicted_rui  \
# 0    http://purl.org/ccf/1.5/05c11830-1526-4472-bd1...
# 1    http://purl.org/ccf/1.5/1fe61622-ba53-47c9-967...
# 2    http://purl.org/ccf/1.5/ca476545-5b98-476c-b2f...
# 3    http://purl.org/ccf/1.5/1fe61622-ba53-47c9-967...
# 4    http://purl.org/ccf/1.5/1fe61622-ba53-47c9-967...
# ..                                                 ...
# 893  http://purl.org/ccf/1.5/dc29aac6-af08-4fa4-9d5...
# 894  http://purl.org/ccf/1.5/e43280c9-840b-481f-a8a...
# 895  http://purl.org/ccf/1.5/cc08d64c-5d75-4995-b3b...
# 896  http://purl.org/ccf/1.5/b2aca02c-9559-4869-b55...
# 897  http://purl.org/ccf/1.5/e43280c9-840b-481f-a8a...
#
#      rui_sim_by_cell_summary  rui_sim_as_percentage
# 0                   0.917636               0.532793
# 1                   0.925033               0.000000
# 2                   0.971689               0.000000
# 3                   0.978646               0.000000
# 4                   0.916703               0.000000
# ..                       ...                    ...
# 893                 0.744706               0.000000
# 894                 1.000000               0.000000
# 895                 0.998475               1.000000
# 896                 0.913469               0.000000
# 897                 0.966213               1.000000
#
# [898 rows x 12 columns]

# %% [markdown]
# ### Subset data (if needed)

# %%
pd.options.display.max_colwidth = 100

# set subset to full df
df_subset = df_merged

# insert any code here to subset if needed
# YOUR CODE HERE

# inspect
df_subset
# Out:
#         sex  \
# 0    Female
# 1    Female
# 2    Female
# 3    Female
# 4    Female
# ..      ...
# 893    Male
# 894    Male
# 895    Male
# 896    Male
# 897    Male
#
#                                                                                                   sample  \
# 0    https://api.cellxgene.cziscience.com/dp/v1/collections/b52eb423-5d0d-4645-b217-e1c6d38b2e72#D1$a...
# 1    https://api.cellxgene.cziscience.com/dp/v1/collections/b52eb423-5d0d-4645-b217-e1c6d38b2e72#D1$a...
# 2    https://api.cellxgene.cziscience.com/dp/v1/collections/b52eb423-5d0d-4645-b217-e1c6d38b2e72#D1$a...
# 3    https://api.cellxgene.cziscience.com/dp/v1/collections/b52eb423-5d0d-4645-b217-e1c6d38b2e72#D1$h...
# 4    https://api.cellxgene.cziscience.com/dp/v1/collections/b52eb423-5d0d-4645-b217-e1c6d38b2e72#D1$h...
# ..                                                                                                   ...
# 893                    https://entity.api.hubmapconsortium.org/entities/d3525d35f6d5ee3dc3186613b0ab1762
# 894                    https://entity.api.hubmapconsortium.org/entities/06f84c2ac7e2b777781965980b9cb07d
# 895                    https://entity.api.hubmapconsortium.org/entities/b3c28a468b99b89af6430e2b53f2557f
# 896                    https://entity.api.hubmapconsortium.org/entities/734f394ab73a5b3974b394a366e48081
# 897                    https://entity.api.hubmapconsortium.org/entities/4ff2d3993ea5aeeeb360d163ab217dc6
#
#                                                      rui_location  \
# 0    http://purl.org/ccf/1.5/9abfed4e-2fde-4d80-a8aa-7439a106d895
# 1    http://purl.org/ccf/1.5/9abfed4e-2fde-4d80-a8aa-7439a106d895
# 2    http://purl.org/ccf/1.5/9abfed4e-2fde-4d80-a8aa-7439a106d895
# 3    http://purl.org/ccf/1.5/2156f837-2ab2-4305-8e7f-8084249e91cd
# 4    http://purl.org/ccf/1.5/2156f837-2ab2-4305-8e7f-8084249e91cd
# ..                                                            ...
# 893  http://purl.org/ccf/1.5/e21afc3c-3a7c-4717-90d5-e5739fd8432c
# 894  http://purl.org/ccf/1.5/b2aca02c-9559-4869-b551-4bfb59bf84b3
# 895  http://purl.org/ccf/1.5/e43280c9-840b-481f-a8a6-90114c2c5cc9
# 896  http://purl.org/ccf/1.5/fb6bb0ea-5ba7-44e2-90a6-f972a70da51a
# 897  http://purl.org/ccf/1.5/cc08d64c-5d75-4995-b3b0-00239a742184
#
#                                                                                                  dataset  \
# 0    https://api.cellxgene.cziscience.com/dp/v1/collections/b52eb423-5d0d-4645-b217-e1c6d38b2e72#D1$a...
# 1    https://api.cellxgene.cziscience.com/dp/v1/collections/b52eb423-5d0d-4645-b217-e1c6d38b2e72#D1$a...
# 2    https://api.cellxgene.cziscience.com/dp/v1/collections/b52eb423-5d0d-4645-b217-e1c6d38b2e72#D1$a...
# 3    https://api.cellxgene.cziscience.com/dp/v1/collections/b52eb423-5d0d-4645-b217-e1c6d38b2e72#D1$h...
# 4    https://api.cellxgene.cziscience.com/dp/v1/collections/b52eb423-5d0d-4645-b217-e1c6d38b2e72#D1$h...
# ..                                                                                                   ...
# 893                    https://entity.api.hubmapconsortium.org/entities/f412e76986c1012ea9589d545ed8f043
# 894                    https://entity.api.hubmapconsortium.org/entities/3ff97368165004ae9e3b799cef261a2a
# 895                    https://entity.api.hubmapconsortium.org/entities/4b3d4efca2e64a650e943c7bf63f9830
# 896                    https://entity.api.hubmapconsortium.org/entities/578f1282276ddc1cc4c4817e4950f13c
# 897                    https://entity.api.hubmapconsortium.org/entities/d67c61063b82f6479e93133bdd8949fb
#
#            tool            modality            organ         organId  \
# 0       azimuth  sc_transcriptomics            heart  UBERON:0000948
# 1    celltypist  sc_transcriptomics            heart  UBERON:0000948
# 2          popv  sc_transcriptomics            heart  UBERON:0000948
# 3       azimuth  sc_transcriptomics            heart  UBERON:0000948
# 4    celltypist  sc_transcriptomics            heart  UBERON:0000948
# ..          ...                 ...              ...             ...
# 893        popv  sc_transcriptomics           spleen  UBERON:0002106
# 894        popv  sc_transcriptomics  urinary bladder  UBERON:0001255
# 895        popv  sc_transcriptomics  urinary bladder  UBERON:0001255
# 896        popv  sc_transcriptomics  urinary bladder  UBERON:0001255
# 897        popv  sc_transcriptomics  urinary bladder  UBERON:0001255
#
#      ctann_sim                                                 predicted_rui  \
# 0     0.911356  http://purl.org/ccf/1.5/05c11830-1526-4472-bd12-ea24dbcfd3cc
# 1     0.701952  http://purl.org/ccf/1.5/1fe61622-ba53-47c9-967e-e764c21b8189
# 2     0.941554  http://purl.org/ccf/1.5/ca476545-5b98-476c-b2fd-1b8e1708faed
# 3     0.933921  http://purl.org/ccf/1.5/1fe61622-ba53-47c9-967e-e764c21b8189
# 4     0.474365  http://purl.org/ccf/1.5/1fe61622-ba53-47c9-967e-e764c21b8189
# ..         ...                                                           ...
# 893   0.744703  http://purl.org/ccf/1.5/dc29aac6-af08-4fa4-9d58-5cb1d93ee8dc
# 894   1.000000  http://purl.org/ccf/1.5/e43280c9-840b-481f-a8a6-90114c2c5cc9
# 895   0.998475  http://purl.org/ccf/1.5/cc08d64c-5d75-4995-b3b0-00239a742184
# 896   0.913469  http://purl.org/ccf/1.5/b2aca02c-9559-4869-b551-4bfb59bf84b3
# 897   0.966213  http://purl.org/ccf/1.5/e43280c9-840b-481f-a8a6-90114c2c5cc9
#
#      rui_sim_by_cell_summary  rui_sim_as_percentage
# 0                   0.917636               0.532793
# 1                   0.925033               0.000000
# 2                   0.971689               0.000000
# 3                   0.978646               0.000000
# 4                   0.916703               0.000000
# ..                       ...                    ...
# 893                 0.744706               0.000000
# 894                 1.000000               0.000000
# 895                 0.998475               1.000000
# 896                 0.913469               0.000000
# 897                 0.966213               1.000000
#
# [898 rows x 12 columns]

# %% [markdown]
# ### Build plot

# %% [markdown]
# Functions for making plots

# %%
def make_validation_scattergraph(x: float, y: float, palette: str, col: str, row: str, hue: str, x_label: str, y_label: str):
    """A wrapper function around a seaborn FacetGrid to make multiple versions of the validation scattergraph

    Args:
                    x (float): x-value
                    y (float): y-value
                    palette (str): Name for color palette
                    col (str): Column of facet grid
                    row (str): Row of facet grid
                    hue (str): Color for points
                    x_label (str): Label on x-axis
            y_label (str): Label on y-axis
    """

    # Create a custom color palette
    custom_palette = sns.color_palette(palette)

    # set font size
    sns.set_theme(font_scale=2)

    # Create FacetGrid
    g = sns.FacetGrid(
        df_subset,
        col=col,
        row=row,
        hue=hue,
        palette=custom_palette,
        height=5,
        aspect=2
    )

    # Set the style of the plot
    # Options: "white", "dark", "whitegrid", "darkgrid", "ticks"
    sns.set_style("whitegrid")

    # Create a scatter plot
    g.map(sns.scatterplot, x, y)

    # Set labels
    g.set(xlabel=x_label, ylabel=y_label)

    # Add a legend
    g.add_legend()

    # Show the plot
    plt.show()

# %% [markdown]
# ### Data dictionary

# %% [markdown]
# | Axis             | Variable                | Explanation                                                                                                                                 |
# | ---------------- | ----------------------- | ------------------------------------------------------------------------------------------------------------------------------------------- |
# | x                | ctann_sim               | CTann (x axis) Cosine sim between TRUE cell summary of input dataset and PREDICTED cell summary of input RUI location (as computed by US 1) |
# | y (cell summary) | rui_sim_by_cell_summary | (y axis) cosine sim between TRUE RUI cell summary vs PREDICTED (most similar cell type population) rui location cell summary |
# | y (AS%)          | rui_sim_as_percentage   | RUI (y axis) cosine sim between AS% of TRUE and PREDICTED rui (determined by cosine sim captured as `ruiVsTopPredictedRuiSim` in [this query](https://github.com/x-atlas-consortia/hra-pop/blob/main/queries/atlas/validation-v7-ctann-rui.rq)). Could also use `datasetVsRuiSim`, which is the sim between a dataset and its OWN rui location
#                                   |

# %% [markdown]
# ### CTann vs RUI AS% similarity

# %%
make_validation_scattergraph(
  "ctann_sim", "rui_sim_as_percentage", "Set1", "sex", "tool", "organ", "CTann", "RUI AS%")

# %%
# correlation
stats = df_subset[['ctann_sim', 'rui_sim_as_percentage',
                   'rui_sim_by_cell_summary']].astype(float)
stats.corr(min_periods=3)
# Out:
#                          ctann_sim  rui_sim_as_percentage  \
# ctann_sim                 1.000000               0.214856
# rui_sim_as_percentage     0.214856               1.000000
# rui_sim_by_cell_summary   0.680724               0.059894
#
#                          rui_sim_by_cell_summary
# ctann_sim                               0.680724
# rui_sim_as_percentage                   0.059894
# rui_sim_by_cell_summary                 1.000000

# %%
# Mean, STDDEV, min, etc.
summary = stats.describe()
summary
# Out:
#         ctann_sim  rui_sim_as_percentage  rui_sim_by_cell_summary
# count  898.000000             898.000000               898.000000
# mean     0.832648               0.419575                 0.869627
# std      0.159287               0.464818                 0.133640
# min      0.117205               0.000000                 0.151411
# 25%      0.743555               0.000000                 0.811778
# 50%      0.886364               0.118469                 0.914306
# 75%      0.953453               1.000000                 0.965113
# max      1.000000               1.000000                 1.000000

# %% [markdown]
# ## Visualize rui_sim_by_cell_summary vs rui_sim_as_percentage

# %%
# make scattergraph of rui_sim_by_cell_summary vs rui_sim_as_percentage
make_validation_scattergraph(
    "ctann_sim", "rui_sim_by_cell_summary", "Set1", "sex", "tool", "organ", "CTann", "RUI cell sim")

# %% [markdown]
# ## Visualize discrepancies between the two RUI sim metrics

# %%
# make scattergraph of rui_sim_by_cell_summary vs rui_sim_as_percentage
make_validation_scattergraph(
    "rui_sim_as_percentage", "rui_sim_by_cell_summary", "Set1", "sex", "tool", "organ", "rui_sim_as_percentage", "rui_sim_by_cell_summary")
