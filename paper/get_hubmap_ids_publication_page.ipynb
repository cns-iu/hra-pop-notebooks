# %% [markdown]
# ## Get all HuBMAP IDs in the HRApop Atlas

# %%
# install and import libraries
# %pip install pandas requests

import pandas as pd
import requests 
import json
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# global settings
hra_pop_version = 'v0.12.0'
branch = 'v0.12.0'

# %%
# load HRApop reports
url = f'https://raw.githubusercontent.com/x-atlas-consortia/hra-pop/refs/heads/{branch}/output-data/{hra_pop_version}/reports/universe-ad-hoc/sankey.csv'
sankey = pd.read_csv(url)
sankey
# Out:
#              portal study_paper  \
# 0              KPMP         NaN
# 1              KPMP         NaN
# 2              KPMP         NaN
# 3               HRA         NaN
# 4      HIRN, ESPACE         NaN
# ...             ...         ...
# 22459         SPARC         NaN
# 22460         SPARC         NaN
# 22461         SPARC         NaN
# 22462          KPMP         NaN
# 22463          KPMP         NaN
#
#                                                      doi lead_author  \
# 0               http://dx.doi.org/10.1681/ASN.2016091027         NaN
# 1               http://dx.doi.org/10.1681/ASN.2016091027         NaN
# 2               http://dx.doi.org/10.1681/ASN.2016091027         NaN
# 3                                                    NaN         NaN
# 4                 https://doi.org/10.5281/zenodo.7742474         NaN
# ...                                                  ...         ...
# 22459  https://sparc.science/datasets/390/version/1?d...         NaN
# ...

# %%
# filter for HuBMAP dataset IDs
hubmap_ids = sankey[(sankey['portal'] == 'HuBMAP') & (sankey['is_atlas_dataset'] == True)][[
    'portal', 'dataset_id', 'organ_name']]

hubmap_ids_filtered = hubmap_ids[hubmap_ids['dataset_id'].str.contains('entity')].drop_duplicates(subset=['dataset_id'], keep='first')
hubmap_ids_filtered
# Out:
#        portal                                         dataset_id  \
# 16667  HuBMAP  https://entity.api.hubmapconsortium.org/entiti...
# 16669  HuBMAP  https://entity.api.hubmapconsortium.org/entiti...
# 16674  HuBMAP  https://entity.api.hubmapconsortium.org/entiti...
# 16681  HuBMAP  https://entity.api.hubmapconsortium.org/entiti...
# 16688  HuBMAP  https://entity.api.hubmapconsortium.org/entiti...
# ...       ...                                                ...
# 20877  HuBMAP  https://entity.api.hubmapconsortium.org/entiti...
# 20888  HuBMAP  https://entity.api.hubmapconsortium.org/entiti...
# 20889  HuBMAP  https://entity.api.hubmapconsortium.org/entiti...
# 20892  HuBMAP  https://entity.api.hubmapconsortium.org/entiti...
# 20896  HuBMAP  https://entity.api.hubmapconsortium.org/entiti...
#
#             organ_name
# 16667     right kidney
# 16669     right kidney
# 16674            heart
# 16681           spleen
# 16688     right kidney
# ...                ...
# ...

# %%
# isolate UUID
hubmap_ids_filtered['uuid'] = hubmap_ids_filtered['dataset_id'].apply(
    lambda d: d.split('/')[len(d.split('/'))-1])
hubmap_ids_filtered
# Out:
#        portal                                         dataset_id  \
# 16667  HuBMAP  https://entity.api.hubmapconsortium.org/entiti...
# 16669  HuBMAP  https://entity.api.hubmapconsortium.org/entiti...
# 16674  HuBMAP  https://entity.api.hubmapconsortium.org/entiti...
# 16681  HuBMAP  https://entity.api.hubmapconsortium.org/entiti...
# 16688  HuBMAP  https://entity.api.hubmapconsortium.org/entiti...
# ...       ...                                                ...
# 20877  HuBMAP  https://entity.api.hubmapconsortium.org/entiti...
# 20888  HuBMAP  https://entity.api.hubmapconsortium.org/entiti...
# 20889  HuBMAP  https://entity.api.hubmapconsortium.org/entiti...
# 20892  HuBMAP  https://entity.api.hubmapconsortium.org/entiti...
# 20896  HuBMAP  https://entity.api.hubmapconsortium.org/entiti...
#
#             organ_name                              uuid
# 16667     right kidney  0027cb59bcb4a34d5db83acaf934a9d9
# 16669     right kidney  00318be0b7cfa3c6ed7fbeab08fe700b
# ...

# %%
# add HuBMAP IDs in addition to UUIDs
entity_api = f'https://entity.api.hubmapconsortium.org/datasets/'

def try_hubmap_id(url):
  """Tries to get a hubmap_id from an API response

  Args:
      url (str): URL for Entity API 
  """
  response = ''
  try:
    response = json.loads(requests.get(url).text)['hubmap_id']
    print(response)
    return response
  except:
    response = "no hubmap_id found"
    print(response)
    return response
    

hubmap_ids_filtered['hubmap'] = hubmap_ids_filtered['dataset_id'].apply(lambda d: try_hubmap_id(d))
hubmap_ids_filtered
# Out:
# HBM465.RKKK.264
# HBM232.FHDF.343
# HBM927.DZCV.762
# HBM556.KSFB.592
# HBM699.GZNP.474
# HBM793.JDRF.289
# HBM633.JXTC.477
# HBM623.PSDG.665
# HBM976.MRWH.263
# HBM795.TFHS.265
# HBM962.KQLZ.422
# HBM732.FZVZ.656
# HBM844.RXXR.293
# HBM495.ZFDT.229
# HBM768.FKCS.477
# HBM688.RPFC.258
# HBM648.DKQK.874
# HBM693.SRHJ.546
# HBM839.ZFRD.789
# HBM735.FSBZ.626
# HBM644.NKCL.897
# HBM374.PCQG.742
# HBM468.SSXX.967
# HBM264.MJCH.639
# HBM793.TLNJ.249
# HBM757.KLKW.524
# HBM746.VTDZ.959
# HBM979.KNQM.454
# HBM689.ZKRJ.585
# HBM934.KLGL.584
# HBM547.TFRR.794
# HBM232.MGHW.694
# HBM455.RZPH.997
# HBM996.XSNK.694
# HBM237.TJFZ.599
# HBM398.JQZB.348
# HBM945.FSHR.864
# HBM936.MHTZ.834
# HBM893.MCGS.487
# HBM389.PKHL.936
# HBM269.GDLH.894
# HBM999.KMVN.849
# HBM528.DMSV.294
# HBM439.WJDV.974
# HBM393.DZDZ.972
# HBM675.RVGB.258
# HBM546.RNHX.756
# HBM265.PCGD.229
# HBM975.WQQQ.853
# HBM385.LQVK.975
# HBM537.GVTL.683
# HBM284.MNHF.223
# HBM996.MDQH.988
# HBM398.BLRW.228
# HBM843.CLTD.457
# ...

# %%
# adjust column names
hubmap_ids_filtered.rename(columns={'hubmap': 'hubmap_id'})
# Out:
#        portal                                         dataset_id  \
# 16667  HuBMAP  https://entity.api.hubmapconsortium.org/entiti...
# 16669  HuBMAP  https://entity.api.hubmapconsortium.org/entiti...
# 16674  HuBMAP  https://entity.api.hubmapconsortium.org/entiti...
# 16681  HuBMAP  https://entity.api.hubmapconsortium.org/entiti...
# 16688  HuBMAP  https://entity.api.hubmapconsortium.org/entiti...
# ...       ...                                                ...
# 20877  HuBMAP  https://entity.api.hubmapconsortium.org/entiti...
# 20888  HuBMAP  https://entity.api.hubmapconsortium.org/entiti...
# 20889  HuBMAP  https://entity.api.hubmapconsortium.org/entiti...
# 20892  HuBMAP  https://entity.api.hubmapconsortium.org/entiti...
# 20896  HuBMAP  https://entity.api.hubmapconsortium.org/entiti...
#
#             organ_name                              uuid        hubmap_id
# 16667     right kidney  0027cb59bcb4a34d5db83acaf934a9d9  HBM465.RKKK.264
# ...

# %%
# export
hubmap_ids_filtered.to_csv('output/hubmap_ids_hra-pop_universe.csv', index=False)
